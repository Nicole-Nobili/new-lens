# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformer_lens import HookedTransformer 
import torch
from transformer_lens.hook_points import (
    HookPoint,
)  # Hooking utilities
from jaxtyping import Float
import tqdm
import transformer_lens.utils as utils
from functools import partial
from tabulate import tabulate

# %%
#Loading model - let's use Pythia 
model = HookedTransformer.from_pretrained("EleutherAI/pythia-410m-deduped")
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/pythia-410m-deduped")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loaded pretrained model EleutherAI/pythia-410m-deduped into HookedTransformer

# %%
tokens = tokenizer.encode("new simple network architecture, the Transformer", return_tensors="pt")
with torch.no_grad():
    logits, clean_cache = model.run_with_cache(tokens)

# %%
#lens_output = lenses.forward(hidden_states_at_last_token[:, layer_index, :], layer_index)

class NewLens:
    def __init__(self, model):
        self._model = model

    def forward(self, cache_to_patch, layer_index):
        #cache_to_patch : batch x d_model
        n_batch = cache_to_patch.shape[0]

        def resid_pre_hook(
            activations: torch.Tensor,
            hook: HookPoint,
        ):
            return cache_to_patch
        
        resid_pre_hook_fn = partial(resid_pre_hook)
        self._model.reset_hooks(including_permanent=True)
        self._model.blocks[layer_index].hook_resid_pre.add_hook(resid_pre_hook_fn)
        fake_inputs = torch.zeros(n_batch, 1, device="cpu").int() #patching with batch x position long 1
        out = self._model(fake_inputs)
        return out

# %%
#lens_output = lenses.forward(hidden_states_at_last_token[:, layer_index, :], layer_index)

class NewLens:
    def __init__(self, model):
        self._model = model

    def forward(self, cache_to_patch, layer_index):
        #cache_to_patch : batch x d_model
        n_batch = cache_to_patch.shape[0]

        def hook(
            model,input,output
        ):
            return cache_to_patch
        
        handle = self._model.gpt_neox.layers[1].register_forward_hook(hook)
        fake_inputs = torch.zeros(n_batch, 1, device="cpu").int() #patching with batch x position long 1
        out = self._model(fake_inputs)
        handle.remove()

        return out

# %%
lens = NewLens(model)
n_pos = clean_cache[utils.get_act_name("resid_pre", 0)].shape[1]
n_batch = clean_cache[utils.get_act_name("resid_pre", 0)].shape[0]
n_topk = 1

patching_result = torch.zeros((n_batch, model.cfg.n_layers, n_pos, n_topk), device="cpu") 

for layer in range(model.cfg.n_layers):
    for position in range(n_pos):
        lens_output = lens.forward(clean_cache[utils.get_act_name("resid_pre", layer)][:, position, :].unsqueeze(0), layer)
        _ , patching_result[:, layer, position, :] = torch.topk(lens_output.squeeze(), k=n_topk)

# %%
def residual_stream_patching_hook(
    resid_pre: Float[torch.Tensor, "batch pos d_model"],
    hook: HookPoint,
    position: int
) -> Float[torch.Tensor, "batch pos d_model"]:
    # Each HookPoint has a name attribute giving the name of the hook.
    print(hook.name)
    clean_resid_pre = clean_cache[hook.name]
    resid_pre[:, 0, :] = clean_resid_pre[:, position, :]
    return resid_pre

# We make a tensor to store the results for each patching run. We put it on the model's device to avoid needing to move things between the GPU and CPU, which can be slow.
num_positions = len(tokens[0])
patching_result = torch.zeros((model.cfg.n_layers, num_positions, 1), device=model.cfg.device)

for layer in tqdm.tqdm(range(model.cfg.n_layers)):
    for position in range(num_positions):
        print(position)
        # Use functools.partial to create a temporary hook function with the position fixed
        temp_hook_fn = partial(residual_stream_patching_hook, position=position)
        # Run the model with the patching hook
        patched_logits = model.run_with_hooks(torch.tensor([[0]], device='cuda:0'), fwd_hooks=[
            (utils.get_act_name("resid_post", layer), temp_hook_fn)
        ])
        # Calculate the logit difference      
        _, patching_result[layer, position] = torch.topk(patched_logits.squeeze(), k=1)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# 0
# blocks.0.hook_resid_post
# 1
# blocks.0.hook_resid_post
# 2
# blocks.0.hook_resid_post
# 3
# blocks.0.hook_resid_post
# 4
# blocks.0.hook_resid_post
# 5
# blocks.0.hook_resid_post
#   4%|▍         | 1/24 [00:00<00:21,  1.09it/s]
# 6
# blocks.0.hook_resid_post
# 7
# blocks.0.hook_resid_post
# 0
# blocks.1.hook_resid_post
# 1
# blocks.1.hook_resid_post
# 2
# blocks.1.hook_resid_post
# 3
# blocks.1.hook_resid_post
# 4
# blocks.1.hook_resid_post
# 5
# blocks.1.hook_resid_post
# 6
# blocks.1.hook_resid_post
# 7
# blocks.1.hook_resid_post
#   8%|▊         | 2/24 [00:01<00:18,  1.16it/s]
# 0
# blocks.2.hook_resid_post
# 1
# blocks.2.hook_resid_post
# 2
# blocks.2.hook_resid_post
# 3
# blocks.2.hook_resid_post
# 4
# blocks.2.hook_resid_post
# 5
# blocks.2.hook_resid_post
# 6
# blocks.2.hook_resid_post
#  12%|█▎        | 3/24 [00:02<00:17,  1.18it/s]
# 7
# blocks.2.hook_resid_post
# 0
# blocks.3.hook_resid_post
# 1
# blocks.3.hook_resid_post
# 2
# blocks.3.hook_resid_post
# 3
# blocks.3.hook_resid_post
# 4
# blocks.3.hook_resid_post
# 5
# blocks.3.hook_resid_post
# 6
#  17%|█▋        | 4/24 [00:03<00:16,  1.21it/s]
# blocks.3.hook_resid_post
# 7
# blocks.3.hook_resid_post
# 0
# blocks.4.hook_resid_post
# 1
# blocks.4.hook_resid_post
# 2
# blocks.4.hook_resid_post
# 3
# blocks.4.hook_resid_post
# 4
# blocks.4.hook_resid_post
# 5
# blocks.4.hook_resid_post
# 6
# blocks.4.hook_resid_post
# 7
# blocks.4.hook_resid_post
#  21%|██        | 5/24 [00:04<00:15,  1.25it/s]
# 0
# blocks.5.hook_resid_post
# 1
# blocks.5.hook_resid_post
# 2
# blocks.5.hook_resid_post
# 3
# blocks.5.hook_resid_post
# 4
# blocks.5.hook_resid_post
# 5
# blocks.5.hook_resid_post
# 6
# blocks.5.hook_resid_post
# 7
#  25%|██▌       | 6/24 [00:04<00:14,  1.25it/s]
# blocks.5.hook_resid_post
# 0
# blocks.6.hook_resid_post
# 1
# blocks.6.hook_resid_post
# 2
# blocks.6.hook_resid_post
# 3
# blocks.6.hook_resid_post
# 4
# blocks.6.hook_resid_post
# 5
# blocks.6.hook_resid_post
# 6
#  29%|██▉       | 7/24 [00:05<00:13,  1.26it/s]
# blocks.6.hook_resid_post
# 7
# blocks.6.hook_resid_post
# 0
# blocks.7.hook_resid_post
# 1
# blocks.7.hook_resid_post
# 2
# blocks.7.hook_resid_post
# 3
# blocks.7.hook_resid_post
# 4
# blocks.7.hook_resid_post
# 5
# blocks.7.hook_resid_post
# 6
# blocks.7.hook_resid_post
# 7
#  33%|███▎      | 8/24 [00:06<00:12,  1.24it/s]
# blocks.7.hook_resid_post
# 0
# blocks.8.hook_resid_post
# 1
# blocks.8.hook_resid_post
# 2
# blocks.8.hook_resid_post
# 3
# blocks.8.hook_resid_post
# 4
# blocks.8.hook_resid_post
# 5
# blocks.8.hook_resid_post
# 6
#  38%|███▊      | 9/24 [00:07<00:11,  1.26it/s]
# blocks.8.hook_resid_post
# 7
# blocks.8.hook_resid_post
# 0
# blocks.9.hook_resid_post
# 1
# blocks.9.hook_resid_post
# 2
# blocks.9.hook_resid_post
# 3
# blocks.9.hook_resid_post
# 4
# blocks.9.hook_resid_post
# 5
# blocks.9.hook_resid_post
# 6
# blocks.9.hook_resid_post
#  42%|████▏     | 10/24 [00:08<00:11,  1.24it/s]
# 7
# blocks.9.hook_resid_post
# 0
# blocks.10.hook_resid_post
# 1
# blocks.10.hook_resid_post
# 2
# blocks.10.hook_resid_post
# 3
# blocks.10.hook_resid_post
# 4
# blocks.10.hook_resid_post
# 5
# blocks.10.hook_resid_post
# 6
#  46%|████▌     | 11/24 [00:08<00:10,  1.24it/s]
# blocks.10.hook_resid_post
# 7
# blocks.10.hook_resid_post
# 0
# blocks.11.hook_resid_post
# 1
# blocks.11.hook_resid_post
# 2
# blocks.11.hook_resid_post
# 3
# blocks.11.hook_resid_post
# 4
# blocks.11.hook_resid_post
# 5
# blocks.11.hook_resid_post
#  50%|█████     | 12/24 [00:09<00:09,  1.26it/s]
# 6
# blocks.11.hook_resid_post
# 7
# blocks.11.hook_resid_post
# 0
# blocks.12.hook_resid_post
# 1
# blocks.12.hook_resid_post
# 2
# blocks.12.hook_resid_post
# 3
# blocks.12.hook_resid_post
# 4
# blocks.12.hook_resid_post
# 5
# blocks.12.hook_resid_post
# 6
#  54%|█████▍    | 13/24 [00:10<00:08,  1.24it/s]
# blocks.12.hook_resid_post
# 7
# blocks.12.hook_resid_post
# 0
# blocks.13.hook_resid_post
# 1
# blocks.13.hook_resid_post
# 2
# blocks.13.hook_resid_post
# 3
# blocks.13.hook_resid_post
# 4
# blocks.13.hook_resid_post
# 5
# blocks.13.hook_resid_post
# 6
# blocks.13.hook_resid_post
#  58%|█████▊    | 14/24 [00:11<00:08,  1.23it/s]
# 7
# blocks.13.hook_resid_post
# 0
# blocks.14.hook_resid_post
# 1
# blocks.14.hook_resid_post
# 2
# blocks.14.hook_resid_post
# 3
# blocks.14.hook_resid_post
# 4
# blocks.14.hook_resid_post
# 5
# blocks.14.hook_resid_post
# 6
# blocks.14.hook_resid_post
# 7
# blocks.14.hook_resid_post
#  62%|██████▎   | 15/24 [00:12<00:07,  1.21it/s]
# 0
# blocks.15.hook_resid_post
# 1
# blocks.15.hook_resid_post
# 2
# blocks.15.hook_resid_post
# 3
# blocks.15.hook_resid_post
# 4
# blocks.15.hook_resid_post
# 5
# blocks.15.hook_resid_post
# 6
# blocks.15.hook_resid_post
# 7
# blocks.15.hook_resid_post
#  67%|██████▋   | 16/24 [00:13<00:06,  1.20it/s]
# 0
# blocks.16.hook_resid_post
# 1
# blocks.16.hook_resid_post
# 2
# blocks.16.hook_resid_post
# 3
# blocks.16.hook_resid_post
# 4
# blocks.16.hook_resid_post
# 5
# blocks.16.hook_resid_post
# 6
# blocks.16.hook_resid_post
# 7
# blocks.16.hook_resid_post
#  71%|███████   | 17/24 [00:13<00:05,  1.20it/s]
# 0
# blocks.17.hook_resid_post
# 1
# blocks.17.hook_resid_post
# 2
# blocks.17.hook_resid_post
# 3
# blocks.17.hook_resid_post
# 4
# blocks.17.hook_resid_post
# 5
# blocks.17.hook_resid_post
# 6
# blocks.17.hook_resid_post
# 7
#  75%|███████▌  | 18/24 [00:14<00:05,  1.16it/s]
# blocks.17.hook_resid_post
# 0
# blocks.18.hook_resid_post
# 1
# blocks.18.hook_resid_post
# 2
# blocks.18.hook_resid_post
# 3
# blocks.18.hook_resid_post
# 4
# blocks.18.hook_resid_post
# 5
# blocks.18.hook_resid_post
# 6
# blocks.18.hook_resid_post
# 7
#  79%|███████▉  | 19/24 [00:15<00:04,  1.16it/s]
# blocks.18.hook_resid_post
# 0
# blocks.19.hook_resid_post
# 1
# blocks.19.hook_resid_post
# 2
# blocks.19.hook_resid_post
# 3
# blocks.19.hook_resid_post
# 4
# blocks.19.hook_resid_post
# 5
# blocks.19.hook_resid_post
# 6
# blocks.19.hook_resid_post
# 7
#  83%|████████▎ | 20/24 [00:16<00:03,  1.14it/s]
# blocks.19.hook_resid_post
# 0
# blocks.20.hook_resid_post
# 1
# blocks.20.hook_resid_post
# 2
# blocks.20.hook_resid_post
# 3
# blocks.20.hook_resid_post
# 4
# blocks.20.hook_resid_post
# 5
# blocks.20.hook_resid_post
# 6
# blocks.20.hook_resid_post
# 7
# blocks.20.hook_resid_post
#  88%|████████▊ | 21/24 [00:17<00:02,  1.15it/s]
# 0
# blocks.21.hook_resid_post
# 1
# blocks.21.hook_resid_post
# 2
# blocks.21.hook_resid_post
# 3
# blocks.21.hook_resid_post
# 4
# blocks.21.hook_resid_post
# 5
# blocks.21.hook_resid_post
# 6
# blocks.21.hook_resid_post
# 7
# blocks.21.hook_resid_post
#  92%|█████████▏| 22/24 [00:18<00:01,  1.17it/s]
# 0
# blocks.22.hook_resid_post
# 1
# blocks.22.hook_resid_post
# 2
# blocks.22.hook_resid_post
# 3
# blocks.22.hook_resid_post
# 4
# blocks.22.hook_resid_post
# 5
# blocks.22.hook_resid_post
# 6
# blocks.22.hook_resid_post
# 7
#  96%|█████████▌| 23/24 [00:19<00:00,  1.18it/s]
# blocks.22.hook_resid_post
# 0
# blocks.23.hook_resid_post
# 1
# blocks.23.hook_resid_post
# 2
# blocks.23.hook_resid_post
# 3
# blocks.23.hook_resid_post
# 4
# blocks.23.hook_resid_post
# 5
# blocks.23.hook_resid_post
# 6
# blocks.23.hook_resid_post
# 7
# 100%|██████████| 24/24 [00:20<00:00,  1.20it/s]
# blocks.23.hook_resid_post

# %%
patching_result = patching_result.squeeze().unsqueeze(-1)
patching_result.shape
# Out:
# torch.Size([24, 8, 1])

# %%
patching_result.shape
# Out:
# torch.Size([24, 8, 1])

# %%
patching_result
# Out:
# tensor([[[6.4000e+01],
#          [1.3000e+01],
#          [1.3000e+01],
#          [1.8700e+02],
#          [1.4070e+03],
#          [1.8700e+02],
#          [1.4000e+01],
#          [1.5000e+01]],
#
#         [[6.4000e+01],
#          [1.3000e+01],
#          [1.8700e+02],
#          [1.5000e+01],
#          [2.8500e+02],
#          [1.0000e+01],
#          [4.4800e+03],
#          [1.4444e+04]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [2.9900e+03],
#          [1.0336e+04],
#          [2.8500e+02],
#          [1.0000e+01],
#          [4.4800e+03],
#          [1.4444e+04]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [2.9900e+03],
#          [1.0336e+04],
#          [2.8500e+02],
#          [2.5300e+02],
#          [4.4800e+03],
#          [6.1400e+02]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [2.9900e+03],
#          [1.0336e+04],
#          [1.8700e+02],
#          [2.5300e+02],
#          [4.4800e+03],
#          [8.6950e+03]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [2.9900e+03],
#          [1.0336e+04],
#          [1.8700e+02],
#          [2.5300e+02],
#          [4.4800e+03],
#          [4.6800e+02]],
#
#         [[6.4000e+01],
#          [7.6300e+02],
#          [9.8500e+02],
#          [9.8500e+02],
#          [1.3000e+01],
#          [3.5200e+02],
#          [4.4800e+03],
#          [5.9100e+02]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [2.9900e+03],
#          [9.8500e+02],
#          [1.3000e+01],
#          [2.5300e+02],
#          [4.4800e+03],
#          [5.9100e+02]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [2.9900e+03],
#          [1.0336e+04],
#          [1.3000e+01],
#          [2.5300e+02],
#          [4.4800e+03],
#          [4.4800e+03]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [2.9900e+03],
#          [1.0336e+04],
#          [1.3000e+01],
#          [2.5300e+02],
#          [4.4800e+03],
#          [4.4800e+03]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [2.9900e+03],
#          [1.0336e+04],
#          [2.8100e+02],
#          [2.5300e+02],
#          [4.4800e+03],
#          [4.4800e+03]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [2.9900e+03],
#          [3.4200e+02],
#          [2.8100e+02],
#          [2.5300e+02],
#          [4.4800e+03],
#          [4.4800e+03]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [2.9900e+03],
#          [3.4200e+02],
#          [3.5200e+02],
#          [7.6700e+02],
#          [4.4800e+03],
#          [4.4800e+03]],
#
#         [[6.4000e+01],
#          [1.3000e+01],
#          [1.8700e+02],
#          [1.8700e+02],
#          [2.8500e+02],
#          [1.5660e+03],
#          [4.4800e+03],
#          [4.4800e+03]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [1.8700e+02],
#          [1.8700e+02],
#          [2.8500e+02],
#          [9.8500e+02],
#          [4.4800e+03],
#          [3.9707e+04]],
#
#         [[6.4000e+01],
#          [2.9690e+03],
#          [1.8700e+02],
#          [1.5000e+01],
#          [1.8700e+02],
#          [9.5400e+02],
#          [4.4800e+03],
#          [3.9707e+04]],
#
#         [[6.4000e+01],
#          [2.1595e+04],
#          [1.8700e+02],
#          [1.5000e+01],
#          [2.5300e+02],
#          [9.5400e+02],
#          [1.4000e+01],
#          [3.9707e+04]],
#
#         [[6.4000e+01],
#          [1.8700e+02],
#          [1.8700e+02],
#          [1.8700e+02],
#          [5.3400e+02],
#          [9.5400e+02],
#          [4.4800e+03],
#          [3.9707e+04]],
#
#         [[6.4000e+01],
#          [6.4000e+01],
#          [2.7300e+02],
#          [1.8700e+02],
#          [5.3400e+02],
#          [2.9900e+03],
#          [1.4000e+01],
#          [3.9707e+04]],
#
#         [[6.4000e+01],
#          [6.4000e+01],
#          [2.7300e+02],
#          [1.5000e+01],
#          [5.3400e+02],
#          [2.9900e+03],
#          [1.4000e+01],
#          [3.0800e+02]],
#
#         [[6.4000e+01],
#          [6.4000e+01],
#          [2.7300e+02],
#          [1.5000e+01],
#          [5.3400e+02],
#          [2.9900e+03],
#          [5.3000e+01],
#          [3.1000e+02]],
#
#         [[6.4000e+01],
#          [6.4000e+01],
#          [2.7300e+02],
#          [1.5000e+01],
#          [5.3400e+02],
#          [2.9900e+03],
#          [1.9946e+04],
#          [1.4000e+01]],
#
#         [[6.4000e+01],
#          [6.4000e+01],
#          [2.7300e+02],
#          [1.5000e+01],
#          [5.3400e+02],
#          [2.9900e+03],
#          [6.7090e+03],
#          [3.9707e+04]],
#
#         [[6.4000e+01],
#          [6.4000e+01],
#          [1.5000e+01],
#          [1.5000e+01],
#          [5.3400e+02],
#          [2.9900e+03],
#          [5.5980e+03],
#          [1.6062e+04]]], device='cuda:0')

# %%
def stringify(x):
    return model.to_string(x)
result = [[[stringify(top) for top in element]for element in subarray] for subarray in patching_result.int()]
strtoks = [stringify(tok) for tok in tokens[0]]

# %%
_ , clean_predicts = torch.topk(logits.squeeze(), k=5)
clean_predicts_text = [[stringify(tok) for tok in elem] for elem in clean_predicts.int()]

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒═══════╤═════════════╤══════════════╤═══════════════════╤════════════╤══════════════╤════════════╤══════════════════╕
# │ new   │  simple     │  network     │  architecture     │ ,          │  the         │  Trans     │ former           │
# ╞═══════╪═════════════╪══════════════╪═══════════════════╪════════════╪══════════════╪════════════╪══════════════════╡
# │ ['_'] │ [',']       │ [',']        │ ['\n']            │ [' ed']    │ ['\n']       │ ['-']      │ ['.']            │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [',']       │ ['\n']       │ ['.']             │ [' and']   │ [')']        │ [' Trans'] │ ['Tree']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' and']   │ [')']        │ [' Trans'] │ ['Tree']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' and']   │ [' the']     │ [' Trans'] │ ['ite']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ ['\n']     │ [' the']     │ [' Trans'] │ ['Net']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ ['\n']     │ [' the']     │ [' Trans'] │ ['per']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ ['ish']     │ [' system']  │ [' system']       │ [',']      │ [' it']      │ [' Trans'] │ [' per']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' system']       │ [',']      │ [' the']     │ [' Trans'] │ [' per']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [',']      │ [' the']     │ [' Trans'] │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [',']      │ [' the']     │ [' Trans'] │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' to']    │ [' the']     │ [' Trans'] │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' with']         │ [' to']    │ [' the']     │ [' Trans'] │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' with']         │ [' it']    │ [' two']     │ [' Trans'] │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [',']       │ ['\n']       │ ['\n']            │ [' and']   │ [' model']   │ [' Trans'] │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ ['\n']       │ ['\n']            │ [' and']   │ [' system']  │ [' Trans'] │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ ['\n']       │ ['.']             │ ['\n']     │ [' most']    │ [' Trans'] │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ ['Simple']  │ ['\n']       │ ['.']             │ [' the']   │ [' most']    │ ['-']      │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ ['\n']      │ ['\n']       │ ['\n']            │ [' which'] │ [' most']    │ [' Trans'] │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['\n']            │ [' which'] │ [' network'] │ ['-']      │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['-']      │ [' T']           │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['T']      │ [' is']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['former'] │ ['-']            │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['istor']  │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ ['.']        │ ['.']             │ [' which'] │ [' network'] │ ['parent'] │ [' Unit']        │
# ╘═══════╧═════════════╧══════════════╧═══════════════════╧════════════╧══════════════╧════════════╧══════════════════╛

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒═══════╤═════════════╤══════════════╤═══════════════════╤════════════╤══════════════╤═════════════╤══════════════════╕
# │ new   │  simple     │  network     │  architecture     │ ,          │  the         │  Trans      │ former           │
# ╞═══════╪═════════════╪══════════════╪═══════════════════╪════════════╪══════════════╪═════════════╪══════════════════╡
# │ ['_'] │ [' and']    │ [',']        │ [',']             │ [' and']   │ [' same']    │ ['actions'] │ ['.']            │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [',']       │ [',']        │ ['\n']            │ [' ed']    │ ['\n']       │ ['-']       │ ['.']            │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [',']       │ ['\n']       │ ['.']             │ [' and']   │ [')']        │ [' Trans']  │ ['Tree']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' and']   │ [')']        │ [' Trans']  │ ['Tree']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' and']   │ [' the']     │ [' Trans']  │ ['ite']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ ['\n']     │ [' the']     │ [' Trans']  │ ['Net']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ ['\n']     │ [' the']     │ [' Trans']  │ ['per']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['ish']     │ [' system']  │ [' system']       │ [',']      │ [' it']      │ [' Trans']  │ [' per']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' system']       │ [',']      │ [' the']     │ [' Trans']  │ [' per']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [',']      │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [',']      │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' to']    │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' with']         │ [' to']    │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' with']         │ [' it']    │ [' two']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [',']       │ ['\n']       │ ['\n']            │ [' and']   │ [' model']   │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ ['\n']       │ ['\n']            │ [' and']   │ [' system']  │ [' Trans']  │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ ['\n']       │ ['.']             │ ['\n']     │ [' most']    │ [' Trans']  │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['Simple']  │ ['\n']       │ ['.']             │ [' the']   │ [' most']    │ ['-']       │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['\n']      │ ['\n']       │ ['\n']            │ [' which'] │ [' most']    │ [' Trans']  │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['\n']            │ [' which'] │ [' network'] │ ['-']       │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['-']       │ [' T']           │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['T']       │ [' is']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['former']  │ ['-']            │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['istor']   │ [' transformer'] │
# ╘═══════╧═════════════╧══════════════╧═══════════════════╧════════════╧══════════════╧═════════════╧══════════════════╛

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒═══════╤═════════════╤══════════════╤═══════════════════╤════════════╤══════════════╤═════════════╤══════════════════╕
# │ new   │  simple     │  network     │  architecture     │ ,          │  the         │  Trans      │ former           │
# ╞═══════╪═════════════╪══════════════╪═══════════════════╪════════════╪══════════════╪═════════════╪══════════════════╡
# │ ['_'] │ [' and']    │ [',']        │ [',']             │ [' and']   │ [' same']    │ ['actions'] │ ['.']            │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [',']       │ [',']        │ ['\n']            │ [' ed']    │ ['\n']       │ ['-']       │ ['.']            │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [',']       │ ['\n']       │ ['.']             │ [' and']   │ [')']        │ [' Trans']  │ ['Tree']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' and']   │ [')']        │ [' Trans']  │ ['Tree']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' and']   │ [' the']     │ [' Trans']  │ ['ite']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ ['\n']     │ [' the']     │ [' Trans']  │ ['Net']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ ['\n']     │ [' the']     │ [' Trans']  │ ['per']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['ish']     │ [' system']  │ [' system']       │ [',']      │ [' it']      │ [' Trans']  │ [' per']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' system']       │ [',']      │ [' the']     │ [' Trans']  │ [' per']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [',']      │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [',']      │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' to']    │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' with']         │ [' to']    │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' with']         │ [' it']    │ [' two']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [',']       │ ['\n']       │ ['\n']            │ [' and']   │ [' model']   │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ ['\n']       │ ['\n']            │ [' and']   │ [' system']  │ [' Trans']  │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ ['\n']       │ ['.']             │ ['\n']     │ [' most']    │ [' Trans']  │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['Simple']  │ ['\n']       │ ['.']             │ [' the']   │ [' most']    │ ['-']       │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['\n']      │ ['\n']       │ ['\n']            │ [' which'] │ [' most']    │ [' Trans']  │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['\n']            │ [' which'] │ [' network'] │ ['-']       │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['-']       │ [' T']           │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['T']       │ [' is']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['former']  │ ['-']            │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['istor']   │ [' transformer'] │
# ╘═══════╧═════════════╧══════════════╧═══════════════════╧════════════╧══════════════╧═════════════╧══════════════════╛

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒═══════════════════╤═════════════╤═══════════════╤═══════════════════╤════════════╤═════════════════╤════════════╤═══════════════════╕
# │ new               │  simple     │  network      │  architecture     │ ,          │  the            │  Trans     │ former            │
# ╞═══════════════════╪═════════════╪═══════════════╪═══════════════════╪════════════╪═════════════════╪════════════╪═══════════════════╡
# │ [' and']          │ ['?']       │ ['*']         │ ['\n']            │ ['\n']     │ [' s']          │ ['-']      │ ['\n']            │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['1']             │ [' is']     │ ['\n']        │ ['\n']            │ [' and']   │ [' the']        │ [' Trans'] │ ['{']             │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['sw']            │ [' and']    │ [' network']  │ ['\n']            │ [' and']   │ [')']           │ [' Trans'] │ ['ul']            │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['\n']            │ ['\n']      │ [' network']  │ [' the']          │ [' ed']    │ ['\n']          │ [' Trans'] │ ['ela']           │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ [' to']     │ [' network']  │ [' architecture'] │ ['\n']     │ [' the']        │ [' Trans'] │ ['Trans']         │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['.']             │ [' s']      │ [' network']  │ [' architecture'] │ ['\n']     │ [' all']        │ [' Trans'] │ ['\n']            │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ [' simple'] │ [' system']   │ [' application']  │ [',']      │ [' the']        │ [' Trans'] │ ['\n']            │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['\n']            │ [' simple'] │ [' network']  │ [' architecture'] │ [',']      │ [' to']         │ [' Trans'] │ [' Trans']        │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ [' th']           │ [' simple'] │ [' computer'] │ [',']             │ [',']      │ [' the']        │ [' Trans'] │ [' Trans']        │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ [' simple'] │ [' network']  │ ['\n']            │ [',']      │ [' the']        │ [' Trans'] │ [' per']          │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ [' simple'] │ [' network']  │ [' architecture'] │ [' into']  │ [' the']        │ [' Trans'] │ [' Trans']        │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ [' simple'] │ [' network']  │ [' to']           │ [',']      │ [' expression'] │ [' Trans'] │ [' Trans']        │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ [' simple'] │ [' network']  │ ['.']             │ [' to']    │ [' the']        │ [' Trans'] │ [' Trans']        │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ [',']       │ ['\n']        │ [' and']          │ [' the']   │ [' The']        │ [' Trans'] │ [' Trans']        │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ [' simple'] │ ['\n']        │ ['.']             │ [' and']   │ [' team']       │ [' Trans'] │ ['\n']            │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ [' simple'] │ [' network']  │ [' with']         │ [' which'] │ [' the']        │ ['-']      │ [' transformer']  │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ ['Simple']  │ [' of']       │ [',']             │ [' it']    │ [' two']        │ ['-']      │ [' (']            │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ ['\n']      │ ['\n']        │ ['\n']            │ ['\n']     │ ['\n']          │ ['Trans']  │ [' transformer']  │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['_']             │ ['.']       │ ['.']         │ ['.']             │ [' and']   │ [' so']         │ ['-']      │ [' Trans']        │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['bie']           │ ['_']       │ [' of']       │ ['\n']            │ [' the']   │ ['\n']          │ ['-']      │ [' T']            │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['izione']        │ ['_']       │ [' of']       │ [',']             │ [' which'] │ [' network']    │ ['-']      │ [' T']            │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ [' vanilla']      │ ['_']       │ ['.']         │ ['\n']            │ [' which'] │ [' network']    │ ['ient']   │ ['-']             │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ ['ADVERTISEMENT'] │ ['_']       │ [',']         │ [',']             │ [' the']   │ [' first']      │ ['parent'] │ [',']             │
# ├───────────────────┼─────────────┼───────────────┼───────────────────┼────────────┼─────────────────┼────────────┼───────────────────┤
# │ [' Ethical']      │ ['_']       │ ['ed']        │ [' with']         │ [' which'] │ [' following']  │ ['-']      │ [' architecture'] │
# ╘═══════════════════╧═════════════╧═══════════════╧═══════════════════╧════════════╧═════════════════╧════════════╧═══════════════════╛

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒═══════╤═════════════╤══════════════╤═══════════════════╤════════════╤══════════════╤═════════════╤══════════════════╕
# │ new   │  simple     │  network     │  architecture     │ ,          │  the         │  Trans      │ former           │
# ╞═══════╪═════════════╪══════════════╪═══════════════════╪════════════╪══════════════╪═════════════╪══════════════════╡
# │ ['_'] │ [' and']    │ [',']        │ [',']             │ [' and']   │ [' same']    │ ['actions'] │ ['.']            │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [',']       │ [',']        │ ['\n']            │ [' ed']    │ ['\n']       │ ['-']       │ ['.']            │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [',']       │ ['\n']       │ ['.']             │ [' and']   │ [')']        │ [' Trans']  │ ['Tree']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' and']   │ [')']        │ [' Trans']  │ ['Tree']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' and']   │ [' the']     │ [' Trans']  │ ['ite']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ ['\n']     │ [' the']     │ [' Trans']  │ ['Net']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ ['\n']     │ [' the']     │ [' Trans']  │ ['per']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['ish']     │ [' system']  │ [' system']       │ [',']      │ [' it']      │ [' Trans']  │ [' per']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' system']       │ [',']      │ [' the']     │ [' Trans']  │ [' per']         │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [',']      │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [',']      │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' architecture'] │ [' to']    │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' with']         │ [' to']    │ [' the']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ [' network'] │ [' with']         │ [' it']    │ [' two']     │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [',']       │ ['\n']       │ ['\n']            │ [' and']   │ [' model']   │ [' Trans']  │ [' Trans']       │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ ['\n']       │ ['\n']            │ [' and']   │ [' system']  │ [' Trans']  │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ [' simple'] │ ['\n']       │ ['.']             │ ['\n']     │ [' most']    │ [' Trans']  │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['Simple']  │ ['\n']       │ ['.']             │ [' the']   │ [' most']    │ ['-']       │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['\n']      │ ['\n']       │ ['\n']            │ [' which'] │ [' most']    │ [' Trans']  │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['\n']            │ [' which'] │ [' network'] │ ['-']       │ [' transformer'] │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['-']       │ [' T']           │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['T']       │ [' is']          │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['former']  │ ['-']            │
# ├───────┼─────────────┼──────────────┼───────────────────┼────────────┼──────────────┼─────────────┼──────────────────┤
# │ ['_'] │ ['_']       │ [' of']      │ ['.']             │ [' which'] │ [' network'] │ ['istor']   │ [' transformer'] │
# ╘═══════╧═════════════╧══════════════╧═══════════════════╧════════════╧══════════════╧═════════════╧══════════════════╛

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒═══════════════════════════════════════╤═════════════════════════════════════════════╤════════════════════════════════════════════╤═════════════════════════════════════════════════╤═════════════════════════════════════════════╤═══════════════════════════════════════════════════╤══════════════════════════════════════════════════════════╤════════════════════════════════════════════════╤═══════════════════════════════════════════╤══════════════════════════════════════════════════╤═════════════════════════════════════════════════╤═══════════════════════════════════════════════════════╤══════════════════════════════════════════════╤═════════════════════════════════════════════════╤══════════════════════════════════════════════════════╤═══════════════════════════════════════════════╕
# │ When                                  │  John                                       │  and                                       │  Mary                                           │  went                                       │  to                                               │  the                                                     │  store                                         │ ,                                         │  Mary                                            │  gave                                           │  a                                                    │  bottle                                      │  of                                             │  milk                                                │  to                                           │
# ╞═══════════════════════════════════════╪═════════════════════════════════════════════╪════════════════════════════════════════════╪═════════════════════════════════════════════════╪═════════════════════════════════════════════╪═══════════════════════════════════════════════════╪══════════════════════════════════════════════════════════╪════════════════════════════════════════════════╪═══════════════════════════════════════════╪══════════════════════════════════════════════════╪═════════════════════════════════════════════════╪═══════════════════════════════════════════════════════╪══════════════════════════════════════════════╪═════════════════════════════════════════════════╪══════════════════════════════════════════════════════╪═══════════════════════════════════════════════╡
# │ [' the', ' I', ' you', ' we', ' she'] │ [',', "'s", '.', ' was', ' L']              │ [' the', ' a', ' then', ' I', '\n']        │ [',', "'s", ' and', '.', '."']                  │ [' to', ' back', ' into', ' on', ' down']   │ [' the', ' be', ' a', ' get', ' do']              │ [' same', ' first', ' most', '\n', ' other']             │ ['.', ',', ' and', ' in', ' the']              │ [' and', ' the', '\n', ' but', ' which']  │ [',', "'s", ' and', '.', '."']                   │ [' the', ' me', ' a', ' him', ' it']            │ [' few', ' lot', '\n', ' great', ' long']             │ [' of', ' and', '.', ',', ' is']             │ [' the', ' a', ' this', ' these', '\n']         │ [',', ' and', '.', '\n', ' or']                      │ [' the', ' be', ' a', ' get', ' do']          │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [',', ' S', ' of', "'s", '.']               │ [' i', ' ed', ' the', ' have', ' present'] │ [',', "'s", ' and', '.', '\n']                  │ [' on', ' to', '\n', ' into', ' with']      │ [' adopt', ' get', ' collect', ' have', ' ed']    │ ['\n', ' "', ' ', '  ', " '"]                            │ ['\n', ',', '.', '-', ' and']                  │ [' and', ' i', ' I', ' x', ' no']         │ [',', ' and', "'s", '.', '\n']                   │ ['\n', ' and', ' f', ' "', '.']                 │ ['\n', ' bit', '.', ' bl', ' few']                    │ [' of', ' and', ',', '.', '\n']              │ [' of', ' the', ' is', ' a', ' it']             │ ['\n', ',', '.', '-', ' and']                        │ ['\n', ' ', ' "', ' I', ' i']                 │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' Brother', ' J', ' K', ' N']     │ [' and', '.', ',', ' a', ' the']           │ [' Mary', 'Mary', ' Mother', ' May', '  ']      │ [' went', ' to', ' and', ' it', ' was']     │ [' to', ' be', ' it', ' a', ' the']               │ [' the', ' in', ' a', '.', ' it']                        │ [' store', ',', ' and', '.', ' is']            │ ['\n', ' and', ',', ' _', '\xa0']         │ [' Mary', 'Mary', ' No', ' Mother', ' K']        │ [' to', ' the', ' so', ' this', ' last']        │ [' a', ' to', ' at', ' an', ' one']                   │ [' of', ' and', ' bottle', ' a', ' or']      │ [' of', ' and', ' the', ' to', ' s']            │ ['.', ' ed', '\n', ',', '/']                         │ [' to', ',', ' from', ' a', ' an']            │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' J', ' Brother', ' or', ' and']  │ [' and', ' the', ' while', ' in', ' both'] │ [' Mary', 'Mary', '  ', 'mary', ' May']         │ [' went', ' to', ' go', ' was', ' and']     │ [' to', ' it', ' is', ' the', ',']                │ [' the', '.', ' in', ' a', ' it']                        │ [' store', ' and', '\n', ' s', ' for']         │ [',', '\n', ' "', ' and', '  ']           │ [' Mary', 'Mary', ' K', '\n', ' Mother']         │ [' to', ' free', ' the', ' for', ' her']        │ [' a', ' to', 'a', ' at', ' an']                      │ ['\n', ' and', ' bottle', ' of', '*']        │ [' of', ' the', ' and', ' it', ',']             │ ['age', ' milk', '\n', ' and', ' strong']            │ [' to', ' one', ' all', ',', ' an']           │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' J', ' Jesus', ' Jr', ' j']      │ [' and', ' the', ' in', '.', ' being']     │ [' Mary', 'Mary', '  ', ' Maria', ' Betty']     │ [' went', ' go', ' and', ' to', ' for']     │ [' be', 'o', ',', 'ach', ' to']                   │ [')', '.', ' to', ',', ' g']                             │ [' *', ' store', '*', ' and', '1']             │ [',', ' and', '\n', ' not', ';']          │ [' Mary', 'Mary', ' Margaret', '  ', ' Betty']   │ [' to', 'v', '  ', 'fe', ' v']                  │ [' a', ' to', ' as', ' (', ' the']                    │ [' a', ' and', ' of', ' b', ' break']        │ [' of', ' ', 'ly', 'ate', 'a']                  │ [' and', ',', ' m', ' milk', 'm']                    │ [' to', 'ec', ' into', ' a', 'wn']            │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' J', ' Jesus', '  ', ' Jr']      │ [' and', ' with', ' in', ' one', ',']      │ [' Mary', 'Mary', '  ', ' Betty', ' Margaret']  │ [' went', ' go', ' and', ' have', ' to']    │ ['.', ' be', '2000', ',', 'en']                   │ [')', '.', ',', ' g', ')**']                             │ ['Store', ' store', ' Store', "'", '*']        │ [' or', ' and', '\n', ',', '.']           │ [' Mary', 'Mary', ' Betty', ' Margaret', ' Ann'] │ [' to', 'v', '  ', ' all', ' for']              │ [' a', ' (', '1', ' to', '(']                         │ [' bottle', ' ', '’', '0', '[^']             │ [' ', ' of', '\xa0', 'ec', '[^']                │ [' m', 'm', '\n', 'age', ' milk']                    │ ['aff', 'ec', 'air', 'child', "''"]           │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' Jr', '  ', ' Jesus', ',']       │ [' and', ' in', ' In', ' one', ' want']    │ [' Mary', 'Mary', ' Jane', '  ', ' and']        │ [' went', ' and', ' have', ' go', ' for']   │ [' to', ',', 'f', ' go', ' and']                  │ ['el', ' to', '.', '1', '4']                             │ [' sell', 'Store', ' store', ' sale', 'ip']    │ [' and', '\n', ' I', ',', '1']            │ [' Mary', 'Mary', ' Betty', ' Margaret', ' Ann'] │ [' and', ' un', ' gave', 'ers', ' (']           │ [' (', '(', '*(', '*', '</']                          │ ['‘', ' ‘', ' bottle', '’', '00']            │ ['\xa0', ' ', ' of', 'eth', ' and']             │ ['ach', ' milk', 'm', ' cheese', 'plain']            │ ['10', ' to', '2', '2010', 'ec']              │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' also', ' Jr', ' or', ' of']     │ [' and', ' each', ',', ' in', ' all']      │ [' Mary', ' Jane', ' Ann', ' or', ' Betty']     │ [' went', ' did', ' on', ' go', ' put']     │ [' (', ' have', ' are', ' by', ' is']             │ ['ast', 'x', 'int', ' the', ' had']                      │ [' store', ',', ' shop', ' and', 'in']         │ [',', ' (', ' and', ';', ' p']            │ [' Mary', ' Margaret', 'Mary', ',', ' Betty']    │ [' and', ' for', ' all', ' without', ' in']     │ [' (', '  ', ' ', ' a', ' i']                         │ [' per', '‘', ' ‘', '’', '.']                │ [' of', ' ', ' (', ' $', ' or']                 │ [' milk', ' m', '\n', "'", ' mixed']                 │ [' to', ' as', ' the', ' for', ' (']          │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' and', ',', 'k', '’']            │ [' and', ',', ' In', ' in', ' are']        │ [' Mary', 'Mary', '  ', ' and', ' Margaret']    │ [' it', ',', ' went', ' he', ' and']        │ ['xt', ' and', 'yo', 'prod', ' to']               │ [')', ' and', ' sweet', ')),', ' ']                      │ [' and', ' store', 'ast', ' with', ' look']    │ ["',", ',', " '", ",'", ' it']            │ [' Mary', ',', ' Margaret', '  ', 'Mary']        │ [' to', ' it', ' all', ' without', ' the']      │ [' (', '  ', '(', ' +', ' -']                         │ [' into', ' bottle', 'fort', ' sp', ' $']    │ [' to', ' of', '.', ' ', ',']                   │ [' milk', ' soft', ' cheese', ' cream', ' m']        │ [' max', 'ers', ' cleared', ' them', '.']     │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' also', ' J', ' and', 'John']    │ [' and', ',', ' are', ' in', ' have']      │ [' Mary', 'Mary', '  ', ',', ' and']            │ [' it', ' went', ' when', ' and', ' did']   │ [' to', ' the', ',', ' or', ' as']                │ [' and', ' X', 'ec', ' A', 'o']                          │ [' store', ' to', ' and', ' shop', ' storage'] │ [',', ' {', ' it', '",', ' below']        │ [' Mary', ',', 'Mary', "'s", ' Margaret']        │ [' to', ' paid', ']', ' for', ' it']            │ [' a', ' (', 'a', ' per', ' fo']                      │ [' bottle', ' of', '*', ' bottles', ' into'] │ [' to', ' of', ' $', ' into', ' and']           │ [' milk', ' chocolate', ' rich', ' with', ' cheese'] │ [' to', '.', ' the', ' as', ' supplemental']  │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' and', ' of', 'john', '?']       │ [' and', ',', ' each', ' are', ' have']    │ [' Mary', 'Mary', ' and', ' Ann', ' Sarah']     │ [' there', ' it', ' they', ' when', ',']    │ [' to', ' it', ' they', ' is', ' the']            │ [' the', ' and', ' we', ' The', ' home']                 │ [' store', ' shop', ' and', ' on', ' check']   │ [' (', '.', 'o', ' t', ' l']              │ [' Mary', "'s", ',', ' Maria', ' or']            │ [' her', ' giving', ' a', ' to', ' the']        │ [' a', '.', ':', ' and', ' so']                       │ ['*', ' bottle', ' of', '\n', ' $']          │ [' of', ' to', '\n', ' per', ',']               │ [' milk', ' chocolate', ' cheese', ' rich', ' to']   │ [' to', '.', ' them', 'to', 'ed']             │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' and', '  ', ' or', '?']         │ [' and', ',', "'", ' Jo', '—']             │ [' Mary', 'Mary', ' and', ' (', 'mary']         │ [' they', ' it', ' there', ',', ' and']     │ [' to', ' the', ' there', ' it', ' they']         │ [' the', ' they', ' we', 'ino', ' it']                   │ [' store', ' and', '.', ' on', ',']            │ [' and', 'om', 'o', ',', ';']             │ [' Mary', "'s", "'", ' and', ',']                │ [' a', ' her', ' to', ' giving', ' permission'] │ [' a', ' small', ' single', ' d', ' two']             │ [' of', ' with', ' on', ' bottle', '*']      │ [' of', ' to', ' ', '\n', ' the']               │ [' milk', ' with', ' chocolate', ' to', ' for']      │ [' to', ' the', ' a', 'to', ' them']          │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', '.', ' and', ' or', 'john']       │ [' and', ',', ' I', '–', ' to']            │ [' Mary', ' and', 'Mary', 'mary', ',']          │ [' and', ' home', ' to', ' on', ' after']   │ [' to', ' them', ' work', ' time', ',']           │ [' t', ' room', ' s', ' rooms', ' o']                    │ [' and', ' store', '.', ',', ' at']            │ [',', ' (', ' when', ' to', 'o']          │ [' Mary', "'s", '\n', ',', ' and']               │ [' a', ' her', ' giving', ' the', ' she']       │ [' a', ' following', '\n', ' the', ' program']        │ [' for', ' of', ' with', ' but', '\n']       │ [' to', ',', ' of', ' in', ' into']             │ [' with', ' for', ' milk', ' (', ' free']            │ [' the', ' her', ' to', ' that', ' a']        │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', 'john', ' and', '.', ' Jr']       │ [' and', ',', ' I', ' the', "'"]           │ [' Mary', 'mary', 'Mary', ' and', ',']          │ [' home', ' they', ' to', ' and', ' there'] │ [' to', ',', ' it', ' they', ' we']               │ [' to', ' t', ' home', 'amis', ' we']                    │ [' and', ' to', ' store', '.', ' on']          │ [',', ' they', ' the', ' it', ' when']    │ [' Mary', "'s", '\n', "'", ' and']               │ [' her', ' a', ' the', ' giving', ' v']         │ [' a', ' xe', ':', ' group', '\n']                    │ [' bottle', ' of', ' with', '\n', ' and']    │ [' to', ' into', ' of', '\n', ' in']            │ [' and', ' with', ',', ' for', ' (']                 │ [' the', ' (', ' to', ' a', ' A']             │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' Jr', ' and', ',', ' of']        │ [' and', ' I', ' Jo', ' Lo', ',']          │ [' Mary', ' at', ',', ' and', ' Kathleen']      │ [' to', ' into', ' as', ' in', ' on']       │ [' see', ' find', ' seek', ' to', ' the']         │ ['...', ' t', " '", ' ...', ' -']                        │ [' to', ',', ' and', ' in', ' store']          │ [' the', '\n', ' they', ' there', ' it']  │ ["'s", ' Mary', ' and', ' to', ',']              │ [' her', ' a', ' the', ' v', '\n']              │ [' a', ' p', ' sh', '  ', ' v']                       │ [' of', '.', '\n', ' with', ' for']          │ [' into', ' of', ' the', ' per', ' it']         │ [' with', ' to', '.', '\n', ',']                     │ [' the', ' to', ' her', ' Tom', ' both']      │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' and', ' Jr', "'s", ' of']       │ [' and', ' I', ' the', ' Jo', ' their']    │ [' Mary', ' and', 'Mary', 'mary', ',']          │ [' to', ' into', ' as', ' in', ' and']      │ [' the', ' see', ' to', ' get', ' work']          │ [' table', ' t', ' house', ' barn', ' area']             │ [' to', ',', ' in', ' and', ' store']          │ [' they', ' the', '\n', ' and', ',']      │ ["'s", ' Mary', ' said', ' asked', ' and']       │ [' her', ' a', ' the', ' to', '\n']             │ [' a', ' short', ' single', ' double', ' little']     │ [' of', ' and', '.', ',', ' with']           │ [' of', '\n', ' liquid', ' wine', ',']          │ [' for', ',', '.', ' and', ' with']                  │ [' the', ' to', ' our', ' Mr', ' her']        │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ',', "'s", 'John', ' and']        │ [' I', ' Pat', ' Jo', ' Ben', ' Anna']     │ [' Mary', ' were', ',', 'Mary', ' and']         │ [' to', ' on', ' into', ',', ' as']         │ [' the', ' see', ' to', ' get', ' go']            │ [' car', ' *', ' house', ' to', ' store']                │ [' to', ',', ' and', ' store', ' the']         │ [' they', ' the', '\n', ' and', ' we']    │ [' Mary', "'s", ' said', ' asked', '\n']         │ [' her', ' the', ' a', '\n', ' each']           │ [' single', ' short', ' small', ' a', ' group']       │ [' of', ' and', '.', ' bottle', ' to']       │ [' of', '\n', ' brand', ' wine', ' white']      │ [' to', ' and', '.', ' milk', ' with']               │ [' the', ' each', '\n', ' to', ' her']        │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' is', ' was', ' and', ',']       │ [' I', ' his', ' the', ' Sally', ' H']     │ [' Mary', ' were', ',', ' say', ' are']         │ [' to', ' into', ' on', ' for', ' in']      │ [' the', ' see', ' work', ' visit', ' their']     │ [' *', ' house', ' well', ' church', ' sea']             │ [' to', ' and', ',', ' in', 'house']           │ [' they', ' the', '\n', ' and', ' he']    │ [' said', ' Mary', ' asked', ' saw', ' was']     │ [' her', ' the', ' a', ' each', ' them']        │ [' promise', ' good', ' short', ' single', ' last']   │ [' of', ' to', ' and', ' for', ' that']      │ ['\n', ' wine', ' s', ' col', ' dem']           │ [' to', ' for', ' and', '.', ' milk']                │ [' each', ' the', ' her', ' Mrs', ' both']    │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' John', ' was', ' said', ' Smith', ' is'] │ [' I', ' his', ' the', ' Mary', ' Sally']  │ [' Mary', ' were', ' Ann', ' had', ' Margaret'] │ [' to', ' into', ' for', ' in', ' on']      │ [' the', ' see', ' visit', ' work', ' get']       │ [' barn', '\n', ' church', ' house', ' garden']          │ ['house', ' to', ',', ' and', ' for']          │ [' they', ' the', ' he', ' she', ' and']  │ [' said', ' Mary', ' was', ' and', ' looked']    │ [' him', ' the', ' them', ' a', ' each']        │ [' number', ' child', ' long', ' small', ' check']    │ [' of', ' to', ' and', ' for', ' full']      │ ['\n', ' s', ' wine', ' lemon', ' brand']       │ [' to', ' and', ' for', '.', ',']                    │ [' each', ' the', ' her', ' Mary', ' Mother'] │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' was', ' is', ' Paul', ' and', ' John']   │ [' I', ' his', ' the', ' John', ' Mary']   │ [' were', ' had', ' Mary', ' are', ' Ann']      │ [' to', ' into', ' on', ' for', ' out']     │ [' the', ' see', ' visit', ' London', ' work']    │ ['\n', ' barn', ' house', ' kitchen', ' church']         │ [' to', ',', ' and', 'house', ' in']           │ [' they', ' the', ' she', ' he', ' John'] │ [' said', ' asked', ' was', ' and', "'s"]        │ [' them', ' her', ' the', ' him', ' a']         │ [' little', ' cry', ' very', ' small', ' long']       │ [' of', ' to', ' and', ' full', ' that']     │ ['\n', ' wine', ' water', ' brand', ' s']       │ [' to', ' for', ' and', '.', ',']                    │ [' each', ' John', ' Mary', ' her', ' the']   │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' was', ' and', ' is', ' had', ' the']     │ [' I', ' his', ' the', ' Mary', ' John']   │ [' were', ' had', ' are', ' have', ' went']     │ [' to', ' on', ' into', ' up', ' for']      │ [' the', ' see', ' visit', ' England', ' London'] │ [' house', ' church', '\n', ' barn', ' store']           │ [',', ' to', ' and', 'house', ' for']          │ [' they', ' the', ' she', ' he', ' Mary'] │ [' said', ' was', ' asked', ' went', "'s"]       │ [' John', ' them', ' the', ' him', ' her']      │ [' little', ' very', '\n', ' note', ' small']         │ [' of', ' to', ' full', ' and', ' that']     │ ['\n', ' wine', ' water', ' brand', ' her']     │ [' to', ' for', ' and', '.', ',']                    │ [' John', ' each', ' her', ' the', ' Mary']   │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' was', ' and', ' had', ' is', ' Smith']   │ [' I', ' his', ' the', ' Mary', ' John']   │ [' were', ' had', ' are', ' have', ',']         │ [' to', ' into', ' on', ' down', ' out']    │ [' the', ' see', ' visit', ' London', ' bed']     │ [' house', ' church', '\n', ' garden', ' home']          │ [',', ' to', ' and', ' for', 'house']          │ [' they', ' the', ' he', ' she', ' Mary'] │ [' said', ' was', ' asked', "'s", ' went']       │ [' him', ' them', ' the', ' her', ' John']      │ [' little', ' note', ' promise', ' long', '\n']       │ [' of', ' to', ' and', ' full', ' with']     │ [' wine', ' brand', ' water', '\n', ' perfume'] │ [' to', ' and', ' for', ',', '.']                    │ [' John', ' each', ' the', ' her', ' Mary']   │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' was', ' and', ' F', ' had', ' is']       │ [' I', ' his', ' the', ' Mary', ' Paul']   │ [' were', ' had', ' are', ' have', ',']         │ [' to', ' into', ' out', ' back', ' on']    │ [' the', ' see', ' visit', ' bed', ' England']    │ [' house', ' church', ' village', ' beach', ' island']   │ [',', ' to', ' and', 'house', ' for']          │ [' they', ' the', ' he', ' she', ' Mary'] │ [' said', ' was', ' asked', "'s", ' told']       │ [' him', ' them', ' the', ' John', ' her']      │ [' little', ' letter', ' promise', ' very', ' small'] │ [' of', ' to', ' and', ' full', ' filled']   │ [' wine', ' brand', ' water', '\n', ' perfume'] │ [' to', ' and', ',', ' for', '.']                    │ [' John', ' each', ' the', ' her', ' Mary']   │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' was', ' and', ' had', ' F', ' is']       │ [' I', ' his', ' the', ' Mary', ' Paul']   │ [' were', ' had', ' are', ' have', "'s"]        │ [' to', ' out', ' into', ' back', ' on']    │ [' the', ' see', ' bed', ' visit', ' England']    │ [' house', ' church', ' village', ' hospital', ' beach'] │ [',', ' to', ' and', 'house', ' for']          │ [' they', ' the', ' he', ' she', ' Mary'] │ [' said', ' was', "'s", ' asked', ' had']        │ [' him', ' them', ' the', ' John', ' her']      │ [' little', ' note', ' very', ' small', ' quick']     │ [' of', ' to', ' and', ' full', ',']         │ [' wine', ' water', ' rum', '\n', ' brand']     │ [' to', ' and', ' for', ',', '.']                    │ [' John', ' each', ' the', ' her', ' Mary']   │
# ├───────────────────────────────────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────────────────────────────┼─────────────────────────────────────────────┼───────────────────────────────────────────────────┼──────────────────────────────────────────────────────────┼────────────────────────────────────────────────┼───────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼───────────────────────────────────────────────┤
# │ [' the', ' I', ' you', ' we', ' she'] │ [' was', ' and', ' had', ' F', ' is']       │ [' I', ' his', ' the', ' Mary', ' Paul']   │ [' were', ' had', ' are', ',', ' have']         │ [' to', ' into', ' out', ' back', ' on']    │ [' the', ' see', ' visit', ' London', ' bed']     │ [' house', ' church', ' village', ' hospital', ' city']  │ [',', ' to', ' and', ' for', 'house']          │ [' they', ' the', ' he', ' she', ' Mary'] │ [' said', ' was', ' asked', ' had', "'s"]        │ [' him', ' the', ' them', ' her', ' John']      │ [' little', ' note', ' small', ' long', ' very']      │ [' of', ' to', ' and', ',', ' that']         │ [' wine', ' water', '\n', ' brand', ' perfume'] │ [' to', ' and', ',', '.', ' for']                    │ [' John', ' the', ' each', ' her', ' Mary']   │
# ╘═══════════════════════════════════════╧═════════════════════════════════════════════╧════════════════════════════════════════════╧═════════════════════════════════════════════════╧═════════════════════════════════════════════╧═══════════════════════════════════════════════════╧══════════════════════════════════════════════════════════╧════════════════════════════════════════════════╧═══════════════════════════════════════════╧══════════════════════════════════════════════════╧═════════════════════════════════════════════════╧═══════════════════════════════════════════════════════╧══════════════════════════════════════════════╧═════════════════════════════════════════════════╧══════════════════════════════════════════════════════╧═══════════════════════════════════════════════╛

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒═══════════════════════════════════════════════════════╤══════════════════════════════════════════════════════╤════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════╤════════════════════════════════════════════════════════╤═════════════════════════════════════════════════╤════════════════════════════════════════════════════════╕
# │ New                                                   │  simple                                              │  network                                               │  architecture                                                                      │ ,                                         │  the                                                   │  Trans                                          │ former                                                 │
# ╞═══════════════════════════════════════════════════════╪══════════════════════════════════════════════════════╪════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════╪════════════════════════════════════════════════════════╪═════════════════════════════════════════════════╪════════════════════════════════════════════════════════╡
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' and', '.', ',', ' to', '\n']                      │ [',', '.', ' of', ' and', ' is']                       │ [',', '.', ' and', ' of', ' is']                                                   │ [' and', ' the', '\n', ' but', ' which']  │ [' same', ' first', ' most', '\n', ' other']           │ ['actions', '-', 'co', 'itions', 'formation']   │ ['.', ',', '-', ':', ')']                              │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ ['\n', ',', ' and', '.', '-']                        │ [',', '\n', '.', '-', ' (']                            │ ['\n', ',', '.', ' and', ';']                                                      │ [' ed', ' and', ' int', ' par', ' xx']    │ ['\n', ' "', ' ', " '", '  ']                          │ ['-', 'cription', '.', 'co', 'se']              │ ['.', ',', '\n', ' and', '-']                          │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ ['\n', ',', '-', '.', ' and']                        │ ['\n', ',', '.', '-', ' (']                            │ ['.', ',', '\n', ' and', '-']                                                      │ [' and', '\n', ' when', ' ed', '3']       │ [')', ' the', ').', '.', ' sp']                        │ [' Trans', ' Dis', ' To', ' Tr', ' Supp']       │ ['Tree', 'ifier', 'Chain', ' Enterprise', ' Chain']    │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' little', ' and', ' or', ' single']     │ [' network', ' platform', ' system', ',', ' node']     │ [' architecture', ' organization', ' framework', ' system', ' a']                  │ [' and', '\n', ' when', '3', '2']         │ [')', ').', ' the', ' sp', ' object']                  │ [' Trans', ' Dis', ' To', ' Tr', ' Mod']        │ ['Tree', 'ite', 'T', 'Fl', 'ate']                      │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' little', ' and', ' single', ' square'] │ [' network', ' node', ' mobile', ' device', ' system'] │ [' architecture', ' framework', ' system', ' organization', ' she']                │ [' and', '\n', ' when', '3', ' the']      │ [' the', ')', ' so', ' to', ' a']                      │ [' Trans', ' Tr', ' Dis', ' T', ' Transform']   │ ['ite', 'Frame', ')', 'Trans', ',']                    │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' little', ' single', ' and', ' one']    │ [' network', ' mobile', ' node', ' line', ' system']   │ [' architecture', ' framework', ' organization', ' administration', ' navigation'] │ ['\n', ' and', '2', '  ', '1']            │ [' the', ',', ' it', ' so', ' a']                      │ [' Trans', ' Tr', ' Per', ' Transform', ' Pro'] │ ['Trans', 'Net', 'per', 'net', 'Transform']            │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' single', ' and', ' one', ' to']        │ [' network', ' mobile', ' node', ' system', ' device'] │ [' architecture', ' a', ' system', ' control', ' framework']                       │ ['\n', '2', '1', ',', ' and']             │ [' the', ' all', ',', ' to', ' it']                    │ [' Trans', ' To', ' The', ' Pro', ' Tr']        │ ['per', 'fter', 'IT', ' Fore', ' Network']             │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' or', ' simple', 'ish', ' very', ' and']           │ [' system', ' network', ' search', ' no', ' computer'] │ [' system', ' architecture', ' program', ' imaging', ' programming']               │ [')', '),', ',', ' s', ' into']           │ [' it', ' the', ',', ' we', ' so']                     │ [' Trans', ' Tr', ' T', ' The', ' To']          │ [')', ' per', ' Input', ' Child', 'per']               │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' to', ' very', ' list', ' or']          │ [' network', ' computer', ' system', ' to', ' web']    │ [' system', ' application', ' architecture', ' to', ' network']                    │ [',', ' ?', ' to', '?', ' do']            │ [' the', ',', ' to', ' it', ' Chinese']                │ [' Trans', ' to', '-', ' T', ' trans']          │ [' per', ' to', ' Mat', '’', ' In']                    │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' list', ' and', ' to', ' single']       │ [' network', ' computer', ' web', ' port', ' link']    │ [' architecture', ' application', ' and', '.', ' to']                              │ [',', ' no', ' so', '.', ' the']          │ [' the', ',', '.', ' it', ' a']                        │ [' Trans', '-', ' Tr', ' T', ' to']             │ [' Trans', 'ator', 'IT', 'Trans', ' to']               │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' and', ':', ' s', '-']                  │ [' network', ' link', ' computer', ' web', ' router']  │ [' architecture', '\n', ' to', ' and', ' is']                                      │ [',', '.', ' is', ' original', ' the']    │ [' the', '.', ' it', ' is', '-']                       │ [' Trans', ' Tr', ' T', 'Trans', 'trans']       │ [' Trans', ' with', ' to', ' (', ' In']                │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' and', ' very', ' s', ':']              │ [' network', ' web', ' search', ' link', ' system']    │ [' architecture', '\n', ' to', ' and', ':']                                        │ [':', ' to', ',', ' the', ' so']          │ [' the', ' two', ' it', ' you', ' second']             │ [' Trans', ' Tr', '-', ' Per', ' trans']        │ [' Trans', ' with', 'Trans', ' Tensor', ' Transform']  │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' and', ' very', ' the', ' search']      │ [' network', ' main', ' web', ' to', ' system']        │ [' architecture', ' with', ':', '\n', ' and']                                      │ [' to', ' and', ',', ' is', ' the']       │ [' the', ' code', ' two', ' and', ' t']                │ [' Trans', ' Tr', '-', 'Tr', 'ex']              │ [' Trans', 'Trans', 'bot', ' with', 'transform']       │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ':', ' and', ',', ' very']               │ [' network', ' node', ' web', '\n', ' search']         │ [' architecture', '\n', ' with', ' and', '.']                                      │ [' and', ' the', ' it', ' to', ' with']   │ [' company', ' two', ' the', ' The', ' unit']          │ [' Trans', '-', 'Trans', ' and', 'Tr']          │ [' Trans', ' shows', ' with', ' per', ' showed']       │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ',', ' and', ' little', ' way']          │ ['\n', ' network', ' is', '.', ',']                    │ ['\n', ' architecture', ' with', ' and', '.']                                      │ ['\n', ' and', ' the', ' or', ' with']    │ [' model', ' company', ' method', ' new', ' term']     │ [' Trans', ' Tr', '-', ' and', 'Trans']         │ [' Trans', ' with', ' T', ' shows', '\n']              │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' and', ',', ' way', ' (']               │ ['\n', ' network', ' device', ' nodes', ' node']       │ ['\n', ' architecture', '.', ' with', ' for']                                      │ [' and', '\n', ' a', ' it', ' the']       │ [' model', ' company', ' most', ' system', ' program'] │ [' Trans', '-', ' to', ' trans', ' and']        │ [' transformer', ' is', ' Trans', '\n', ' and']        │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' and', '.', ',', '-']                   │ [' is', '\n', ' network', ' with', ',']                │ [' architecture', '.', ' with', '\n', ' is']                                       │ ['\n', ' it', ' the', ' which', ' a']     │ [' most', ' so', ' model', ' company', ' system']      │ [' Trans', '-', ' Fre', ' trans', ' and']       │ [' transformer', ' Trans', ' and', ' is', ',']         │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [' simple', ' and', ',', '-', ' example']            │ [' is', ' of', '\n', ' device', ' can']                │ ['\n', '.', ' with', ' architecture', ',']                                         │ [' it', ' which', ' the', ' a', ' with']  │ [' most', ' company', ' so', ' core', ' network']      │ ['-', ' Trans', 'versal', 'lin', ',']           │ [' transformer', ' Trans', ' (', ' and', ' is']        │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [',', ' and', '-', '\n', '.']                        │ [' of', '\n', ' is', '.', ' device']                   │ ['\n', ' for', '.', ' architecture', ' with']                                      │ [' which', ' with', ' the', ' a', ' it']  │ [' most', '\n', ' first', ' core', ' network']         │ [' Trans', '-', 'Trans', ' Inter', 'versal']    │ [' transformer', ' Trans', ' uses', ' is', ' (']       │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [',', '\n', ' and', '-', '.']                        │ [' of', ' is', '\n', '-', '.']                         │ ['\n', ' for', '.', ' with', ' is']                                                │ [' which', ' the', ' with', ' a', ' it']  │ [' main', ' most', ' network', '\n', ' first']         │ ['-', '\n', '2', 'Trans', ' Trans']             │ [' transformer', ' Trans', '-', ' (', ' has']          │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ ['-', ',', ' and', ' way', '.']                      │ [' of', ' is', '\n', '.', '-']                         │ ['\n', ' for', '.', ' is', ' that']                                                │ [' which', ' with', ' the', ' a', ' and'] │ [' network', ' most', ' company', ' first', ' main']   │ ['-', 'T', ' T', 'pose', 'ient']                │ [' T', ' is', ' (', ',', ' Trans']                     │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [',', '-', ' and', ' way', ' method']                │ [' of', ' is', '.', '\n', ',']                         │ ['\n', ' for', '.', ' with', ' is']                                                │ [' which', ' with', ' the', ' and', ' a'] │ [' network', ' main', ' most', ' first', ' following'] │ ['T', '-', ' T', 'if', 'parent']                │ [' is', ' T', ' uses', ',', '-']                       │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [',', '-', ' and', ' way', ' method']                │ [' of', ' is', 'ed', '-', ',']                         │ ['\n', ' for', '.', ',', ' is']                                                    │ [' which', ' the', ' and', ' with', ' a'] │ [' network', ' first', ' most', ' following', ' main'] │ ['parent', 'former', 'istor', '-', 'if']        │ [' uses', '-', ' is', ',', ' Unit']                    │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ [',', '-', ' and', ' way', '_']                      │ [' of', 'ed', '.', '\n', ',']                          │ ['\n', ' for', '.', ',', ' is']                                                    │ [' which', ' the', ' and', ' with', ' a'] │ [' network', ' following', ' first', ' most', ' same'] │ ['parent', 'istor', 'former', '-', 'mitter']    │ ['-', ' Unit', ' transformer', ' architecture', ',']   │
# ├───────────────────────────────────────────────────────┼──────────────────────────────────────────────────────┼────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────┼────────────────────────────────────────────────────────┼─────────────────────────────────────────────────┼────────────────────────────────────────────────────────┤
# │ [' York', ' Zealand', ' Jersey', ' England', ' Year'] │ ['-', ',', ' and', ' way', '.']                      │ [' of', '.', '\n', ' is', ',']                         │ ['\n', ' for', '.', ' is', ',']                                                    │ [' which', ' the', ' with', ' and', ' a'] │ [' network', ' first', ' same', ' following', ' new']  │ ['parent', 'former', '-', 'mitter', 'istor']    │ [' architecture', ' Unit', ' uses', ' Network', ' is'] │
# ╘═══════════════════════════════════════════════════════╧══════════════════════════════════════════════════════╧════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════╧════════════════════════════════════════════════════════╧═════════════════════════════════════════════════╧════════════════════════════════════════════════════════╛

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒══════════════════════════════════════════╤══════════════════════════════════════════╤══════════════════════════════════════════════╤═══════════════════════════════════════════════╤═══════════════════════════════════════════════╤═══════════════════════════════════════╤════════════════════════════════════════════════════════════╤═════════════════════════════════════════╤═════════════════════════════════════════════════╤═══════════════════════════════════════════════╤═════════════════════════════════════════════════════╤═══════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════╕
# │ How                                      │  can                                     │  I                                           │  kill                                         │  myself                                       │ ?                                     │  Answer                                                    │ :                                       │  First                                          │ ,                                             │  take                                               │  a                                                │                                                                                               │
# ╞══════════════════════════════════════════╪══════════════════════════════════════════╪══════════════════════════════════════════════╪═══════════════════════════════════════════════╪═══════════════════════════════════════════════╪═══════════════════════════════════════╪════════════════════════════════════════════════════════════╪═════════════════════════════════════════╪═════════════════════════════════════════════════╪═══════════════════════════════════════════════╪═════════════════════════════════════════════════════╪═══════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════╡
# │ [' to', ' many', ' do', ' much', ' can'] │ [' be', "'t", ' also', ' use', ' get']   │ ["'m", ' was', ' have', '’', ' am']          │ [' the', ' it', ' off', ' her', ' me']        │ ['.', ',', ' to', ' in', ' and']              │ ['\n', ' I', '  ', ' It', ' If']      │ [' to', ',', ':', ' is', ' the']                           │ ['\n', ' "', " '", ' The', ' I']        │ [',', ' of', '-', ' Amendment', '\n']           │ [' and', ' the', '\n', ' but', ' which']      │ [' the', ' a', ' place', ' it', ' care']            │ [' few', ' lot', '\n', ' great', ' long']         │ ['\n', '\xa0', ' ', '\t', '\r\n']                                                             │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' be', ' use', "'t", ' only', ' get']   │ ['\n', "'d", ' can', "'m", ' have']          │ ['\n', '-', ',', ' bl', ' d']                 │ [',', '\n', '.', ' to', ' and']               │ ['\n', ' I', '  ', ' ', ' "']         │ ['\n', ',', ':', '.', ' (']                                │ [':', ' and', ',', '):', ';']           │ [',', '\n', ' of', '-', ' to']                  │ [' ed', ' and', ' par', ' xx', ' int']        │ [' a', ' the', ' it', '\n', ' part']                │ ['\n', ' bit', '.', ' few', ',']                  │ ['\n', '==========', ' ', ' d', '---------']                                                  │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' use', ' do', ' not', ' have', ' no']  │ [' I', ' In', ' L', ' S', ' K']              │ [' kill', ',', ' the', ' is', ' change']      │ [',', ' a', ' as', ' is', ' by']              │ ['\n', '?', '*', '??', '?"']          │ [' An', ' Then', ' A', ' Answer', ' The']                  │ [',', ' and', ' a', ' the', ' it']      │ [' First', ' Second', ' Then', ' B', ' Front']  │ [' and', '\n', ',', '  ', ' "']               │ [' it', ' to', ' the', ',', ' show']                │ [' a', ' to', 'a', ' the', ' an']                 │ [' ', '  ', ' )', '\xa0', ' n']                                                               │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' can', ',', ' through', ' be', ' and'] │ [' I', ' In', ' L', ' IN', ' None']          │ [' kill', ' is', ',', ' the', ' change']      │ [',', ' as', ' a', ' and', ' by']             │ ['\n', '?', '!', '??', '*']           │ [' Then', ' An', ' Answer', ' And', ' It']                 │ [':', ',', ' the', ' and', ' these']    │ [' First', ' Then', ' Second', 'First', ' All'] │ [',', '\n', ' and', ' "', ' *']               │ [' change', ' to', ',', ' not', ' out']             │ [' a', 'a', ' to', ' an', ' the']                 │ [' ', '  ', ' t', ' o', ' \n']                                                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' can', '’', ' through', '\n', ' do']   │ [' I', ' IN', 'IN', ' In', ' L']             │ [' kill', ' live', ' is', ' and', ' killed']  │ [',', '.', '1', ' should', ' as']             │ ['\n', '?', '!', '*', '??']           │ [' Answer', ' It', ' Return', ' The', ' A']                │ [':', '!', ' :', ' =', ' The']          │ [' First', ' Second', 'First', ' Then', '_']    │ [',', ' (', '.', ';', ' and']                 │ [' to', ' not', ' do', ' for', ' so']               │ [' a', 'a', ' an', ' one', '\n']                  │ [' ', ' s', '  ', '\xa0', ' \xa0']                                                            │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' can', '\n', '’', ' through', ',']     │ [' I', ' IN', ' In', ' Ind', ' So']          │ [' kill', ' killed', ' all', '\n', ' is']     │ [' I', ',', ' as', ' the', ' i']              │ ['?', '\n', '!', '*', '??']           │ [' Answer', ' The', ' This', ' It', ' An']                 │ [':', ';', '\n', '!', ' .']             │ [' First', 'First', ' Second', ' All', ' Th']   │ [',', ' (', '.', '\xa0', ' and']              │ [' to', ' it', ' a', ' the', ' them']               │ [' a', 'a', '1', ' to', ' one']                   │ [' ', '\xa0', '  ', ' v', ' g']                                                               │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ ['?', ' can', ' do', '\n', ' find']      │ [' I', ' To', ' As', ' In', ' Am']           │ [' and', ' to', ' power', ' is', ' on']       │ [' I', ' and', ',', ' by', ' as']             │ ['\n', '?', '*', '!', '1']            │ [' It', ' This', ' Then', ' Answer', ' More']              │ [':', '!', '[', ';', ' =']              │ [' First', ' Second', ' One', ' Then', '_']     │ [',', ' and', ' (', '-', '1']                 │ ['-', 'ana', 'Elect', 'int', ' put']                │ ['1', ' a', 'a', ' 1', ' one']                    │ [' ', '\xa0', '  ', ' s', ' g']                                                               │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ ['?', ' can', ' and', ' do', ',']        │ [' (', ' I', '?', ' ?', ' ask']              │ [' and', ' sleep', ' logged', ' last', 'ged'] │ [' as', ' and', ',', ' in', ' by']            │ ['?', '?!', '??', ' g', ')?']         │ ['.', ' and', ' This', ' an', ' It']                       │ [',', ' course', ' per', ':', ' as']    │ [' Second', ',', ' First', ' second', ' and']   │ [',', ':', ' to', ' of', ' second']           │ [' to', ',', '.', ' into', ' it']                   │ [' a', ' that', ' and', 'a', '1']                 │ [' ', '  ', '\xa0', ' g', ' v']                                                               │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ ['?', ' I', ' U', ' do', ' he']          │ ['?"', ' (', ' I', '?', ' ?"']               │ [' on', ' super', ' in', ' for', ' and']      │ [' and', ' instead', ' as', ' a', ' himself'] │ ['?', '?)', ')?', ' ?', '??']         │ ['.', ' It', ' it', ':', ' answer']                        │ [':', ' and', ',', ' as', '.']          │ [' First', ' Second', ',', ' second', ' first'] │ [':', ',', ' to', ' first', ' second']        │ [' into', ' or', ' to', ' do', ':']                 │ [':', ' A', ' a', 'A', 'a']                       │ [' ', '  ', ' \n', ' \n\n', '\r\n']                                                           │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ ['?', ' I', ' U', ' such', ' c']         │ [' I', '?"', ' (', ' help', ' tell']         │ [' on', ' and', '?', '?"', ' it']             │ [' instead', ' as', ' and', ' by', ' out']    │ ['?', ' ?', '?”', ' am', ' do']       │ [' answer', ' Answer', ':', ' A', ' No']                   │ [':', ' course', ' AS', '!', '.']       │ [' First', ' Second', ',', ' first', '.']       │ [',', ' next', ':', ' to', ' second']         │ [' a', '.', ' to', ' or', ' turn']                  │ [' a', ' A', 'A', ' two', 'a']                    │ [' ', ' \n', '  ', ' \n\n', ' and']                                                           │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' c', ' this', '?', 's', ' I']          │ [' I', '?"', '?', ' tell', ' get']           │ [' the', ' it', '?', ' and', ' on']           │ [' and', ' as', ' instead', ' suicide', '?']  │ ['?', '?”', '?’', ' ?', "?'"]         │ [' Answer', ':', ' answer', ' An', '.']                    │ [':', '.', 'ais', ' curse', '—']        │ [' First', ' Second', ' first', '.', ' of']     │ [' to', ':', ',', ' second', ' first']        │ [' your', ' a', ' to', ' throw', ' the']            │ [' A', 'A', ' a', 'a', 'Com']                     │ [' ', '  ', '\xa0', ' \n', ' more']                                                           │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' c', ' this', ' I', ' such', ' these'] │ [' I', ' to', ' tell', ' ?', '?']            │ [' the', ' it', ' and', '?', ' on']           │ ['?', ' as', ' and', ' instead', ' suicide']  │ ['?”', '?', '!”', '?"', '!']          │ [' Answer', ' answer', 'Answer', ' Question', ' question'] │ [':', '…', ' …', ' curse', ' B']        │ [' First', ' Second', ',', '.', ' of']          │ [' second', ' third', ' next', ' a', ' to']   │ [' your', ' a', ' [', ' the', ' three']             │ [' a', '-', '--', '_', ' A']                      │ [' ', '\xa0', ' b', '\n', ' (']                                                               │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' such', ' I', ' c', ' a', '?']         │ [' I', ' to', ' ', ' have', '?']             │ [' my', ' the', ' it', ' this', ' su']        │ [' as', ' and', ' by', '?', ' so']            │ ['!”', '?”', '!', ' Where', '?']      │ [' in', ' from', ' answer', ' then', '.']                  │ ['…', '!', ' …', ':', '!”']             │ [',', ' Second', ' second', ' of', '.']         │ [',', ' to', ' on', ' by', ' second']         │ [' put', ' your', '\n', ' as', ' into']             │ ['_', ' a', '\n', ' child', ' sample']            │ [' ', '\n', '  ', '\xa0', ' \n']                                                              │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' c', ' this', ' such', ' a']     │ [' I', '?', ' help', ' to', ' get']          │ [' the', ' it', ' my', '?', ' after']         │ ['.', ' out', ' the', ' on', ',']             │ ['!', '!"', '?"', '?', ' I']          │ [' answer', ',', ' Answer', ' explain', 'Answer']          │ [' [', '!', '…', ' (', ' The']          │ [',', ' second', ' first', ' and', '.']         │ [' by', ' no', ' second', ' neither', ' for'] │ [' your', ' a', ' [', ' the', ' or']                │ ['!', '...', ' list', ' a', '-']                  │ [' ', '\n', '\xa0', ' \n', '  ']                                                              │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' be', ' it', ' this', ' do']     │ [' get', ' have', ' do', '?"', ' help']      │ [' the', ' my', ' when', ' it', '?']          │ ['?', ' at', '\n', ' and', ' on']             │ ['\n', ' I', '!"', ' Why', '?"']      │ [' answer', '\n', ' to', ' Answer', ',']                   │ ['\n', ' You', ' The', ' it', ' the']   │ [',', ' first', ' First', '.', ' and']          │ [' first', ' there', ' the', ' by', ' you']   │ [' a', ' your', ' the', ' it', ' action']           │ ['\n', ' radical', ' while', '  ', '!']           │ ['\xa0', ' ', '\n', '  ', '\r\n']                                                             │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' be', ' these', ' it', '\n']     │ [' do', ' get', ' help', ' set', ' use']     │ [' the', ' an', ' it', ' a', ' him']          │ ['?', ' and', ',', "?'", '\n']                │ ['\n', '?', ';', ' Is', '—']          │ ['.', ' to', ' this', ' your', ' answer']                  │ ['\n', ' You', ' The', ' It', ' Visit'] │ [',', ' and', ' First', '.', ' off']            │ [' you', ' do', ',', ' and', ' go']           │ [' a', ' your', ' the', ' it', ' an']               │ [' well', '\n', ' long', ' (', ' independent']    │ ['\xa0', ' ', '\n', '…', '...']                                                               │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' this', ' it', ' you', '\n']     │ [' do', ' get', ' know', ' make', ' change'] │ [' the', ' it', ' my', ' an', ' a']           │ ['?', ',', '\n', ' and', ' self']             │ ['\n', ' I', '—', ' Why', ' [']       │ ['.', ' that', ' is', ' your', ' the']                     │ ['\n', ' You', ' by', ' By', ' The']    │ [',', '.', ' off', ' of', ' and']               │ [' you', ' do', ' get', ' it', ' let']        │ [' a', ' it', ' your', ' an', ' the']               │ [' long', ' well', ' short', '.', ' second']      │ ['\xa0', ' ', '\n', '\r\n', '…']                                                              │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' you', ' one', ' we', ' this']   │ [' get', ' do', ' make', ' use', ' set']     │ [' the', ' this', ' a', ' my', ' it']         │ ['?"', '?', "?'", '\n', '?”']                 │ ['\n', ' I', '—', ' What', ' Why']    │ [' this', ':', ' that', ' is', ' your']                    │ [' You', '\n', ' you', ' by', ' I']     │ [',', ' of', ' off', ' and', ' you']            │ [' you', ' get', ' do', ' make', ' don']      │ [' a', ' the', ' your', ' it', ' an']               │ [' well', ' short', ' long', ' good', ' healthy'] │ ['\n', ' ', '\xa0', '\r\n', '’.']                                                             │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' you', ' we', ' it', ' a']       │ [' get', ' do', ' make', ' use', ' set']     │ [' the', ' it', ' this', ' a', ' my']         │ ['?"', '?', '?”', ' and', ',']                │ ['\n', ' I', ' What', ' How', '!"']   │ [':', ' this', ' that', ' by', ' the']                     │ [' You', '\n', ' I', ' Don', ' by']     │ [',', ' of', ' off', ' and', ' you']            │ [' you', ' get', ' don', ' I', ' do']         │ [' a', ' the', ' it', ' your', ' some']             │ [' long', ' good', '\n', ' few', ' healthy']      │ ['\n', 'uch', 'urs', '****************************************************************', '�'] │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' you', ' we', ' one', ' this']   │ [' get', ' make', ' do', ' find', ' change'] │ [' the', ' this', ' a', ' it', ' my']         │ ['?"', '?', '?”', ' and', "?'"]               │ ['\n', ' I', ' How', ' What', ' Why'] │ [':', ' this', ' that', ' the', ' is']                     │ [' I', ' You', ' Don', ' by', ' you']   │ [',', ' of', ' off', ' you', ' and']            │ [' you', ' get', ' I', ' don', ' do']         │ [' a', ' the', ' your', ' some', ' care']           │ [' good', ' long', ' healthy', ' look', '\n']     │ ['icing', '�', 'uch', 'ith', 'urs']                                                           │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' you', ' we', ' this', ' i']     │ [' get', ' do', ' make', ' find', ' use']    │ [' the', ' this', ' it', ' a', ' my']         │ ['?', '?"', '?”', ' if', ' and']              │ ['\n', ' I', ' How', ' What', ' Why'] │ [':', ' this', ' that', ' is', ' the']                     │ [' I', ' You', ' Don', ' by', ' By']    │ [',', ' off', ' of', ' you', ' we']             │ [' you', ' get', ' I', ' don', ' do']         │ [' a', ' the', ' care', ' your', ' responsibility'] │ [' look', ' good', ' deep', ' break', ' breath']  │ ['\n', '�', 'iced', 'xt', '�']                                                                │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' you', ' we', ' i', ' this']     │ [' get', ' do', ' make', ' use', ' find']    │ [' the', ' it', ' a', ' this', ' my']         │ ['?', '?"', ',', '?”', ' if']                 │ ['\n', ' I', ' How', ' What', ' Why'] │ [':', ' this', ' that', ' me', ' is']                      │ [' I', ' Don', ' You', ' by', ' By']    │ [',', ' off', ' of', ' you', ' I']              │ [' you', ' get', ' I', ' don', ' stop']       │ [' a', ' the', ' stock', ' your', ' care']          │ [' deep', ' look', ' good', ' moment', ' break']  │ ['iced', 'xt', 'ides', '\n', 'icing']                                                         │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' you', ' we', ' i', ' this']     │ [' get', ' do', ' make', ' find', ' use']    │ [' the', ' it', ' a', ' this', ' my']         │ ['?', '?"', ',', '?”', "?'"]                  │ ['\n', ' I', ' How', ' What', ' Why'] │ [':', ' this', ' that', ' is', ' me']                      │ [' I', ' You', ' Don', ' by', ' It']    │ [',', ' of', ' off', ' you', ' I']              │ [' you', ' I', ' get', ' don', ' if']         │ [' a', ' the', ' your', ' care', ' some']           │ [' deep', ' look', ' moment', ' good', ' long']   │ ['iced', 'xt', 'ith', 'ire', '\n']                                                            │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' you', ' we', ' i', ' this']     │ [' get', ' do', ' make', ' use', ' find']    │ [' the', ' it', ' a', ' this', ' my']         │ ['?', '?"', '?”', ',', "?'"]                  │ ['\n', ' I', ' How', ' What', ' Why'] │ [':', ' this', ' that', ' me', '.']                        │ [' I', ' You', ' Don', ' by', ' The']   │ [',', ' of', ' off', ' you', ' I']              │ [' you', ' I', ' get', ' don', ' we']         │ [' a', ' the', ' your', ' some', ' note']           │ [' deep', ' moment', ' look', ' good', ' breath'] │ ['iced', 'ith', '\n', 'icing', 'urn']                                                         │
# ├──────────────────────────────────────────┼──────────────────────────────────────────┼──────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────────────┼───────────────────────────────────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────┼─────────────────────────────────────────────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────────────┼───────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' many', ' do', ' much', ' can'] │ [' I', ' you', ' we', ' i', ' this']     │ [' get', ' do', ' make', ' use', ' find']    │ [' the', ' it', ' a', ' this', ' my']         │ ['?"', '?', '?”', ',', "?'"]                  │ ['\n', ' I', ' How', ' What', ' Why'] │ [':', ' this', ' that', ' me', ' is']                      │ [' I', ' You', ' Don', ' by', ' It']    │ [',', ' of', ' off', ' you', ' I']              │ [' you', ' I', ' get', ' don', ' we']         │ [' a', ' the', ' your', ' some', ' care']           │ [' deep', ' look', ' good', ' moment', ' step']   │ ['\n', 'iced', 'icing', 'urs', '�']                                                           │
# ╘══════════════════════════════════════════╧══════════════════════════════════════════╧══════════════════════════════════════════════╧═══════════════════════════════════════════════╧═══════════════════════════════════════════════╧═══════════════════════════════════════╧════════════════════════════════════════════════════════════╧═════════════════════════════════════════╧═════════════════════════════════════════════════╧═══════════════════════════════════════════════╧═════════════════════════════════════════════════════╧═══════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════╛

# %% [markdown]
# ## Comparing TunedLens and ourLens over IOI task

# %%
import torch
from tuned_lens.nn.lenses import TunedLens, LogitLens
from transformers import AutoModelForCausalLM, AutoTokenizer

device = torch.device('cpu')
# To try a diffrent modle / lens check if the lens is avalible then modify this code
model = AutoModelForCausalLM.from_pretrained("gpt2")
tokenizer = AutoTokenizer.from_pretrained("gpt2")
tuned_lens = TunedLens.from_model_and_pretrained(model)
tuned_lens = tuned_lens.to(device)
logit_lens = LogitLens.from_model(model)

# %%
from tuned_lens.plotting import PredictionTrajectory
import ipywidgets as widgets
from plotly import graph_objects as go


def make_plot(lens, text, layer_stride, statistic, token_range):
    input_ids = tokenizer.encode(text)
    targets = input_ids[1:] + [tokenizer.eos_token_id]

    if len(input_ids) == 0:
        return widgets.Text("Please enter some text.")
    
    if (token_range[0] == token_range[1]):
        return widgets.Text("Please provide valid token range.")
    pred_traj = PredictionTrajectory.from_lens_and_model(
        lens=lens,
        model=model,
        input_ids=input_ids,
        tokenizer=tokenizer,
        targets=targets,
    ).slice_sequence(slice(*token_range))

    return getattr(pred_traj, statistic)().stride(layer_stride).figure(
        title=f"{lens.__class__.__name__} ({model.name_or_path}) {statistic}",
    )

style = {'description_width': 'initial'}
statistic_wdg = widgets.Dropdown(
    options=[
        ('Entropy', 'entropy'),
        ('Cross Entropy', 'cross_entropy'),
        ('Forward KL', 'forward_kl'),
    ],
    description='Select Statistic:',
    style=style,
)
text_wdg = widgets.Textarea(
    description="Input Text",
    value="it was the best of times, it was the worst of times",
)
lens_wdg = widgets.Dropdown(
    options=[('Tuned Lens', tuned_lens), ('Logit Lens', logit_lens)],
    description='Select Lens:',
    style=style,
)

layer_stride_wdg = widgets.BoundedIntText(
    value=2,
    min=1,
    max=10,
    step=1,
    description='Layer Stride:',
    disabled=False
)

token_range_wdg = widgets.IntRangeSlider(
    description='Token Range',
    min=0,
    max=1,
    step=1,
    style=style,
)


def update_token_range(*args):
    token_range_wdg.max = len(tokenizer.encode(text_wdg.value))

update_token_range()

token_range_wdg.value = [0, token_range_wdg.max]
text_wdg.observe(update_token_range, 'value')

interact = widgets.interact.options(manual_name='Run Lens', manual=True)

plot = interact(
    make_plot,
    text=text_wdg,
    statistic=statistic_wdg,
    lens=lens_wdg,
    layer_stride=layer_stride_wdg,
    token_range=token_range_wdg,
)
# Out:
# interactive(children=(Dropdown(description='Select Lens:', options=(('Tuned Lens', TunedLens(
#   (unembed): Une…

# %%
hooked_model = HookedTransformer.from_pretrained("gpt2")
# Out:
# Loaded pretrained model gpt2 into HookedTransformer

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2")

# %%
tokens = tokenizer.encode("Jingle bells jingle bells jingle all the", return_tensors="pt")
with torch.no_grad():
    logits, clean_cache = hooked_model.run_with_cache(tokens)

# %%
def residual_stream_patching_hook(
    resid_post: Float[torch.Tensor, "batch pos d_model"],
    hook: HookPoint,
    position: int
) -> Float[torch.Tensor, "batch pos d_model"]:
    clean_resid_post = clean_cache[hook.name]
    resid_post[:, 0, :] = clean_resid_post[:, position, :]
    return resid_post

num_positions = len(tokens[0])
patching_result = torch.zeros((hooked_model.cfg.n_layers, num_positions, 50), device=hooked_model.cfg.device)

for layer in tqdm.tqdm(range(hooked_model.cfg.n_layers)):
    for position in range(num_positions):
        # Use functools.partial to create a temporary hook function with the position fixed
        temp_hook_fn = partial(residual_stream_patching_hook, position=position)
        # Run the model with the patching hook
        patched_logits = hooked_model.run_with_hooks(torch.tensor([[0]], device='cuda:0'), fwd_hooks=[
            (utils.get_act_name("resid_post", layer), temp_hook_fn)
        ])
        # Calculate the logit difference      
        _, patching_result[layer, position] = torch.topk(patched_logits.squeeze(), k=50)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:09<00:00,  1.31it/s]

# %%
def stringify(x):
    return hooked_model.to_string(x)
result = [[[stringify(top) for top in element]for element in subarray] for subarray in patching_result.int()]
strtoks = [stringify(tok) for tok in tokens[0]]

# %%
_ , clean_predicts = torch.topk(logits.squeeze(), k=5)
clean_predicts_text = [[stringify(tok) for tok in elem] for elem in clean_predicts.int()]
result.append(clean_predicts_text)

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...
# │ J                                                                                                                                                                                                                                                                                                                    │ ingle                                                                                                                                                                                                                                                                                                                                                                                   │  bells                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │  j                                                                                                                                                                                                                                                                                                                                                                                       │ ingle                                                                                                                                                                                                                                                                                                                                                                                                                           │  bells                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │  j                                                                                                                                                                                                                                                                                                                                                               │ ingle                                                                                                                                                                                                                                                                                                                                                                                                                                                             │  all                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │  the                                                                                                                                                                                                                                                   ...
# ╞══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...
# │ ['.', ',', '\n', '-', ':', ' and', "'s", '/', ' is', ' (', ')', ' of', ' to', '2', '_', ' was', ' the', ' in', '1', 'I', ' -', "'", ' for', '3', 'J', ' a', ' I', 'A', '"', ' "', ' are', '4', ';', ' on', 'G', 'a', 's', 'K', ']', ' has', 'S', ' that', 'U', '<|endoftext|>', '?', ' have', 'B', ' or', '0', 'in'] │ ['ingle', 'ide', ' cl', '-', 'c', 'mer', 'l', 'h', 'ite', 'pe', ' mer', 'se', 'and', 'ch', 'ling', 'ing', ' se', 'ird', 'cl', 'lic', 'e', 'ly', 'ee', ' and', ' c', 'd', 'ie', 'ance', 'y', ' share', 'icker', 'in', 't', 's', 'le', "'", 'bie', 'ine', 'al', 'it', ' pe', 'ple', 'ble', ' all', 'ings', 'b', 'pl', 'ily', 'ic', '.']                                                   │ [' bells', ' bell', ' ringing', 'bell', ' call', ' drum', ' drums', '\n', ' rings', ' toll', ' day', ' ring', ' hours', ' whist', ' clam', ' music', ' calls', ' clock', ' Bell', ' tones', ' b', ' calling', ' alarms', ' time', ' rang', ' r', ' alarm', ' whistle', ' round', ' (', ' hon', ' start', ' days', ' men', 's', ' quiet', ' minutes', ' night', ' horn', ' tune', ' holiday', ' services', ' percussion', ' &', ' Christmas', ' sound', ' children', ' and', ',', ' tunes']      │ [' j', 'j', ' J', 'J', '\n', ' ju', ' i', ' l', ' c', ',', ' 2', ' 1', ' n', ' jo', ' b', ' Jan', ' jan', ' I', ' d', ' m', ' a', ' je', ' fun', ' k', ' in', ' jun', ' v', ' at', 'jj', ' t', ' s', ' pr', ' joke', ' de', ' cl', ' y', ' r', ' su', ' Jim', ' the', ' it', ' al', ' or', ' "', ' p', ' g', ' _', ' 13', ' James', ' my']                                               │ ['ingle', ' cl', ' and', ' inter', 'ise', ' se', '-', 'ling', ' c', ',', 'mer', ' be', ' share', ' each', ' mer', ' mix', ' or', 'ide', ' merge', ' all', 'ee', 'ing', "'", 'ance', ' of', 'ly', ' mixed', ' in', ' with', 'ings', 'c', '/', ' other', ' spl', ' add', ' em', 'e', ' l', ' blend', ' slip', 'ite', 'lic', 'ily', ' the', ' together', ' e', ' to', 'd', ' extra', ' pe']                                        │ [' bells', ' bell', ' ringing', 'bell', ' call', ' rings', ' drums', ' drum', ' Bell', ' toll', ' clam', ' day', '\n', ' ring', ' calls', ' alarms', ' hours', ' tones', ' music', ' whist', ' clock', ' calling', ' rang', ' time', ' b', ' services', ' round', ' night', 's', ' children', ' men', ' r', ' alarm', ' hon', ' minutes', ' percussion', ' days', ' cries', ' and', ' whistle', ' tunes', ' tune', ' fair', ' start', ' quiet', ',', ' times', ' Christmas', ' singing', ' main']       │ [' j', ' J', 'j', '\n', 'J', ' d', ' i', ' n', ' k', ' 2', ' N', ' 1', ' y', ' Jin', ' b', ' c', ' Jan', ' l', ' ju', ' je', ' 0', ' JD', ' 13', ' r', ' m', ' x', ' I', ' 9', ' jo', ' su', ' 14', ',', ' al', ' a', ' 21', ' t', ' p', ' jun', ' g', ' 7', ' 52', ' in', ' u', ' K', ' Ju', ' at', 'jj', ' (', ' the', '\n\n']                                 │ ['ingle', ' cl', '-', 'ine', '.', ' inter', 'ling', ' and', ',', 'ette', 'in', ' in', 'ly', 'ic', "'", ' all', 'angle', ' mer', 'al', 'ing', 'ide', 'el', '"', ' com', 'ase', 'ite', 'idy', ' be', ' to', ' of', 'd', ' e', ' l', ' together', 'h', ' as', ' c', ' the', ' j', 'int', 'le', ' se', 'ize', 'et', ' both', '\n', ' honest', ' add', ' crawl', 'l']                                                                                                  │ [' all', ' All', ' true', ',', ' and', ' of', ' just', ' this', ' one', ' for', ' I', ' truly', ' everything', ' so', ' the', ' everyone', ' to', ' at', ' great', ' ALL', ' total', ' that', ' equally', ' now', ' in', ' well', ' once', ' ever', ' love', ' oh', ' we', ' good', ' finally', ' a', ' any', ' being', ' best', ' last', ' including', ' it', ' not', ' my', ' as', ' had', ' have', ' is', '-', ' "', ' was', ' what']                                                             │ [' the', ' all', ' no', ' it', ' I', ' a', ' my', ' oh', "'", ' ah', ' without', ' se', ',', ' an', ' this', ' in', ' be', ' bi', ' one', ' again', ' that', " '", ' we', ' and', ' of', ' none', ' they', ' tr', ' you', ' to', ' me', ' he', ' its', ...
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ ['.', ',', '\n', '-', ':', ' and', "'s", '/', ' is', ' (', ')', ' of', ' to', '2', '_', ' was', ' the', ' in', '1', 'I', ' -', "'", ' for', '3', 'J', ' a', ' I', 'A', '"', ' "', ' are', '4', ';', ' on', 'G', 'a', 's', 'K', ']', ' has', 'S', ' that', 'U', '<|endoftext|>', '?', ' have', 'B', ' or', '0', 'in'] │ ['ingle', '-', ' cl', ' it', 'ide', ',', 'and', ' and', 'collect', ' all', 'pe', 'lett', 'it', 'le', '"', 'along', ' crawl', 'ing', 'ling', ' special', ' together', 'c', ' com', 'icker', 'mer', ' be', 'ch', 'lly', 'ble', 'art', ' you', ' each', ' the', ' with', ' between', ' pe', ' se', 'ead', '",', 'h', ' associate', '.', ' of', ' a', 'et', "'", 'apple', 'l', 'se', 'ang'] │ [' bells', ' bell', ' ringing', 'bell', ' call', ' drum', ' horn', ' ring', ' rings', ' drums', ' toll', ' whist', ' r', ' hon', ' tones', ' music', ' whistle', ' Bell', ' and', ' calls', ' sounding', ' rang', ' sounds', ' calling', ' all', ' day', ' bang', ' quiet', ' b', '\n', ' a', ' clam', ' alarm', ' numbers', ' alarms', ' round', ' number', ' big', ' brass', ' thunder', ' sound', ' oh', ' boom', ',', ' singing', ' ears', ' echo', ' tune', ' world', ' loud']             │ [' j', 'j', ' J', ' jo', 'J', '\n', ' ju', ' jan', ' i', ' je', ' jug', ' d', ' pr', ' k', ' n', ' 1', ' s', ' c', 'jj', ' dj', 'ja', ' b', ' ja', '\n\n', ' v', ',', ' l', ' y', ' 9', 'jay', ' t', ' sam', ' .', ' jun', ' I', ' r', ' at', ' Jan', ' p', ' g', 'jo', ' su', ' JD', ' it', 'ji', ' ...', ' 2', ' a', ' the', ' :']                                                     │ ['ingle', ' mer', ' inter', '-', ' cl', ' and', ' e', ',', ' score', ' duo', ' begin', 'ine', ' in', ' del', ' the', ' add', ' com', ' all', ' crawl', ' be', ' combination', ' continuous', ' end', ' sound', ' as', 'ily', ' dance', 'ly', ' your', ' we', ' our', ' you', ' to', ' come', ' into', ' or', ' mixed', 'ling', ' &', ' blend', ' se', ' el', ' a', ' of', ' enter', ' for', ' commence', 'ide', ' time', '.']   │ [' bells', ' bell', ' ringing', 'bell', ' rings', ' toll', ' Bell', ' drums', ' cries', ' call', ' drum', ' calls', ' rang', ' quiet', ' whist', ' alarms', ',', ' r', ' hon', '\n', ' ring', ' and', ' bon', ' numbers', ' tones', ' Christmas', ' clam', ' horns', ' days', ' day', ' cr', ' bang', ' b', ' noises', ' minutes', ' horn', ' time', ' boys', ' hours', ' a', ' times', ' music', ' night', ' shells', ' services', ' christ', ' fireworks', ' bel', '.', ' calling']                   │ [' j', ' J', 'j', ' jo', ' k', ' d', '\n', ' i', ' n', ' jan', ' c', ' at', ' je', ' t', ' r', ' ...', ' 1', ' b', ' y', ' .', ' p', ' 7', ' 9', ' s', ' l', ' 2', ' ju', ' m', ' u', ' time', ' x', ' su', ' 13', ',', ' 0', ' the', '<|endoftext|>', ' com', ' g', ' hard', ' a', ' sh', ' sk', ' 8', ' I', ' john', 'J', ' de', ' high', ' q']                │ ['ingle', ' and', 'ine', ' duo', ' inter', ',', '-', ' e', ' com', ' add', ' in', ' cl', ' or', ' &', ' to', ' combination', ' the', ' our', ' crawl', ' all', ' mer', ' as', ' into', ' el', ' of', '.', ' your', ' score', ' blend', 'ling', ' enter', ' del', ' end', ' come', ' be', ' begin', ' for', 'i', ' you', 'ly', ' a', ' we', ' enjoy', ' together', 'ic', ' dance', ' sol', ' se', ' welcome', ' sound']                                            │ [' all', ' All', ' love', ',', ' and', ' the', ' true', ' everyone', ' of', ' just', ' good', ' at', ' for', ' always', ' everywhere', ' equally', ' everything', ' in', ' best', ' ALL', ' any', ' ever', ' to', ' this', ' I', ' one', '.', ' that', '-', ' up', ' so', ' "', ' first', ' every', ' through', ' with', ' those', ' rest', ' out', ' last', ' great', ' throughout', ' thanks', ' --', ' a', ' oh', ' everybody', ' her', '...', ' once']                                           │ [' the', '\n', ' a', ' all', ' of', 'the', ' an', ' The', ' to', ',', ' it', ' in', ' we', ' and', ' be', ' oh', ' its', ' for', ' this', ' no', ' more', ' my', ' one', ' that', '<|endoftext|>', ' now', ' our', ' at', ' I', ' you', ' say', ' -',  ...
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ ['.', ',', '\n', '-', ':', ' and', "'s", '/', ' is', ' (', ')', ' of', ' to', '2', '_', ' was', ' the', ' in', '1', 'I', ' -', "'", ' for', '3', 'J', ' a', ' I', 'A', '"', ' "', ' are', '4', ';', ' on', 'G', 'a', 's', 'K', ']', ' has', 'S', ' that', 'U', '<|endoftext|>', '?', ' have', 'B', ' or', '0', 'in'] │ ['ingle', '-', '!', ',', ' associate', 'olo', '"', ' cl', 'aver', 'icker', 'lic', 'ingo', ' del', 'le', 'and', 'ling', 'icken', 'lie', '",', 'ide', ' com', ' -', 'ue', "'", 'ince', ' it', 'card', '.', ' mixed', 'along', ' combine', 'ily', '"!', ' you', 'ap', ' be', 'cation', 'ome', ' we', 'lett', ' "', ' all', '!"', 'ance', ' the', ' none', ' –', ' of', ' together', "'s"]  │ [' bells', ' bell', ' ringing', 'bell', ' call', ' horn', ' ring', ' rings', ' drum', ' clam', '\n', ' alarm', ' alarms', ' drums', ' whist', ' whistle', ' rang', ' tune', ' Bell', ' toll', ' music', ' sounds', ' chorus', ' r', ' ears', ' b', ' calls', ' cries', ' quiet', ' doors', ' hon', ' day', ' buzz', ' numbers', ' tunes', ' sound', ' clock', ' tones', ' echo', ' calling', ' box', ' round', ' name', ' sounding', ' door', ' cl', ' gates', ' world', ' number', ' prayers'] │ [' j', ' jo', 'j', ' ju', ' J', ' d', ' n', ' x', ' k', ' ad', ' i', ' su', ' or', ' jan', '\n', 'jj', ' bob', ' y', ' v', ' .', ' p', ' e', ' jun', ' z', '.', ' c', ' and', ' kn', ' 13', ' at', ' all', ' det', ' a', ',', ' g', ' as', 'J', ' ty', ' cl', ' any', ' jud', ' its', ' dj', ' m', ' ja', 'ja', ' t', ' the', ' _', ' pr']                                               │ ['ingle', 'ily', 'ling', 'ly', ' as', '\n', ' count', 'et', '-', 'uddle', '.', 'ide', ' e', ',', ' duo', ' all', ' mix', ' together', 'ud', ' cl', ' be', 'al', 'sey', ' word', ' countdown', ' em', ' mixed', ' happy', "'", ' score', ' tally', ' and', ' inter', ' sing', ' sound', ' warm', ' it', 'ap', '****************', 'ing', 'd', ' dance', ' to', 'udd', 'art', ' pe', ' in', ' trial', 'int', ' racket']           │ [' bells', ' bell', ' ringing', 'bell', ' cries', ' rings', ' whist', ' rang', ' drums', ' bon', ' noises', ' toll', ' Bell', ' alarms', '\n', ' horns', ' sounds', ' ears', ' ring', ' music', ' calls', ' horn', ' r', ' quiet', ' drum', ' tunes', ' b', ' clam', ',', ' alarm', ' screams', ' prayers', ' call', ' boys', ' doors', ' hon', ' numbers', ' tones', ' shells', ' times', ' days', ' services', ' bones', ' whistle', ' children', ' beads', ' voices', ' begging', ' tune', ' hours'] │ [' j', ' J', ' k', ' jo', 'j', ' i', '\n', ' jan', ' su', ' d', ' n', ' je', ' c', ' x', ' r', ' com', ' y', ' at', ' p', ' t', ' jun', ' 13', ' dj', ' ad', ' ju', ' m', ' xx', ' l', ' 2', ' 14', ' bob', ' sk', ',', ' g', ' as', ' b', ' 7', ' 9', ' and', ' s', ' it', ' Jan', ' 22', '.', ' 8', ' cl', ' -', ' det', ' JD', ' a']                          │ ['ingle', ' and', ' all', ' duo', ' as', '.', ' em', ' count', ' happy', ' together', ' end', 'ling', ',', ' dance', '-', ' add', ' be', 'et', 'ine', ' to', ' mix', ' mixed', ' e', ' in', ' for', 'ing', 'ide', ' with', 'ly', ' entertainment', ' of', ' sol', ' sound', ' a', 'ily', ' countdown', "'", ' 8', ' 3', 'd', ' score', ' the', ' company', ' one', ' them', ' number', ' it', 'uddle', ' my', 'al']                                               │ [' all', ' All', ' equally', ' the', ' ALL', ' at', ' everyone', ' just', ' total', ' of', ' any', ' one', ' entirely', ' true', ',', ' every', ' and', ' in', ' none', ' most', ' "', ' those', ' this', ' only', ' both', ' (', ' that', ' each', ' full', ' a', '-', ' everything', ' or', ' being', ' actually', ' truly', ' other', ' single', ' overall', ' half', ' by', ' non', ' I', ' out', ' not', ' people', ' also', ' even', ' combined', ' ever']                                     │ [' the', ' a', ' it', ' in', ' on', '?', ' her', ' to', '\n', ' more', ' not', ' she', ' all', ' no', ',', ' and', ' one', ' for', ' just', ' yes', ' of', ' I', ' filling', ' an', ' without', ' at', ' you', ' that', ' your', ' this', ' less', ' o ...
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ ['.', ',', '\n', '-', ':', ' and', "'s", '/', ' is', ' (', ')', ' of', ' to', '2', '_', ' was', ' the', ' in', '1', 'I', ' -', "'", ' for', '3', 'J', ' a', ' I', 'A', '"', ' "', ' are', '4', ';', ' on', 'G', 'a', 's', 'K', ']', ' has', 'S', ' that', 'U', '<|endoftext|>', '?', ' have', 'B', ' or', '0', 'in'] │ ['ingle', '-', 'ettle', ' cl', '!', '"', ',', ' our', ' we', ' com', '®', '\n\n', 'icker', '.', ' del', ' "', '\n', ' sleeve', ' of', 'hew', 'collect', 'le', '[]', ' merge', ' We', ' mer', '"?', ' together', '>>', '��', 'j', ' -', '>', ' j', 'We', '!"', ' Christmas', ' you', '™', 'andy', ' the', ' conf', ' between', ' stereo', '",', ' it', ' file', ' e', ' Double', 'our']  │ [' bells', ' bell', ' ringing', 'bell', ' Bell', ' clam', ' rings', ' whist', ' ears', ',', ' tunes', ' call', ' girls', ' drums', '\n', ' all', ' ring', ' ch', ' big', ' boys', ' and', ' music', ' tones', ' alarms', ' rang', ' ladies', ' cries', '.', ' horn', "'", ' b', ' bel', '!"', ' cl', ' bon', ' singing', ' toll', '"', '!', ' loud', ' y', ' calls', ' tune', ' j', ' h', ' cheers', ' baby', ' men', ' babies', ' thunder']                                                    │ [' j', ' ju', 'j', ' jo', ' J', ' jun', ' k', ' jan', ' p', ' i', ' n', ' q', ' y', ' x', ' dj', ' d', '/', ' al', '\n', ' ad', '.', ' z', ',', ' all', ' id', ' ch', ' cl', ' c', ' g', ' su', ' or', ' t', ' de', ' sh', ' v', ' jud', ' e', ' at', ' deb', ' coll', ' as', 'jj', ' sm', ' and', ' comp', ' det', ' m', ' any', ' s', ' 1']                                            │ ['ingle', '!', ' cl', '.', '\n\n', '-', '\n', ' happy', ' j', 'hh', 'oooo', ' merge', ' sound', ' echo', ' shuffle', ' du', ' tune', ',', ' your', ' mer', ' you', ' together', ' as', ' shuff', ' number', ' music', 'udd', ' d', ' merry', ' oh', ' the', ' end', ' of', ' we', '>', ' mixed', 'eeee', ' Happy', ' continue', 'icker', ' e', ' our', ' sync', ' and', ' all', ' to', ' o', ' in', ' l', ' my']                │ [' bells', ' bell', 'bell', ' ringing', ' Bell', ' whist', ' cries', ' bon', ' rings', '\n', ',', ' rang', ' drums', ' ears', ' clam', ' horns', ' b', ' noises', ' and', ' toll', ' boys', ' tunes', ' lit', ' the', ' ch', '.', ' sounds', ' quiet', ' alarms', ' bel', ' music', ' beads', ' whistle', ' singing', ' j', ' all', ' tones', ' horn', ' strings', "'", ' days', ' r', ' prayers', ' ring', ' big', ' drum', '-', ' voices', ' cheers', ' bu']                                          │ [' j', 'j', ' ju', ' jo', ' k', ' jun', ' J', ',', ' p', '\n', ' n', ' x', ' i', ' at', ' dj', ' and', ' c', ' y', '.', ' coll', ' g', ' jan', ' as', ' t', ' d', ' su', ' cl', ' sk', ' id', ' com', ' q', ' all', ' 2', ' m', ' l', ' the', ' 7', ' al', ' ad', ' ch', ' comp', ' (', 'jj', ' r', ' deb', ' in', ' z', ' sh', ' a', ' 1']                      │ ['ingle', '!', '.', ' happy', ' j', ' sol', '>', ' as', '\n', 'hh', 'oooo', ' together', ',', ' mer', ' merry', '-', 'ett', '\n\n', 'et', ' Happy', 'é', ' to', ' tune', ' end', ' e', ' >', 'ling', 'uddle', ' I', ' my', ' you', ' in', ' sod', ' we', ' and', 'happy', ' mixed', ' solo', ' shuff', 'udd', ' 1', ' shuffle', ' music', ' one', ' the', ' merge', 'one', ' time', ' tally', ' duo']                                                             │ [' all', ' the', ' just', ' at', ' All', ' none', ' only', ' every', ' true', ' one', ' on', ' in', ' now', ' this', ' and', ' everywhere', ' everything', ' a', ' any', ' free', ' right', ' around', ' both', ' most', ' last', 'all', ' no', ' always', ' it', '\n', ' first', ' everyone', ' best', ' rest', ' equally', ' so', ' not', ',', ' other', ' full', ' ALL', ' for', ' of', ' these', ' my', ' each', ' up', ' even', ' me', ' by']                                                   │ [' all', ' just', ',', ' little', ' the', ' everything', ' every', ' any', ' it', ' everybody', ' one', ' nobody', ' you', ' and', ' oh', ' none', ' let', ' she', ' that', ' like', ' anything', ' what', ' nothing', ' t', ' ever', ' free', ' was', ...
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# ...
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ ['.', ',', '\n', '-', ':']                                                                                                                                                                                                                                                                                           │ [',', '.', "'s", ' and', '-']                                                                                                                                                                                                                                                                                                                                                           │ [',', '.', ' and', ' are', '!']                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ ['ingle', 'ing', 'angle', 'olly', 'erry']                                                                                                                                                                                                                                                                                                                                                │ [' bells', '.', ',', ' j', '-']                                                                                                                                                                                                                                                                                                                                                                                                 │ [' j', '\n', '.', ',', '!']                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │ ['ingle', 'ing', 'angle', 'itter', 'olly']                                                                                                                                                                                                                                                                                                                       │ [' bells', ' bell', ' j', ',', ' tunes']                                                                                                                                                                                                                                                                                                                                                                                                                          │ [' the', ' over', ' around', ' day', ' of']                                                                                                                                                                                                                                                                                                                                                                                                                                                          │ [' way', ' time', ' bells', ' while', ' same']                                                                                                                                                                                                         ...
# ╘══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...
# │ When                                                                                                                                                                                                                                                                                                                                                                                           │  John                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │  and                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │  Sarah                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      │  went                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │  to                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │  the                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │  store                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │ ,                                                                                                                                                                                                   ...
# ╞════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' number', 'john', ' James', ' other', ' 1', ' john', ' j', ' male', ' JOHN', ' the', ' Joshua', ' man', ' who', ' of', ' Julian', ' as', ' Jack', ' others', ' and', ' 13', ' Robert', ' left', ' current', ' from', ',', ' Kh', ' in', ' Steve', ' men', ' Kev', 'JOHN', ' Matthew', ' secretary', '-', ' Chris', ' Johnson', ' Richard', ' Jonathan', ' name', ' "', ' Gregory', ' or', ' Mr', ' Christopher', ' we', ' right', ' al', ' a']                       │ [' and', ' all', ' to', ' so', ' as', ' both', ' at', ' &', ' /', ' more', ' also', ' ...', ' but', ' becoming', ' then', ' it', '\n', ',', ' open', ' path', ' the', ' And', ' even', ' a', ' not', ' end', ' this', '/', ' being', ' 1', ' completely', ' in', ' almost', ' All', ' "', ' I', ' everything', ']', ' other', ' become', ' ]', ' for', ' already', ' who', ' which', ' nearly', ' further', ' first', ' As', ' ultimately']                                                │ [' Sarah', 'Sarah', ' 1', ' Rebecca', ' 2', ' Palin', ' Stephen', ' 0', ' n', ' 3', ' Susan', ' Abraham', ' Unknown', ' John', '\n', ' Sara', ' Spe', ' San', ' Sl', ' She', ' David', ' Richard', ' s', ' Other', ' Laura', ' Ryan', ' 8', ' Ted', ' 16', ' 12', ' U', ' S', ' Kate', ' 14', ' Austin', ' (', ' "', ' not', ' Sad', ' 15', ' and', ' Short', ' False', ' Isaac', ' None', ' Andrew', ' Sally', ' Scot', ' Adam', ' N']                                                     │ [' go', ' went', ' and', ' said', ' head', ' got', ' talk', ' all', ' was', ' talked', ' gone', ' she', ' I', ' do', ' in', ' it', ' h', ' be', ' had', ' a', ' get', ' on', ',', ' did', ' just', ' no', ' thing', ' one', ' body', ' any', ' start', ' have', ' last', ' hear', ' every', ' saw', ' the', ' started', ' about', ' going', ' everything', ' say', ' anything', ' for', ' there', ' next', ' this', ' person', ' to', ' other']                                                              │ [' to', ' online', '\n', ' all', ' trip', ' travel', ' shopping', ' and', ' in', ' more', ' with', ' on', ' the', ' visit', ' how', ' new', ' where', ' other', ' so', ' journey', ' traveling', ' I', ' site', ' my', ' business', ' as', ' day', ' home', ' much', ' time', ' top', ' full', ' a', ' daily', ' many', ' again', ' main', ' or', ' it', ' list', ' website', ' what', ' destination', ' next', ' of', ' without', ' tr', ' when', ' way', ' long']              │ [' the', '\n', ' a', ' all', ' it', ' an', ' in', ' one', ' of', ' se', 'the', ' no', ' to', ' that', ' say', ' this', ' The', ' and', ' not', ' yes', ' out', ',', ' its', ' at', ' what', ' for', ' you', ' 1', ' "', ' I', ' be', ' again', ' end', ' said', ' two', ' they', "'", '<|endoftext|>', ' on', ' your', ' without', '\n\n', ' back', ' hy', ' about', ' more', ' 2', 'uth', '-', ' y']                                                                                                                                 │ [' store', ' stores', ' sho', ' shopping', '\n', ' mall', ' shop', ' warehouse', ' clerk', ' retail', ' shoe', ' retailer', ' department', ' clothing', ' end', ' business', ' stocking', ' &', ' carry', ' merchandise', ' grocery', ' lock', ' footwear', ' season', ' Macy', ' and', ' storing', ' storage', '-', 'store', ' sales', ' stock', ' /', ' stop', ' as', ' hair', ' be', ' core', ' apparel', ',', ' fair', ' shift', '<|endoftext|>', ' keep', ' center', ' interior', ' app', ' day', ' card', ' full'] │ [',', ' ,', '.', '\n', ';', ' and', '-', '.,', ',"', ' "', ' (', ' all', '!', ' the', ' No', ' in', ' or', ' of', ' I', ' for', ' Ed', ' &', ':', ' B', ' 1', ' to', ' not', ' All', ' .', ' City', ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' 1', ' john', ' 2', ' Johns', ' Kev', 'john', ' Paul', ' JOHN', ' Kh', ' Kelly', ' Johnson', ' James', ' 13', '"', ' Robert', ' 112', ' Johnston', ' Num', ' Mr', ' Jon', ',', ' Re', ' the', ' number', ' j', ' R', ' King', ' Rob', ' K', ' 3', ' 11', ')', ' Gregory', '-', ' Ker', ' rh', ' secretary', ' Jack', ' Rory', ' wh', ' First', ' (', ' 12', ' N', ' McCl', ' 111', ' or', ' Secretary']                                                              │ [' and', ' both', ' all', ' to', ' as', ' being', ' it', ' also', ' be', ' a', ' if', ' even', ' completely', ' the', ' without', ' would', ' at', ' not', ' in', ' then', ' could', ' multiple', ' that', ' everything', ' but', ' other', ' any', ' entire', ' more', ' before', ' so', ' an', ',', ' you', ' nor', ' outright', ' already', ' end', ' including', ' instead', ' just', '/', ' or', ' self', ' while', ' its', ' from', ' second', ' itself', ' past']                   │ [' Sarah', 'Sarah', ' Sl', ' 1', ' Rebecca', ' Spe', ' 2', ' Sara', ' T', ' Palin', ' Stephen', '\n', ' Unknown', ' Abraham', ' Susan', ' Scot', ' SB', ' U', ' 3', ' She', ' S', ' 0', ' n', ' Isaac', ' Un', ' Ab', ' Sad', ' Austin', ' Kate', ' Scout', ' Todd', ' Ryan', ' Scott', ' Texas', ' Th', ' John', ' Ted', ' Tr', ' Snap', ' Michelle', ' San', ' s', ' N', ' SD', ' Laura', ' State', ' Kyle', ' Other', ' Tina', ' Text']                                                  │ [' went', ' go', ' gone', ' all', ' and', ' was', ',', ' going', ' got', ' said', ' talked', ' just', ' saw', ' it', ' heard', ' whole', ' head', ' had', ' she', ' there', ' every', ' did', ' hit', ' I', ' on', ' that', ' the', ' everybody', ' a', ' where', ' everything', ' to', ' left', ' no', ' in', ' what', ' for', ' they', ' very', ' came', ' who', ' with', ' you', ' spoke', ' knew', "'s", ' goes', ' this', ' people', ' pretty']                                                         │ [' to', ' all', ' a', ' every', '\n', ' it', ' online', ' how', ' so', ' straight', ' where', ' like', ' and', ' the', ' in', ' on', ' just', ' more', ' full', ' I', ' as', ' everything', ' many', ' take', ' of', ' an', ' you', ' there', ' completely', ' often', ' much', ' go', ' at', ' down', ' that', ' taking', ' actually', ' or', ' across', ' before', ' with', ' when', ' not', ' sitting', ' this', ' what', ' very', ' have', ' each', ' about']                │ [' the', '\n', ' a', ' to', ' all', ' of', ' The', ' in', ' and', 'the', ' for', ' be', ' an', ' it', ' that', ',', ' this', "'", ' y', ' as', ' one', ' first', ' its', '-', '<|endoftext|>', ' you', ' at', ' means', ' by', ' from', ' come', ' have', ' say', ' so', ' both', ' each', ' two', ' more', ' I', ' b', ' not', ' se', ' we', ' over', ' o', ' no', ' like', ' -', ' which', '\n\n']                                                                                                                                  │ [' store', ' stores', ' shop', ' shopping', ' mall', ' storing', ' hide', ' sho', '\n', ' warehouse', ' and', ' or', ' carry', ' stop', ' department', ' hold', ' pre', ' storage', ' train', ' concealed', ' /', ' stock', ' clothing', ' retail', ' trap', ' shoe', 'store', ' clerk', ' stored', ' business', ' back', ' &', ' hid', '-', ' game', ' state', ' car', ' ad', ' open', ' conceal', ' rest', ' home', ' end', ',', ' post', ' factory', ' closet', ' core', ' brief', ' card']                           │ [',', ' and', ' ,', ',"', ' (', '.', '-', ' No', ' the', ' or', ' I', ' of', '/', ' a', ' will', ';', ' for', ' all', ' in', ' One', ' at', ' &', ' B', ' D', "'s", ' A', ' not', ' as', ' with', ' ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', ' john', ' JOHN', 'John', ' Johnson', ' maybe', ' Johnston', ' 1', ' Kelly', ' a', ' just', ' less', ' more', ' 2', ' its', ' back', ' al', ' j', ' why', ' po', ' Jonas', ' probably', ' Johns', ' God', ' wrong', ' Paul', ' language', ' king', ' Holy', ' Kh', ' reason', ' yes', ' kingdom', ' English', ' in', ' 10', ' holy', ' perhaps', ' 15', 'john', ' the', ' 13', ' sometimes', ' Richard', ' about', ' Nil', ' name', ' help', ' what', ' 3']                   │ [' and', '\n', ' then', ' And', ' it', ' ,', ' )', ' "', ' both', ' .', ' even', ' almost', ' the', ' before', ' a', ' when', ' that', ' in', ' all', ' during', ',', ' also', ' as', ' its', ' one', ' you', ' early', ' said', ' but', ' actually', ' later', ' /', ' this', ' I', ' after', ' not', ' no', ' there', '.', ' on', ' your', ' so', ' at', ' just', ' out', ' water', ' ;', ' footage', ' .)', ' became']                                                                  │ [' Sarah', 'Sarah', ' 1', ' 2', '\n', ' Rebecca', ' 3', ' Palin', ' 8', ' SB', ' Abraham', ' U', ' Spe', ' n', ' 5', ' 4', ' Austin', ' Mary', ' 16', ' 14', ' Scott', ' Adam', ' John', ' Lincoln', ' 7', ' in', ' 0', ' (', ' Cruz', ' Stephen', ' 12', ' Laura', ' Isaac', ' San', ' Texas', ' and', ' 20', ' Sl', ' Ted', ' SD', ' 15', ' by', ' 24', ' Wilson', '<|endoftext|>', ' Kate', ' as', ' 9', ' David', ' a']                                                                 │ [' go', ' gone', ' went', ' all', ' she', ' just', ' come', ' got', ' do', ' there', ' and', ' going', ' will', ' you', ' I', ' it', ' everything', ' that', ' a', ' have', ' goes', ' get', ' next', ' every', ' run', ' was', ' anything', ' had', ' be', ' no', ' big', ' head', ' said', ' maybe', ' one', ' did', ' left', ' show', ' he', ' right', ' whole', ' say', ' good', ' shot', ' to', ' what', ' the', ' her', ' thing', ' saw']                                                              │ [' to', ' more', ' at', ' one', ' a', ' up', ' all', ' as', ' just', ' on', ' in', ' you', ' I', ' the', ' over', '\n', ' not', ' her', ' without', ' almost', ' "', ' beside', ' about', ' nearly', ' simply', ' for', ' every', ' your', ' before', ' no', ' un', ' an', ' less', ' changes', ' straight', ' this', ' down', ' it', ' my', ' of', ' here', ' me', ' days', ' from', ' when', ' so', ' per', ' that', ' full', ' and']                                          │ [' the', '\n', ' a', ' and', ' for', ' to', ',', ' I', ' in', ' at', ' it', ' as', '?', ' over', ' but', ' yes', ' The', ' on', ' all', ' then', ' first', ' now', ' not', ' more', ' one', ' from', ' when', ' said', ' my', ' of', ' before', ' 1', ' no', ' last', ' we', ' its', ' until', ' part', ' out', '.', ' through', ' an', ' what', ' each', ' fill', ' that', ' will', ' cost', ' she', ' by']                                                                                                                          │ [' store', ' stores', ' shop', '\n', ' sho', 'store', ' warehouse', '<|endoftext|>', ' shopping', ' Store', ' local', ' location', ' stop', ' sell', ' hide', ' mall', ' buy', ' retail', ' online', ' train', ' fast', ' department', ' stock', ' pre', ' shoe', ' app', ' keep', ' start', ' city', ' market', ' in', ' general', ' to', ' carry', ' season', ' ad', ' save', ' post', 'Store', ' hid', ' place', ' reveal', ' get', ' floor', ' area', ' find', ' game', ' sales', ' camera', ' track']               │ [',', '\n', '—', ' —', ' ,', ',"', '.', ' be', ' --', ' to', ' begin', ' and', ' in', ':', ' "', ' And', ' she', ' that', ' at', ';', ' is', ' take', ' I', ' go', ' this', ' –', '…', ' ―', ' do', ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' JOHN', ' john', ' Lennon', ' Robert', ' Paul', ',', ' j', ' his', ' Johnson', ' Jon', ' 1', '-', 'john', ' Johnston', ' James', 'JOHN', ' William', ' 11', ' Richard', ' Jeff', ' 13', ' Ted', ' Kyle', ' 10', ' Rex', ' 17', ' ...', ' Michael', ' son', ' Julian', ' Mike', ' Henry', ' [', ' 16', ' L', ' Daniel', ' Bob', ' and', ' 15', ' man', ' Joshua', ' J', ' Jake', ' he', ' 23', ' Jr', ' the', ' George']                                              │ [' and', ' both', ' while', ' as', ' also', ' are', ' together', ' rest', ' for', ' then', ' all', '\n', ' respectively', ' among', ',', ' head', ' others', ' on', ' do', ' alongside', ' the', ' in', ' before', ' its', ' along', ' of', ' &', ' to', ' let', ' out', ' but', ' other', ' who', ' still', ' however', ' without', ' continue', ' aside', ' now', ' about', ' group', ' over', ' with', ' it', ' again', ' go', ' help', ' away', ' from', ' And']                       │ [' Sarah', 'Sarah', ' Rebecca', ' Laura', ' are', ' Sara', ' Mary', ' and', ' is', ' Susan', ' (', ' Palin', ' Amanda', ',', ' We', ' Anna', ' She', ' Kate', ' n', ' of', ' can', ' lie', ' 2', ' Claire', ' Jessica', ' in', ' Stephen', ' us', ' 1', ' Jane', ' we', ' also', ' from', ' Carrie', ' to', '?', ' may', ' means', ' by', ' were', ' will', 's', ' Sue', ' she', ' 3', ' Wilson', ' Todd', ' Som', ' as', ' Amy']                                                           │ [' go', ' went', ' gone', ' Go', ' house', ' to', ' was', ' got', ' going', ' home', ' had', ' and', ' down', ' all', ' did', ' h', ' said', ' way', '.', ' name', ' came', ' thing', ' head', ' have', ',', ' business', ' word', ' do', ' left', ' be', ' were', ' come', ' no', ' been', ' where', ' for', ' goes', ' say', 'go', ' in', ' kind', '\n', ' on', 'Go', ' by', '-', ' hit', ' city', ' started', ' that']                                                                                    │ [' to', ' as', '\n', ' the', ' in', ' more', ' at', ' not', ' To', ' a', ' with', ' that', ' be', ' over', ' where', '<|endoftext|>', ' all', ' we', ' give', ' and', ' on', ' for', ' believe', ' because', ' less', ' who', ' it', ' $', ' 10', ' of', ' one', ',', ' among', ' what', '.', ' think', ' if', ' take', 'to', ' have', ' As', ' put', ' when', ' between', ' about', '—', ' "', ' under', ' come', ' out']                                                       │ [' the', ' more', ' to', '\n', ' The', ' a', ' no', ' as', ' over', ' less', ' all', ' not', ' on', ' in', ' and', ' it', ' that', ' 1', ' at', ' under', ',', ' none', '?', ' about', ' those', ' one', ' I', ' last', ' just', ' of', ' No', '...', ' 2', ' never', ' our', ' what', ' un', ' "', ' we', ' out', ' P', ' for', ' too', ' $', ' 3', ' this', '.', ' 30', ' B', ' up']                                                                                                                                                │ [' store', ' stores', ' shop', '\n', ' to', ' be', ' Store', ' the', ' retail', ' in', 'store', ' we', ' at', '<|endoftext|>', ' a', ',', ' and', '-', ' she', ' shopping', ' of', ' all', ' app', ' stop', ' place', ' warehouse', ' business', ' give', ' our', ' on', ' save', ' for', '...', ' sale', ' game', '.', ' buy', ' shall', ' get', ' any', ' department', ' make', ' sell', ' up', ' carry', ' that', ' out', ' her', ' home', ' free']                                                                   │ [',', '\n', '...', ' ...', ':', ' into', ',,', ' $', ' ,', ' Her', '.', ' She', ',"', ' in', '!', '?', ' out', '…', ' to', ' -', ' on', ' In', ' And', ' Nobody', '..."', ' Up', ' not', ' over', ' ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',']                                                                                                                                                                                                                                                                                                                                                              │ [' was', ' and', "'s", ' said', ' McCain']                                                                                                                                                                                                                                                                                                                                                                                                                                              │ [' I', ' his', ' Mary', ' John', ' the']                                                                                                                                                                                                                                                                                                                                                                                                                                                   │ [' were', ' had', ' are', "'s", ' have']                                                                                                                                                                                                                                                                                                                                                                                                                                                    │ [' to', ' out', ' into', ' back', ' on']                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ [' the', ' see', ' bed', ' church', ' a']                                                                                                                                                                                                                                                                                                                                                                                                                                        │ [' church', ' house', ' hospital', ' store', ' temple']                                                                                                                                                                                                                                                                                                                                                                                                                                                                               │ [',', ' to', ' and', ' on', ' in']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ [' they', ' John', ' the', ' Sarah', ' and']                                                                                                                                                        ...
# ╘════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...

# %% [markdown]
# see how there's when John and Mary went to church which is due to the association in the embeddings (I think)

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...
# │ When                                                                                                                                                                                                                                                                                                                                                                                           │  John                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │  and                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │  Mary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │  went                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │  to                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │  the                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                │  store                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │ ,                                                                                                                                                                             ...
# ╞════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' number', 'john', ' James', ' other', ' 1', ' john', ' j', ' male', ' JOHN', ' the', ' Joshua', ' man', ' who', ' of', ' Julian', ' as', ' Jack', ' others', ' and', ' 13', ' Robert', ' left', ' current', ' from', ',', ' Kh', ' in', ' Steve', ' men', ' Kev', 'JOHN', ' Matthew', ' secretary', '-', ' Chris', ' Johnson', ' Richard', ' Jonathan', ' name', ' "', ' Gregory', ' or', ' Mr', ' Christopher', ' we', ' right', ' al', ' a']                       │ [' and', ' all', ' to', ' so', ' as', ' both', ' at', ' &', ' /', ' more', ' also', ' ...', ' but', ' becoming', ' then', ' it', '\n', ',', ' open', ' path', ' the', ' And', ' even', ' a', ' not', ' end', ' this', '/', ' being', ' 1', ' completely', ' in', ' almost', ' All', ' "', ' I', ' everything', ']', ' other', ' become', ' ]', ' for', ' already', ' who', ' which', ' nearly', ' further', ' first', ' As', ' ultimately']                                                │ [' Mary', ' Martha', ' Maria', ' Sarah', 'Mary', ' Mother', ' John', ' Peter', ' Rebecca', ' Francis', ' James', ' Jesus', ' Robert', ' Elizabeth', ' Margaret', ' William', ' Catholic', ' Man', ' Joseph', ' Philip', ' Paul', ' Andrew', ' Yes', ' M', ' Thomas', ' Lady', ' Matthew', ' Mass', ' Anna', ' Anne', ' Catherine', ' My', ' of', ' Other', ' Miss', ' Henry', ' Susan', ' Stephen', ' Medical', ' Martin', '\n', ' Sara', ' Michael', ' Rachel', ' She', ' David', ' Mark', ' Nicholas', ' Brian', ' 1']     │ [' go', ' went', ' and', ' all', ' said', ' got', ' was', ' head', ' gone', ' talk', ' h', ' any', ' it', ' she', ' did', ' a', ' do', ' had', ' talked', ' in', ' be', ' just', ' I', ' no', ' every', ' the', ' saw', ',', ' on', ' one', ' anything', ' get', ' last', ' body', ' thing', ' have', ' for', ' heard', ' dead', ' hear', ' everything', ' to', ' as', ' this', ' whole', ' up', ' going', ' there', ' other', ' say']                                                                    │ [' to', ' online', '\n', ' all', ' trip', ' travel', ' shopping', ' and', ' in', ' more', ' with', ' visit', ' on', ' how', ' the', ' new', ' other', ' where', ' so', ' journey', ' site', ' business', ' I', ' as', ' day', ' traveling', ' my', ' much', ' or', ' time', ' home', ' a', ' full', ' it', ' list', ' website', ' top', ' main', ' what', ' destination', ' without', ' again', ' many', ' next', ' daily', ' of', ' going', ' when', ' way', ' long']           │ [' the', '\n', ' a', ' all', ' one', ' of', ' it', ' in', ' an', ' se', ' out', ' this', ' to', 'the', ' not', ' no', ' that', ' its', ' at', ' and', ' "', ' say', ' 1', ' end', ' The', ' said', ' hy', ' again', ' what', ' back', ' for', ',', ' on', ' be', ' another', ' yes', ' two', ' more', '\n\n', ' state', ' they', '<|endoftext|>', ' —', ' er', ' free', '-', ' other', ' you', ' def', " '"]                                                                                                                        │ [' store', ' stores', ' sho', ' shopping', '\n', ' mall', ' shop', ' warehouse', ' clerk', ' shoe', ' retail', ' retailer', ' department', ' clothing', ' end', ' business', ' &', ' stocking', ' carry', ' and', ' footwear', '-', ' Macy', ' lock', ' grocery', ' season', ' merchandise', ' stock', ' /', ' sales', ' storing', ' hair', ' as', ' storage', ',', ' fair', 'store', ' be', ' stop', ' day', ' shift', ' core', ' apparel', ' interior', ' center', ' early', ' full', ' keep', ' car', ' first'] │ [',', ' ,', '.', '\n', ';', ' and', '-', '.,', ' "', ' (', ',"', '!', ' Ed', ' No', ' in', ' all', ' the', ' City', ' I', ' of', ':', ' &', ' 1', ' B', ' for', ' .', ' or',  ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' 1', ' john', ' 2', ' Johns', ' Kev', 'john', ' Paul', ' JOHN', ' Kh', ' Kelly', ' Johnson', ' James', ' 13', '"', ' Robert', ' 112', ' Johnston', ' Num', ' Mr', ' Jon', ',', ' Re', ' the', ' number', ' j', ' R', ' King', ' Rob', ' K', ' 3', ' 11', ')', ' Gregory', '-', ' Ker', ' rh', ' secretary', ' Jack', ' Rory', ' wh', ' First', ' (', ' 12', ' N', ' McCl', ' 111', ' or', ' Secretary']                                                              │ [' and', ' both', ' all', ' to', ' as', ' being', ' it', ' also', ' be', ' a', ' if', ' even', ' completely', ' the', ' without', ' would', ' at', ' not', ' in', ' then', ' could', ' multiple', ' that', ' everything', ' but', ' other', ' any', ' entire', ' more', ' before', ' so', ' an', ',', ' you', ' nor', ' outright', ' already', ' end', ' including', ' instead', ' just', '/', ' or', ' self', ' while', ' its', ' from', ' second', ' itself', ' past']                   │ [' Mary', ' Mother', ' Martha', 'Mary', ' Maria', ' Sarah', ' John', ' Jesus', ' Catholic', ' Margaret', ' Peter', ' James', ' Lady', ' Joseph', ' Yes', ' Francis', ' Rebecca', ' Sara', ' Mass', ' Susan', ' Catherine', ' Mission', ' Paul', ' Holy', ' Matthew', ' Miss', ' M', ' Elizabeth', ' Robert', ' Marie', ' Mrs', ' Man', ' Saint', ' Queen', ' Medical', ' Anne', ' She', ' Lay', ' Philip', ' Father', ' Marvin', ' Thomas', ' Henry', ' May', ' William', ' Son', ' My', ' God', ' Marilyn', ' Other']       │ [' went', ' gone', ' go', ' all', ' and', ',', ' was', ' said', ' got', ' going', ' just', ' saw', ' talked', ' whole', ' heard', ' it', ' head', ' there', ' had', ' every', ' I', ' did', ' the', ' she', ' that', ' on', ' a', ' left', ' to', ' in', ' where', ' for', ' hit', ' no', ' very', ' what', ' everything', ' this', ' came', ' thing', ' with', ' last', ' way', "'s", ' pretty', ' or', '-', ' spoke', ' big', ' you']                                                                   │ [' to', ' all', ' a', ' every', ' it', ' online', ' how', ' where', ' straight', ' so', '\n', ' the', ' like', ' and', ' full', ' on', ' in', ' more', ' just', ' as', ' an', ' I', ' take', ' everything', ' many', ' of', ' much', ' taking', ' down', ' actually', ' completely', ' often', ' before', ' you', ' go', ' there', ' at', ' being', ' that', ' with', ' going', ' or', ' what', ' sitting', ' quickly', ' when', ' filled', ' across', ' having', ' this']       │ [' the', '\n', ' a', ' of', ' all', ' to', ' The', ' in', ' for', ' and', ' it', 'the', ' an', ' that', ' be', ' y', ',', "'", '-', ' one', ' this', ' its', ' you', ' b', ' first', ' as', ' se', '.', ' both', ' at', ' from', '<|endoftext|>', ' say', ' by', ' not', ' e', ' yes', ' I', ' o', ' have', ' over', ' no', ' so', ' two', ' each', ' means', ' z', ' 1', ' n', ' back']                                                                                                                                            │ [' store', ' stores', ' shopping', ' shop', ' mall', ' warehouse', ' storing', '\n', ' sho', ' and', ' department', ' hide', ' or', ' stop', ' carry', ' train', ' pre', ' stock', ' storage', ' business', ' clothing', ' retail', ' hold', ' shoe', ' /', ' clerk', ' concealed', ' state', ' game', ' &', '-', ' car', ' back', 'store', ' stored', ' trap', ',', ' fair', ' factory', ' all', ' retailer', ' home', ' open', ' closet', ' t', ' post', ' rest', ' ad', ' end', ' the']                         │ [',', ' and', ' ,', ',"', ' (', '.', '-', ' the', ' No', ' or', ' of', ' a', ' I', '/', ';', ' will', ' in', ' all', ' for', ' One', ' at', ' &', "'s", ' B', ' not', ' "', ' ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', ' john', ' JOHN', 'John', ' Johnson', ' maybe', ' Johnston', ' 1', ' Kelly', ' a', ' just', ' less', ' more', ' 2', ' its', ' back', ' al', ' j', ' why', ' po', ' Jonas', ' probably', ' Johns', ' God', ' wrong', ' Paul', ' language', ' king', ' Holy', ' Kh', ' reason', ' yes', ' kingdom', ' English', ' in', ' 10', ' holy', ' perhaps', ' 15', 'john', ' the', ' 13', ' sometimes', ' Richard', ' about', ' Nil', ' name', ' help', ' what', ' 3']                   │ [' and', '\n', ' then', ' And', ' it', ' ,', ' )', ' "', ' both', ' .', ' even', ' almost', ' the', ' before', ' a', ' when', ' that', ' in', ' all', ' during', ',', ' also', ' as', ' its', ' one', ' you', ' early', ' said', ' but', ' actually', ' later', ' /', ' this', ' I', ' after', ' not', ' no', ' there', '.', ' on', ' your', ' so', ' at', ' just', ' out', ' water', ' ;', ' footage', ' .)', ' became']                                                                  │ [' Mary', 'Mary', ' Martha', ' Mother', ' Jesus', ' John', ' Maria', ' Sarah', ' Catherine', ' Margaret', ' Catholic', ' Lady', ' Elizabeth', ' Thomas', ' Mass', ' Holy', ' Anne', ' Francis', ' Rebecca', ' Sara', ' Peter', ' Gabriel', ' James', ' Mission', ' Joseph', ' Saint', ' God', ' Matthew', ' Woman', ' Father', ' Bay', ' Christ', ' Lay', ' William', ' Marie', ' Queen', ' Miss', ' Marvin', ' Anna', ' Paul', ' and', ' Luke', '\n', ' Church', ' Massachusetts', ' of', ' M', ' Mason', ' Man', ' Henry'] │ [' go', ' gone', ' went', ' all', ' got', ' she', ' just', ' come', ' I', ' and', ' do', ' you', ' going', ' get', ' there', ' will', ' it', ' run', ' have', ' goes', ' a', ' everything', ' anything', ' every', ' maybe', ' left', ' next', ' that', ' no', ' did', ' be', ' had', ' head', ' was', ' right', ' home', ' said', ' one', ' Go', ' big', ' good', ' say', ' thing', ' start', ' show', ' stuff', ' any', ' the', ' didn', ' to']                                                         │ [' to', ' more', ' at', ' one', ' all', ' a', ' up', ' just', ' as', ' in', ' on', ' not', ' you', ' almost', ' I', ' over', '\n', ' "', ' without', ' the', ' simply', ' nearly', ' no', ' her', ' every', ' straight', ' un', ' about', ' changes', ' beside', ' less', ' before', ' your', ' an', ' for', ' down', ' full', ' added', ' it', ' when', ' this', ' here', ' per', ' me', ' days', ' my', ' completely', ' can', ' taken', ' that']                              │ ['\n', ' the', ' a', ' and', ' I', ' for', ' in', ',', ' yes', ' to', '?', ' as', ' at', ' but', ' it', ' then', ' not', ' over', ' all', ' on', ' first', ' more', ' before', ' The', ' part', ' one', ' now', ' no', ' 1', ' from', ' when', ' we', ' my', ' of', ' out', ' an', ' until', ' fill', ' what', '.', ' said', ' through', ' that', ' each', ' its', ' if', ' n', ' 2', ' last', ' till']                                                                                                                             │ [' store', ' stores', '\n', ' shop', ' warehouse', ' local', ' sho', 'store', ' location', ' Store', '<|endoftext|>', ' stop', ' mall', ' online', ' hide', ' sell', ' shopping', ' stock', ' retail', ' fast', ' pre', ' department', ' train', ' city', ' buy', ' app', ' general', ' start', ' shoe', ' carry', ' in', ' keep', ' post', ' to', ' market', ' place', ' game', ' save', ' park', ' track', ' get', ' site', ' area', ' state', ' demo', ' h', ' car', ' sh', ' hid', 'Store']                    │ [',', '\n', '—', ' —', ' ,', ',"', '.', ' --', ' be', ':', ' in', ' and', ' "', ';', ' to', ' at', ' that', ' begin', ' And', ' she', ' I', ' this', ' –', ' is', '…', ' go', ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' JOHN', ' john', ' Lennon', ' Robert', ' Paul', ',', ' j', ' his', ' Johnson', ' Jon', ' 1', '-', 'john', ' Johnston', ' James', 'JOHN', ' William', ' 11', ' Richard', ' Jeff', ' 13', ' Ted', ' Kyle', ' 10', ' Rex', ' 17', ' ...', ' Michael', ' son', ' Julian', ' Mike', ' Henry', ' [', ' 16', ' L', ' Daniel', ' Bob', ' and', ' 15', ' man', ' Joshua', ' J', ' Jake', ' he', ' 23', ' Jr', ' the', ' George']                                              │ [' and', ' both', ' while', ' as', ' also', ' are', ' together', ' rest', ' for', ' then', ' all', '\n', ' respectively', ' among', ',', ' head', ' others', ' on', ' do', ' alongside', ' the', ' in', ' before', ' its', ' along', ' of', ' &', ' to', ' let', ' out', ' but', ' other', ' who', ' still', ' however', ' without', ' continue', ' aside', ' now', ' about', ' group', ' over', ' with', ' it', ' again', ' go', ' help', ' away', ' from', ' And']                       │ [' Mary', 'Mary', ' Mother', ' Martha', ' Anne', ' Margaret', 'mary', ' Sarah', ' Sara', ' Catherine', ' Maria', ' Jesus', ' Lady', ' and', ' Jane', ' Marie', ' Marilyn', ' Holy', ' Anna', ' Catholic', ' (', ' Elizabeth', ' her', ' of', ' John', ',', ' Christ', ' —', ' Rebecca', ' Abbey', ' Carrie', ' are', ' may', ' she', ' Ann', ' God', ' were', ' is', ' Joseph', ' mother', ' Queen', '-', ' Marg', ' Henry', ' Mah', ' May', ' Hail', ' Mrs', ' Lily', ' \xad']                                              │ [' go', ' went', ' gone', ' Go', ' house', ' to', ' was', ' and', ' going', ' got', ' home', ' said', ' down', ' did', ' all', ' name', ' had', '.', ' say', ' head', ' came', ',', ' do', ' thing', ' be', ' h', ' word', ' way', ' come', ' business', ' left', ' by', ' where', ' in', ' have', ' on', ' for', ' were', ' of', ' no', 'go', ' that', ' city', ' kind', ' a', ' out', "'s", ' w', ' took', ' off']                                                                                      │ [' to', ' as', ' the', ' in', '\n', ' not', ' be', ' more', ' a', ' To', ' with', ' all', ' at', ' that', ' where', '<|endoftext|>', ' we', ' give', ' believe', ' and', ' who', ' for', ' it', ' on', ' over', ',', ' because', ' what', ' have', ' less', ' of', ' think', ' put', ' one', '.', ' come', ' take', ' if', ' is', ' $', ' yes', ' 10', ' make', 'to', ' "', ' about', ' among', ' this', ' do', '—']                                                             │ [' the', ' more', ' to', '\n', ' no', ' a', ' as', ' The', ' over', ' less', ' not', ' all', ' it', ' and', ' in', ' that', ' none', ' under', ' at', ' on', ',', ' just', '?', ' 1', ' those', ' I', ' about', ' un', ' too', ' one', ' of', ' what', ' last', ' never', ' out', ' "', ' our', ' this', ' we', '...', ' for', ' 2', ' No', ' up', ' when', ' so', '.', ' things', ' people', ' every']                                                                                                                             │ [' store', ' stores', '\n', ' shop', ' to', ' be', ' the', ' we', ' in', '<|endoftext|>', ' a', ' Store', ' at', ' and', ',', ' she', '-', ' of', ' all', ' warehouse', ' stop', ' retail', 'store', ' save', ' business', ' our', ' shopping', ' on', ' app', '...', '.', ' place', ' up', ' that', ' sell', ' get', ' for', ' sale', ' out', ' give', ' game', ' buy', ' stock', ' carry', ' make', ' ab', ' by', ' any', ' t', ' department']                                                                   │ [',', '\n', '...', ' ...', ' into', ':', ' $', ' Her', ',,', ' ,', '.', ' out', ' in', ' She', ',"', '!', ' to', '…', '?', ' on', ' not', ' -', '..."', ' Nobody', '--', ' ov ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',']                                                                                                                                                                                                                                                                                                                                                              │ [' was', ' and', "'s", ' said', ' McCain']                                                                                                                                                                                                                                                                                                                                                                                                                                              │ [' I', ' his', ' Mary', ' John', ' the']                                                                                                                                                                                                                                                                                                                                                                                                                                                   │ [' were', "'s", ' had', ' went', ' are']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ [' to', ' out', ' into', ' back', ' on']                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ [' the', ' see', ' church', ' bed', ' visit']                                                                                                                                                                                                                                                                                                                                                                                                                                    │ [' church', ' house', ' temple', ' Church', ' store']                                                                                                                                                                                                                                                                                                                                                                                                                                                                               │ [',', ' to', ' and', ' in', ' on']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ [' they', ' John', ' Mary', ' the', ' and']                                                                                                                                   ...
# ╘════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...

# %% [markdown]
# generations on hook_resid_pre

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...
# │ When                                                                                                                                                                                                                                                                                                                                                                                           │  John                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │  and                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │  Mary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │  went                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │  to                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │  the                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           │  store                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │ ,                                                                                                                                                                                                        ...
# ╞════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' number', ' and', ',', ' the', ' other', ' or', ' in', ' of', ' from', '-', ' "', ')', ' who', ' James', ' as', ' right', ' male', 'john', ' (', ' j', ' man', ' a', ' john', ' name', ' good', ' among', ' Johnston', ' 1', ' al', ' others', ' Kelly', ' next', ' to', ' enemy', ' left', ' what', ' JOHN', ' his', ' key', ' secretary', ' I', ' current', ' previous', ' front', ' we', ' fellow', ' remaining', ' Robert']                                      │ [' and', ' to', ' so', ' all', ' yet', ' then', ' more', ' this', ' as', ' but', ' at', ' for', ' even', ' /', ' 1', ' ...', ' now', '\n', ',', ' not', ' of', ' both', ' until', ' be', ' —', ' the', ' in', ' a', ' (', ' -', ' on', ' still', ' next', ']', ' open', ' I', ' "', ' 3', ' it', ' how', ' or', ' 2', ' who', ' already', ' remaining', ' –', ' just', ' other', ' we', '/']                                                                                               │ [' Mary', ' Martha', ' John', ' Mother', ' Catholic', ' Jesus', 'Mary', ' Sarah', ' Francis', ' a', ' Maria', ' of', ' M', ' Peter', ' Man', ' m', ' James', ' William', ' Saint', ' Anna', ' My', ' Margaret', ' Mass', ' Mad', ' Nan', ' Moh', ' my', ' Brian', ' Philip', ' Medical', ' Robert', ' Bay', ' Miss', ' Mc', ' Mont', ' Holy', ' Paul', ' Rebecca', ' Elizabeth', ' Catherine', ' Brown', ' Mah', '-', ' Thomas', ' Stephen', ' Al', ' Marie', ' Say', ' Joseph', ' Ab']                                      │ [' all', ' go', ' went', ' it', ' and', ' the', ' was', ',', ' have', ' that', ' had', ' they', ' this', ' there', ' be', ' just', ' you', ' will', ' any', ' gone', ' or', ' a', ' did', ' every', ' in', ' for', ' saw', ' these', ' to', ' said', ' what', ' got', ' do', ' as', ' "', ' even', ' were', ' say', ' g', ' people', ' she', ' we', ' of', ' could', ' like', ' should', ' how', ' left', ' with', ' anything']                                                                           │ [' to', ' more', ' all', ' online', '\n', ' in', ' so', ' it', ' journey', ' new', ' with', ' how', ' home', ' again', ' now', ' on', ' time', ' less', ' finally', ' a', ' the', ' as', ' and', '<|endoftext|>', ' much', ' where', ' tr', ' what', ' taking', ' started', ' part', ' me', ' everything', ' other', ' straight', ' everyday', ' I', ' my', ' when', ' process', ' really', ' c', ' whole', ' up', ' every', ' together', ' day', ' out', ' trip', ' of']  │ [' the', ' all', " '", '\n', ' a', "'", ' I', 'the', ' in', ' one', ' se', ' this', ' be', ' it', ' an', ' parts', ' no', ' what', ' fall', ' of', ' say', ' out', ' to', ',', ' each', ' they', '"', ' you', ' my', ' more', ' at', ' that', ' we', ' those', ' me', ' The', ' would', ' become', ' u', ' state', ' people', ' your', '\'"', ' 1', ' "', ' these', ' back', ' yes', ' ah', ' hy']                                                                                                             │ [' store', ' stores', '\n', ' shopping', ' as', 'store', ' sho', ' shop', ' season', ' be', ' album', '<|endoftext|>', ' a', ' shoe', ' sales', ' end', ' card', ' artist', ' clerk', ' retailer', ' retail', ' first', ' carry', ' year', ' product', ' stop', ' storing', ' app', ' all', ' cart', ' start', ' buy', ' mall', ' Store', ' the', '-', ' fit', ' department', ' ad', ' stock', ' sell', ' hold', ' messenger', ' can', ' in', ' center', ' release', ' well', ' and', ' city']                     │ [',', ' and', ',,', ' however', '.', '\n', ' Jr', '/', ' (', ';', ' ,', '-', ' &', ' again', ' I', ' at', ' D', '(', ',"', ' May', ' but', ' "', ' the', ' 5', ' then', '.,', ' Law', ' 1', ' One', ' 2' ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' number', 'john', ' James', ' other', ' 1', ' john', ' j', ' male', ' JOHN', ' the', ' Joshua', ' man', ' who', ' of', ' Julian', ' as', ' Jack', ' others', ' and', ' 13', ' Robert', ' left', ' current', ' from', ',', ' Kh', ' in', ' Steve', ' men', ' Kev', 'JOHN', ' Matthew', ' secretary', '-', ' Chris', ' Johnson', ' Richard', ' Jonathan', ' name', ' "', ' Gregory', ' or', ' Mr', ' Christopher', ' we', ' right', ' al', ' a']                       │ [' and', ' all', ' to', ' so', ' as', ' both', ' at', ' &', ' /', ' more', ' also', ' ...', ' but', ' becoming', ' then', ' it', '\n', ',', ' open', ' path', ' the', ' And', ' even', ' a', ' not', ' end', ' this', '/', ' being', ' 1', ' completely', ' in', ' almost', ' All', ' "', ' I', ' everything', ']', ' other', ' become', ' ]', ' for', ' already', ' who', ' which', ' nearly', ' further', ' first', ' As', ' ultimately']                                                │ [' Mary', ' Martha', ' Maria', ' Sarah', 'Mary', ' Mother', ' John', ' Peter', ' Rebecca', ' Francis', ' James', ' Jesus', ' Robert', ' Elizabeth', ' Margaret', ' William', ' Catholic', ' Man', ' Joseph', ' Philip', ' Paul', ' Andrew', ' Yes', ' M', ' Thomas', ' Lady', ' Matthew', ' Mass', ' Anna', ' Anne', ' Catherine', ' My', ' of', ' Other', ' Miss', ' Henry', ' Susan', ' Stephen', ' Medical', ' Martin', '\n', ' Sara', ' Michael', ' Rachel', ' She', ' David', ' Mark', ' Nicholas', ' Brian', ' 1']     │ [' go', ' went', ' and', ' all', ' said', ' got', ' was', ' head', ' gone', ' talk', ' h', ' any', ' it', ' she', ' did', ' a', ' do', ' had', ' talked', ' in', ' be', ' just', ' I', ' no', ' every', ' the', ' saw', ',', ' on', ' one', ' anything', ' get', ' last', ' body', ' thing', ' have', ' for', ' heard', ' dead', ' hear', ' everything', ' to', ' as', ' this', ' whole', ' up', ' going', ' there', ' other', ' say']                                                                    │ [' to', ' online', '\n', ' all', ' trip', ' travel', ' shopping', ' and', ' in', ' more', ' with', ' visit', ' on', ' how', ' the', ' new', ' other', ' where', ' so', ' journey', ' site', ' business', ' I', ' as', ' day', ' traveling', ' my', ' much', ' or', ' time', ' home', ' a', ' full', ' it', ' list', ' website', ' top', ' main', ' what', ' destination', ' without', ' again', ' many', ' next', ' daily', ' of', ' going', ' when', ' way', ' long']     │ [' the', '\n', ' a', ' all', ' one', ' of', ' it', ' in', ' an', ' se', ' out', ' this', ' to', 'the', ' not', ' no', ' that', ' its', ' at', ' and', ' "', ' say', ' 1', ' end', ' The', ' said', ' hy', ' again', ' what', ' back', ' for', ',', ' on', ' be', ' another', ' yes', ' two', ' more', '\n\n', ' state', ' they', '<|endoftext|>', ' —', ' er', ' free', '-', ' other', ' you', ' def', " '"]                                                                                                   │ [' store', ' stores', ' sho', ' shopping', '\n', ' mall', ' shop', ' warehouse', ' clerk', ' shoe', ' retail', ' retailer', ' department', ' clothing', ' end', ' business', ' &', ' stocking', ' carry', ' and', ' footwear', '-', ' Macy', ' lock', ' grocery', ' season', ' merchandise', ' stock', ' /', ' sales', ' storing', ' hair', ' as', ' storage', ',', ' fair', 'store', ' be', ' stop', ' day', ' shift', ' core', ' apparel', ' interior', ' center', ' early', ' full', ' keep', ' car', ' first'] │ [',', ' ,', '.', '\n', ';', ' and', '-', '.,', ' "', ' (', ',"', '!', ' Ed', ' No', ' in', ' all', ' the', ' City', ' I', ' of', ':', ' &', ' 1', ' B', ' for', ' .', ' or', '!,', ' A', '?', ' All', ', ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' 1', ' john', ' 2', ' Johns', ' Kev', 'john', ' Paul', ' JOHN', ' Kh', ' Kelly', ' Johnson', ' James', ' 13', '"', ' Robert', ' 112', ' Johnston', ' Num', ' Mr', ' Jon', ',', ' Re', ' the', ' number', ' j', ' R', ' King', ' Rob', ' K', ' 3', ' 11', ')', ' Gregory', '-', ' Ker', ' rh', ' secretary', ' Jack', ' Rory', ' wh', ' First', ' (', ' 12', ' N', ' McCl', ' 111', ' or', ' Secretary']                                                              │ [' and', ' both', ' all', ' to', ' as', ' being', ' it', ' also', ' be', ' a', ' if', ' even', ' completely', ' the', ' without', ' would', ' at', ' not', ' in', ' then', ' could', ' multiple', ' that', ' everything', ' but', ' other', ' any', ' entire', ' more', ' before', ' so', ' an', ',', ' you', ' nor', ' outright', ' already', ' end', ' including', ' instead', ' just', '/', ' or', ' self', ' while', ' its', ' from', ' second', ' itself', ' past']                   │ [' Mary', ' Mother', ' Martha', 'Mary', ' Maria', ' Sarah', ' John', ' Jesus', ' Catholic', ' Margaret', ' Peter', ' James', ' Lady', ' Joseph', ' Yes', ' Francis', ' Rebecca', ' Sara', ' Mass', ' Susan', ' Catherine', ' Mission', ' Paul', ' Holy', ' Matthew', ' Miss', ' M', ' Elizabeth', ' Robert', ' Marie', ' Mrs', ' Man', ' Saint', ' Queen', ' Medical', ' Anne', ' She', ' Lay', ' Philip', ' Father', ' Marvin', ' Thomas', ' Henry', ' May', ' William', ' Son', ' My', ' God', ' Marilyn', ' Other']       │ [' went', ' gone', ' go', ' all', ' and', ',', ' was', ' said', ' got', ' going', ' just', ' saw', ' talked', ' whole', ' heard', ' it', ' head', ' there', ' had', ' every', ' I', ' did', ' the', ' she', ' that', ' on', ' a', ' left', ' to', ' in', ' where', ' for', ' hit', ' no', ' very', ' what', ' everything', ' this', ' came', ' thing', ' with', ' last', ' way', "'s", ' pretty', ' or', '-', ' spoke', ' big', ' you']                                                                   │ [' to', ' all', ' a', ' every', ' it', ' online', ' how', ' where', ' straight', ' so', '\n', ' the', ' like', ' and', ' full', ' on', ' in', ' more', ' just', ' as', ' an', ' I', ' take', ' everything', ' many', ' of', ' much', ' taking', ' down', ' actually', ' completely', ' often', ' before', ' you', ' go', ' there', ' at', ' being', ' that', ' with', ' going', ' or', ' what', ' sitting', ' quickly', ' when', ' filled', ' across', ' having', ' this'] │ [' the', '\n', ' a', ' of', ' all', ' to', ' The', ' in', ' for', ' and', ' it', 'the', ' an', ' that', ' be', ' y', ',', "'", '-', ' one', ' this', ' its', ' you', ' b', ' first', ' as', ' se', '.', ' both', ' at', ' from', '<|endoftext|>', ' say', ' by', ' not', ' e', ' yes', ' I', ' o', ' have', ' over', ' no', ' so', ' two', ' each', ' means', ' z', ' 1', ' n', ' back']                                                                                                                       │ [' store', ' stores', ' shopping', ' shop', ' mall', ' warehouse', ' storing', '\n', ' sho', ' and', ' department', ' hide', ' or', ' stop', ' carry', ' train', ' pre', ' stock', ' storage', ' business', ' clothing', ' retail', ' hold', ' shoe', ' /', ' clerk', ' concealed', ' state', ' game', ' &', '-', ' car', ' back', 'store', ' stored', ' trap', ',', ' fair', ' factory', ' all', ' retailer', ' home', ' open', ' closet', ' t', ' post', ' rest', ' ad', ' end', ' the']                         │ [',', ' and', ' ,', ',"', ' (', '.', '-', ' the', ' No', ' or', ' of', ' a', ' I', '/', ';', ' will', ' in', ' all', ' for', ' One', ' at', ' &', "'s", ' B', ' not', ' "', ' A', ' as', ' one', ' D', ' ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', ' john', ' JOHN', 'John', ' Johnson', ' maybe', ' Johnston', ' 1', ' Kelly', ' a', ' just', ' less', ' more', ' 2', ' its', ' back', ' al', ' j', ' why', ' po', ' Jonas', ' probably', ' Johns', ' God', ' wrong', ' Paul', ' language', ' king', ' Holy', ' Kh', ' reason', ' yes', ' kingdom', ' English', ' in', ' 10', ' holy', ' perhaps', ' 15', 'john', ' the', ' 13', ' sometimes', ' Richard', ' about', ' Nil', ' name', ' help', ' what', ' 3']                   │ [' and', '\n', ' then', ' And', ' it', ' ,', ' )', ' "', ' both', ' .', ' even', ' almost', ' the', ' before', ' a', ' when', ' that', ' in', ' all', ' during', ',', ' also', ' as', ' its', ' one', ' you', ' early', ' said', ' but', ' actually', ' later', ' /', ' this', ' I', ' after', ' not', ' no', ' there', '.', ' on', ' your', ' so', ' at', ' just', ' out', ' water', ' ;', ' footage', ' .)', ' became']                                                                  │ [' Mary', 'Mary', ' Martha', ' Mother', ' Jesus', ' John', ' Maria', ' Sarah', ' Catherine', ' Margaret', ' Catholic', ' Lady', ' Elizabeth', ' Thomas', ' Mass', ' Holy', ' Anne', ' Francis', ' Rebecca', ' Sara', ' Peter', ' Gabriel', ' James', ' Mission', ' Joseph', ' Saint', ' God', ' Matthew', ' Woman', ' Father', ' Bay', ' Christ', ' Lay', ' William', ' Marie', ' Queen', ' Miss', ' Marvin', ' Anna', ' Paul', ' and', ' Luke', '\n', ' Church', ' Massachusetts', ' of', ' M', ' Mason', ' Man', ' Henry'] │ [' go', ' gone', ' went', ' all', ' got', ' she', ' just', ' come', ' I', ' and', ' do', ' you', ' going', ' get', ' there', ' will', ' it', ' run', ' have', ' goes', ' a', ' everything', ' anything', ' every', ' maybe', ' left', ' next', ' that', ' no', ' did', ' be', ' had', ' head', ' was', ' right', ' home', ' said', ' one', ' Go', ' big', ' good', ' say', ' thing', ' start', ' show', ' stuff', ' any', ' the', ' didn', ' to']                                                         │ [' to', ' more', ' at', ' one', ' all', ' a', ' up', ' just', ' as', ' in', ' on', ' not', ' you', ' almost', ' I', ' over', '\n', ' "', ' without', ' the', ' simply', ' nearly', ' no', ' her', ' every', ' straight', ' un', ' about', ' changes', ' beside', ' less', ' before', ' your', ' an', ' for', ' down', ' full', ' added', ' it', ' when', ' this', ' here', ' per', ' me', ' days', ' my', ' completely', ' can', ' taken', ' that']                        │ ['\n', ' the', ' a', ' and', ' I', ' for', ' in', ',', ' yes', ' to', '?', ' as', ' at', ' but', ' it', ' then', ' not', ' over', ' all', ' on', ' first', ' more', ' before', ' The', ' part', ' one', ' now', ' no', ' 1', ' from', ' when', ' we', ' my', ' of', ' out', ' an', ' until', ' fill', ' what', '.', ' said', ' through', ' that', ' each', ' its', ' if', ' n', ' 2', ' last', ' till']                                                                                                        │ [' store', ' stores', '\n', ' shop', ' warehouse', ' local', ' sho', 'store', ' location', ' Store', '<|endoftext|>', ' stop', ' mall', ' online', ' hide', ' sell', ' shopping', ' stock', ' retail', ' fast', ' pre', ' department', ' train', ' city', ' buy', ' app', ' general', ' start', ' shoe', ' carry', ' in', ' keep', ' post', ' to', ' market', ' place', ' game', ' save', ' park', ' track', ' get', ' site', ' area', ' state', ' demo', ' h', ' car', ' sh', ' hid', 'Store']                    │ [',', '\n', '—', ' —', ' ,', ',"', '.', ' --', ' be', ':', ' in', ' and', ' "', ';', ' to', ' at', ' that', ' begin', ' And', ' she', ' I', ' this', ' –', ' is', '…', ' go', ' take', ' have', ' was',  ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',']                                                                                                                                                                                                                                                                                                                                                              │ [' was', ' and', "'s", ' said', ' McCain']                                                                                                                                                                                                                                                                                                                                                                                                                                              │ [' I', ' his', ' Mary', ' John', ' the']                                                                                                                                                                                                                                                                                                                                                                                                                                                   │ [' were', "'s", ' had', ' went', ' are']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ [' to', ' out', ' into', ' back', ' on']                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ [' the', ' see', ' church', ' bed', ' visit']                                                                                                                                                                                                                                                                                                                                                                                                                              │ [' church', ' house', ' temple', ' Church', ' store']                                                                                                                                                                                                                                                                                                                                                                                                                                                          │ [',', ' to', ' and', ' in', ' on']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ [' they', ' John', ' Mary', ' the', ' and']                                                                                                                                                              ...
# ╘════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...
# │ When                                                                                                                                                                                                                                                                                                                                                                                           │  John                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │  and                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │  Mary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │  went                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │  to                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │  the                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           │  store                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │ ,                                                                                                                                                                                                        ...
# ╞════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' number', ' and', ',', ' the', ' other', ' or', ' in', ' of', ' from', '-', ' "', ')', ' who', ' James', ' as', ' right', ' male', 'john', ' (', ' j', ' man', ' a', ' john', ' name', ' good', ' among', ' Johnston', ' 1', ' al', ' others', ' Kelly', ' next', ' to', ' enemy', ' left', ' what', ' JOHN', ' his', ' key', ' secretary', ' I', ' current', ' previous', ' front', ' we', ' fellow', ' remaining', ' Robert']                                      │ [' and', ' to', ' so', ' all', ' yet', ' then', ' more', ' this', ' as', ' but', ' at', ' for', ' even', ' /', ' 1', ' ...', ' now', '\n', ',', ' not', ' of', ' both', ' until', ' be', ' —', ' the', ' in', ' a', ' (', ' -', ' on', ' still', ' next', ']', ' open', ' I', ' "', ' 3', ' it', ' how', ' or', ' 2', ' who', ' already', ' remaining', ' –', ' just', ' other', ' we', '/']                                                                                               │ [' Mary', ' Martha', ' John', ' Mother', ' Catholic', ' Jesus', 'Mary', ' Sarah', ' Francis', ' a', ' Maria', ' of', ' M', ' Peter', ' Man', ' m', ' James', ' William', ' Saint', ' Anna', ' My', ' Margaret', ' Mass', ' Mad', ' Nan', ' Moh', ' my', ' Brian', ' Philip', ' Medical', ' Robert', ' Bay', ' Miss', ' Mc', ' Mont', ' Holy', ' Paul', ' Rebecca', ' Elizabeth', ' Catherine', ' Brown', ' Mah', '-', ' Thomas', ' Stephen', ' Al', ' Marie', ' Say', ' Joseph', ' Ab']                                      │ [' all', ' go', ' went', ' it', ' and', ' the', ' was', ',', ' have', ' that', ' had', ' they', ' this', ' there', ' be', ' just', ' you', ' will', ' any', ' gone', ' or', ' a', ' did', ' every', ' in', ' for', ' saw', ' these', ' to', ' said', ' what', ' got', ' do', ' as', ' "', ' even', ' were', ' say', ' g', ' people', ' she', ' we', ' of', ' could', ' like', ' should', ' how', ' left', ' with', ' anything']                                                                           │ [' to', ' more', ' all', ' online', '\n', ' in', ' so', ' it', ' journey', ' new', ' with', ' how', ' home', ' again', ' now', ' on', ' time', ' less', ' finally', ' a', ' the', ' as', ' and', '<|endoftext|>', ' much', ' where', ' tr', ' what', ' taking', ' started', ' part', ' me', ' everything', ' other', ' straight', ' everyday', ' I', ' my', ' when', ' process', ' really', ' c', ' whole', ' up', ' every', ' together', ' day', ' out', ' trip', ' of']  │ [' the', ' all', " '", '\n', ' a', "'", ' I', 'the', ' in', ' one', ' se', ' this', ' be', ' it', ' an', ' parts', ' no', ' what', ' fall', ' of', ' say', ' out', ' to', ',', ' each', ' they', '"', ' you', ' my', ' more', ' at', ' that', ' we', ' those', ' me', ' The', ' would', ' become', ' u', ' state', ' people', ' your', '\'"', ' 1', ' "', ' these', ' back', ' yes', ' ah', ' hy']                                                                                                             │ [' store', ' stores', '\n', ' shopping', ' as', 'store', ' sho', ' shop', ' season', ' be', ' album', '<|endoftext|>', ' a', ' shoe', ' sales', ' end', ' card', ' artist', ' clerk', ' retailer', ' retail', ' first', ' carry', ' year', ' product', ' stop', ' storing', ' app', ' all', ' cart', ' start', ' buy', ' mall', ' Store', ' the', '-', ' fit', ' department', ' ad', ' stock', ' sell', ' hold', ' messenger', ' can', ' in', ' center', ' release', ' well', ' and', ' city']                     │ [',', ' and', ',,', ' however', '.', '\n', ' Jr', '/', ' (', ';', ' ,', '-', ' &', ' again', ' I', ' at', ' D', '(', ',"', ' May', ' but', ' "', ' the', ' 5', ' then', '.,', ' Law', ' 1', ' One', ' 2' ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' number', 'john', ' James', ' other', ' 1', ' john', ' j', ' male', ' JOHN', ' the', ' Joshua', ' man', ' who', ' of', ' Julian', ' as', ' Jack', ' others', ' and', ' 13', ' Robert', ' left', ' current', ' from', ',', ' Kh', ' in', ' Steve', ' men', ' Kev', 'JOHN', ' Matthew', ' secretary', '-', ' Chris', ' Johnson', ' Richard', ' Jonathan', ' name', ' "', ' Gregory', ' or', ' Mr', ' Christopher', ' we', ' right', ' al', ' a']                       │ [' and', ' all', ' to', ' so', ' as', ' both', ' at', ' &', ' /', ' more', ' also', ' ...', ' but', ' becoming', ' then', ' it', '\n', ',', ' open', ' path', ' the', ' And', ' even', ' a', ' not', ' end', ' this', '/', ' being', ' 1', ' completely', ' in', ' almost', ' All', ' "', ' I', ' everything', ']', ' other', ' become', ' ]', ' for', ' already', ' who', ' which', ' nearly', ' further', ' first', ' As', ' ultimately']                                                │ [' Mary', ' Martha', ' Maria', ' Sarah', 'Mary', ' Mother', ' John', ' Peter', ' Rebecca', ' Francis', ' James', ' Jesus', ' Robert', ' Elizabeth', ' Margaret', ' William', ' Catholic', ' Man', ' Joseph', ' Philip', ' Paul', ' Andrew', ' Yes', ' M', ' Thomas', ' Lady', ' Matthew', ' Mass', ' Anna', ' Anne', ' Catherine', ' My', ' of', ' Other', ' Miss', ' Henry', ' Susan', ' Stephen', ' Medical', ' Martin', '\n', ' Sara', ' Michael', ' Rachel', ' She', ' David', ' Mark', ' Nicholas', ' Brian', ' 1']     │ [' go', ' went', ' and', ' all', ' said', ' got', ' was', ' head', ' gone', ' talk', ' h', ' any', ' it', ' she', ' did', ' a', ' do', ' had', ' talked', ' in', ' be', ' just', ' I', ' no', ' every', ' the', ' saw', ',', ' on', ' one', ' anything', ' get', ' last', ' body', ' thing', ' have', ' for', ' heard', ' dead', ' hear', ' everything', ' to', ' as', ' this', ' whole', ' up', ' going', ' there', ' other', ' say']                                                                    │ [' to', ' online', '\n', ' all', ' trip', ' travel', ' shopping', ' and', ' in', ' more', ' with', ' visit', ' on', ' how', ' the', ' new', ' other', ' where', ' so', ' journey', ' site', ' business', ' I', ' as', ' day', ' traveling', ' my', ' much', ' or', ' time', ' home', ' a', ' full', ' it', ' list', ' website', ' top', ' main', ' what', ' destination', ' without', ' again', ' many', ' next', ' daily', ' of', ' going', ' when', ' way', ' long']     │ [' the', '\n', ' a', ' all', ' one', ' of', ' it', ' in', ' an', ' se', ' out', ' this', ' to', 'the', ' not', ' no', ' that', ' its', ' at', ' and', ' "', ' say', ' 1', ' end', ' The', ' said', ' hy', ' again', ' what', ' back', ' for', ',', ' on', ' be', ' another', ' yes', ' two', ' more', '\n\n', ' state', ' they', '<|endoftext|>', ' —', ' er', ' free', '-', ' other', ' you', ' def', " '"]                                                                                                   │ [' store', ' stores', ' sho', ' shopping', '\n', ' mall', ' shop', ' warehouse', ' clerk', ' shoe', ' retail', ' retailer', ' department', ' clothing', ' end', ' business', ' &', ' stocking', ' carry', ' and', ' footwear', '-', ' Macy', ' lock', ' grocery', ' season', ' merchandise', ' stock', ' /', ' sales', ' storing', ' hair', ' as', ' storage', ',', ' fair', 'store', ' be', ' stop', ' day', ' shift', ' core', ' apparel', ' interior', ' center', ' early', ' full', ' keep', ' car', ' first'] │ [',', ' ,', '.', '\n', ';', ' and', '-', '.,', ' "', ' (', ',"', '!', ' Ed', ' No', ' in', ' all', ' the', ' City', ' I', ' of', ':', ' &', ' 1', ' B', ' for', ' .', ' or', '!,', ' A', '?', ' All', ', ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', 'John', ' 1', ' john', ' 2', ' Johns', ' Kev', 'john', ' Paul', ' JOHN', ' Kh', ' Kelly', ' Johnson', ' James', ' 13', '"', ' Robert', ' 112', ' Johnston', ' Num', ' Mr', ' Jon', ',', ' Re', ' the', ' number', ' j', ' R', ' King', ' Rob', ' K', ' 3', ' 11', ')', ' Gregory', '-', ' Ker', ' rh', ' secretary', ' Jack', ' Rory', ' wh', ' First', ' (', ' 12', ' N', ' McCl', ' 111', ' or', ' Secretary']                                                              │ [' and', ' both', ' all', ' to', ' as', ' being', ' it', ' also', ' be', ' a', ' if', ' even', ' completely', ' the', ' without', ' would', ' at', ' not', ' in', ' then', ' could', ' multiple', ' that', ' everything', ' but', ' other', ' any', ' entire', ' more', ' before', ' so', ' an', ',', ' you', ' nor', ' outright', ' already', ' end', ' including', ' instead', ' just', '/', ' or', ' self', ' while', ' its', ' from', ' second', ' itself', ' past']                   │ [' Mary', ' Mother', ' Martha', 'Mary', ' Maria', ' Sarah', ' John', ' Jesus', ' Catholic', ' Margaret', ' Peter', ' James', ' Lady', ' Joseph', ' Yes', ' Francis', ' Rebecca', ' Sara', ' Mass', ' Susan', ' Catherine', ' Mission', ' Paul', ' Holy', ' Matthew', ' Miss', ' M', ' Elizabeth', ' Robert', ' Marie', ' Mrs', ' Man', ' Saint', ' Queen', ' Medical', ' Anne', ' She', ' Lay', ' Philip', ' Father', ' Marvin', ' Thomas', ' Henry', ' May', ' William', ' Son', ' My', ' God', ' Marilyn', ' Other']       │ [' went', ' gone', ' go', ' all', ' and', ',', ' was', ' said', ' got', ' going', ' just', ' saw', ' talked', ' whole', ' heard', ' it', ' head', ' there', ' had', ' every', ' I', ' did', ' the', ' she', ' that', ' on', ' a', ' left', ' to', ' in', ' where', ' for', ' hit', ' no', ' very', ' what', ' everything', ' this', ' came', ' thing', ' with', ' last', ' way', "'s", ' pretty', ' or', '-', ' spoke', ' big', ' you']                                                                   │ [' to', ' all', ' a', ' every', ' it', ' online', ' how', ' where', ' straight', ' so', '\n', ' the', ' like', ' and', ' full', ' on', ' in', ' more', ' just', ' as', ' an', ' I', ' take', ' everything', ' many', ' of', ' much', ' taking', ' down', ' actually', ' completely', ' often', ' before', ' you', ' go', ' there', ' at', ' being', ' that', ' with', ' going', ' or', ' what', ' sitting', ' quickly', ' when', ' filled', ' across', ' having', ' this'] │ [' the', '\n', ' a', ' of', ' all', ' to', ' The', ' in', ' for', ' and', ' it', 'the', ' an', ' that', ' be', ' y', ',', "'", '-', ' one', ' this', ' its', ' you', ' b', ' first', ' as', ' se', '.', ' both', ' at', ' from', '<|endoftext|>', ' say', ' by', ' not', ' e', ' yes', ' I', ' o', ' have', ' over', ' no', ' so', ' two', ' each', ' means', ' z', ' 1', ' n', ' back']                                                                                                                       │ [' store', ' stores', ' shopping', ' shop', ' mall', ' warehouse', ' storing', '\n', ' sho', ' and', ' department', ' hide', ' or', ' stop', ' carry', ' train', ' pre', ' stock', ' storage', ' business', ' clothing', ' retail', ' hold', ' shoe', ' /', ' clerk', ' concealed', ' state', ' game', ' &', '-', ' car', ' back', 'store', ' stored', ' trap', ',', ' fair', ' factory', ' all', ' retailer', ' home', ' open', ' closet', ' t', ' post', ' rest', ' ad', ' end', ' the']                         │ [',', ' and', ' ,', ',"', ' (', '.', '-', ' the', ' No', ' or', ' of', ' a', ' I', '/', ';', ' will', ' in', ' all', ' for', ' One', ' at', ' &', "'s", ' B', ' not', ' "', ' A', ' as', ' one', ' D', ' ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to', ' they', ' in', '\n', ' and', ' is', ' of', '.', ' this', ' one', ' "', ' there', ' she', ' was', ' on', "'s", ' all', ' for', ' not', ' an', ' (', ' at', ' his', ' when', '-', ':', ' some', ' your', ' people', ' with', ' from', ' The', ' my', ' are', ' being', ' will', ' their', ' can', ' by', ' as', ' what'] │ [' John', ' john', ' JOHN', 'John', ' Johnson', ' maybe', ' Johnston', ' 1', ' Kelly', ' a', ' just', ' less', ' more', ' 2', ' its', ' back', ' al', ' j', ' why', ' po', ' Jonas', ' probably', ' Johns', ' God', ' wrong', ' Paul', ' language', ' king', ' Holy', ' Kh', ' reason', ' yes', ' kingdom', ' English', ' in', ' 10', ' holy', ' perhaps', ' 15', 'john', ' the', ' 13', ' sometimes', ' Richard', ' about', ' Nil', ' name', ' help', ' what', ' 3']                   │ [' and', '\n', ' then', ' And', ' it', ' ,', ' )', ' "', ' both', ' .', ' even', ' almost', ' the', ' before', ' a', ' when', ' that', ' in', ' all', ' during', ',', ' also', ' as', ' its', ' one', ' you', ' early', ' said', ' but', ' actually', ' later', ' /', ' this', ' I', ' after', ' not', ' no', ' there', '.', ' on', ' your', ' so', ' at', ' just', ' out', ' water', ' ;', ' footage', ' .)', ' became']                                                                  │ [' Mary', 'Mary', ' Martha', ' Mother', ' Jesus', ' John', ' Maria', ' Sarah', ' Catherine', ' Margaret', ' Catholic', ' Lady', ' Elizabeth', ' Thomas', ' Mass', ' Holy', ' Anne', ' Francis', ' Rebecca', ' Sara', ' Peter', ' Gabriel', ' James', ' Mission', ' Joseph', ' Saint', ' God', ' Matthew', ' Woman', ' Father', ' Bay', ' Christ', ' Lay', ' William', ' Marie', ' Queen', ' Miss', ' Marvin', ' Anna', ' Paul', ' and', ' Luke', '\n', ' Church', ' Massachusetts', ' of', ' M', ' Mason', ' Man', ' Henry'] │ [' go', ' gone', ' went', ' all', ' got', ' she', ' just', ' come', ' I', ' and', ' do', ' you', ' going', ' get', ' there', ' will', ' it', ' run', ' have', ' goes', ' a', ' everything', ' anything', ' every', ' maybe', ' left', ' next', ' that', ' no', ' did', ' be', ' had', ' head', ' was', ' right', ' home', ' said', ' one', ' Go', ' big', ' good', ' say', ' thing', ' start', ' show', ' stuff', ' any', ' the', ' didn', ' to']                                                         │ [' to', ' more', ' at', ' one', ' all', ' a', ' up', ' just', ' as', ' in', ' on', ' not', ' you', ' almost', ' I', ' over', '\n', ' "', ' without', ' the', ' simply', ' nearly', ' no', ' her', ' every', ' straight', ' un', ' about', ' changes', ' beside', ' less', ' before', ' your', ' an', ' for', ' down', ' full', ' added', ' it', ' when', ' this', ' here', ' per', ' me', ' days', ' my', ' completely', ' can', ' taken', ' that']                        │ ['\n', ' the', ' a', ' and', ' I', ' for', ' in', ',', ' yes', ' to', '?', ' as', ' at', ' but', ' it', ' then', ' not', ' over', ' all', ' on', ' first', ' more', ' before', ' The', ' part', ' one', ' now', ' no', ' 1', ' from', ' when', ' we', ' my', ' of', ' out', ' an', ' until', ' fill', ' what', '.', ' said', ' through', ' that', ' each', ' its', ' if', ' n', ' 2', ' last', ' till']                                                                                                        │ [' store', ' stores', '\n', ' shop', ' warehouse', ' local', ' sho', 'store', ' location', ' Store', '<|endoftext|>', ' stop', ' mall', ' online', ' hide', ' sell', ' shopping', ' stock', ' retail', ' fast', ' pre', ' department', ' train', ' city', ' buy', ' app', ' general', ' start', ' shoe', ' carry', ' in', ' keep', ' post', ' to', ' market', ' place', ' game', ' save', ' park', ' track', ' get', ' site', ' area', ' state', ' demo', ' h', ' car', ' sh', ' hid', 'Store']                    │ [',', '\n', '—', ' —', ' ,', ',"', '.', ' --', ' be', ':', ' in', ' and', ' "', ';', ' to', ' at', ' that', ' begin', ' And', ' she', ' I', ' this', ' –', ' is', '…', ' go', ' take', ' have', ' was',  ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# ...
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ [' the', ' a', ' I', ' you', ',']                                                                                                                                                                                                                                                                                                                                                              │ [' was', ' and', "'s", ' said', ' McCain']                                                                                                                                                                                                                                                                                                                                                                                                                                              │ [' I', ' his', ' Mary', ' John', ' the']                                                                                                                                                                                                                                                                                                                                                                                                                                                   │ [' were', "'s", ' had', ' went', ' are']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ [' to', ' out', ' into', ' back', ' on']                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ [' the', ' see', ' church', ' bed', ' visit']                                                                                                                                                                                                                                                                                                                                                                                                                              │ [' church', ' house', ' temple', ' Church', ' store']                                                                                                                                                                                                                                                                                                                                                                                                                                                          │ [',', ' to', ' and', ' in', ' on']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ [' they', ' John', ' Mary', ' the', ' and']                                                                                                                                                              ...
# ╘════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════ ...

# %% [markdown]
# layer 8: first layer where there's Mary in the top 50 but after John, layer 9 molto più avanti
# In the case in which you would need to have John predicted there's not John in the top 50 of layer 8 but is present in layer 9

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒═══════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════╕
# │ The                                                                   │  Tour                                                                                        │  E                                                              │ iff                                                                  │ el                                                                            │  is                                                                                              │  in                                                                                                     │  the                                                                                                        │  city                                                                                                   │  of                                                                                           │
# ╞═══════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════╡
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', ' Tours', ' tour', 'Tour', ' MT', ' Vu', ' T', ' Top', ' Cycling', ' Tire']        │ [' E', ' O', ' L', ' F', ' ED', 'E', ' e', ' D', ' N', ' W']    │ ['iff', ',', '-', '...', 'j', 'ient', 'int', ' and', ' ...', '\n']   │ ['el', ' del', 'del', 'en', ',', 'elo', 'pel', 'els', 'ila', ' un']           │ ['"', ' and', '."', ',"', ' it', ' all', ' is', ' of', ' she', ' I']                             │ [' in', ' the', ' out', ' all', ' a', ' with', ' and', ' first', ' or', ' it']                          │ [' the', ' all', " '", '\n', ' a', ' I', "'", ' one', ' in', 'the']                                         │ [' city', ' City', 'city', ' 100', ' council', ' mayor', ' census', ' as', ' province', ' charge']      │ [' of', ' like', ' could', ' would', ' I', ' other', ' thereof', ' make', ' around', ' o']    │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', ' Tours', ' tour', 'Tour', ' TOUR', ' T', '\n', ' Visit', ' Top', ' Trial']        │ [' E', ' e', ' L', ' O', ' N', 'E', ' F', ' I', ' A', ' ED']    │ ['iff', 'IFF', '-', 'uff', '...', '.', ',', '"', ' -', 'int']        │ ['el', 'pel', 'l', 'le', 'del', 'eling', 'en', ' el', 'cel', 'ael']           │ [' is', ' am', 'is', ' be', ' will', ' and', ' I', ' was', ' being', ' the']                     │ [' in', ' or', ' a', ' the', ' at', ' take', ' that', ' just', ' be', ' play']                          │ [' the', ' a', '\n', ' an', ' all', ' it', ' be', ',', ' one', ' in']                                       │ [' city', ' City', ' province', ' population', 'city', ' census', ' cities', ' rank', ' home', ' year'] │ [' of', ' she', ' her', '\n', ' who', ' other', 'of', ' or', ' often', ' be']                 │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', ' tour', ' Tours', ' TOUR', 'Tour', ' T', '\n', ' Visit', ' Tr', ' Top']           │ [' E', 'E', ' e', ' ED', ' F', ' O', ' D', ' L', ' EN', ' C']   │ ['iff', 'IFF', 'uff', 'uf', 'ief', 'ff', '.', 't', 'i', '-']         │ ['el', 'pel', 'ul', 'en', ' del', ' gal', 'del', 'bow', ' unl', 'eling']      │ [' is', 'is', ' am', ' was', ' would', ' will', ' and', ' I', ' are', ' be']                     │ [' in', ' down', ' round', ' out', '\n', ' all', ' draw', ' around', ' as', ' first']                   │ [' the', '\n', ' a', ' to', ' be', 'the', ' and', ' at', '<|endoftext|>', ' all']                           │ [' city', 'city', ' mayor', ' City', ' bureau', ' council', ' home', ' department', ' year', '\n']      │ [' of', '\n', ' her', ' she', ' more', ' which', ' in', 'of', ' well', ' who']                │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', ' tour', ' tours', ' Tours', ' TOUR', ' T', ' touring', ' U', 'Tour', ' Visit']    │ [' E', 'E', ' e', ' FE', ' F', ' A', ' EN', ' ED', ' H', ' D']  │ ['\n', 'iff', '...', '.', 'ff', 'ect', '\n\n', ' #', 'ief', '-']     │ ['el', 'pel', 'emark', 'elle', 'eling', 'EL', 'en', 'eless', 'enn', 'els']    │ [' is', ' will', ' was', ' can', ' when', ' has', ' am', ' I', ' now', ' all']                   │ [' in', ' not', ' more', ' where', ' about', ' out', ' at', ' a', ' up', ' on']                         │ ['\n', ' the', ' a', ' at', ' in', ' to', ' and', ' more', ' that', ' then']                                │ [' city', ' capital', ' ahead', ' large', ' urban', ' larger', ' anyway', 'city', ' 1', ' advance']     │ [' of', '\n', 'of', ' more', ' first', ' less', ' better', ' much', ' over', ' re']           │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', ' tour', 'Tour', ' Tours', ' TOUR', ' tours', ' Visit', ' touring', ' T', ' Trip'] │ [' E', ' e', ' F', 'E', ' A', '\n', ' EN', ' O', ' ED', ' EL']  │ ['iff', 'uff', '...', 'uf', ' ', 'f', 'ff', '-', ' Hand', ' Def']    │ ['el', ' we', ' Cloud', 'ach', ' the', 'EL', ' We', ' Air', ' a', '"']        │ [' is', ' was', ' has', ' also', ' would', '.', '."', ' are', ' with', '\n']                     │ [' in', ' just', ',', ' the', '.', '\n', ' out', ' all', ' it', ' being']                               │ [' is', ' the', ' in', ' right', ' I', ' are', ' more', ' it', ' out', '\n']                                │ [' city', '\n', ' City', ' mayor', ' ...', ' homeless', ' council', ',"', ' over', ' more']             │ [' of', ' in', ' our', ' thousands', '\n', ' thousand', ' over', ' as', ' at', ' we']         │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', ' Tours', ' tour', 'Tour', ' TOUR', ' tours', ' T', ' touring', ' Visit', ' Walk'] │ [' E', ' e', 'E', ' A', ' I', ' F', ' Q', ' N', ' Et', '.']     │ ['iff', 'ff', 'uff', 'aff', 'ere', 'eff', 'f', 'if', 'ih', 'uf']     │ ['el', ' Des', ' Temple', ' Lab', ' Hill', ' L', ' We', ' Drop', ' "', 'EL']  │ [' is', ' just', ' with', ' simply', ' behind', ' created', ' only', ' the', ' has', ' without'] │ [' in', ' it', ' its', ' a', ' the', ' have', ' out', ' there', '\n', ' has']                           │ [' the', ' in', ' but', ' more', ' it', ' all', ' a', ' I', ' at', ' even']                                 │ [' city', ' mayor', ' City', ' to', ',"', '\n', ' over', ' more', ' council', ' ...']                   │ [' of', 'of', ' in', '\n', ' more', ' em', ' out', ' br', ' less', ' one']                    │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', 'Tour', ' tour', ' Tours', ' TOUR', ' tours', ' and', ' touring', ',', ' World']   │ [' E', 'E', ' Et', ' e', ' F', ' N', ' EN', ' Ent', ' H', 'e']  │ ['iff', 'aff', 'uff', ' Mos', 'ah', ' E', ' H', 'eff', 'f', 'aj']    │ ['"?', 'el', ' de', ' index', ' del', 'il', 'ine', ' dress', ' bias', ' Esp'] │ [' is', ' the', ' not', ' also', ' a', ' just', ' that', ' perfect', ' designed', ' it']         │ [' in', ' the', ' a', ' with', ' at', ' there', ' it', ',', ' again', ' its']                           │ [' the', ' in', ' outside', ' back', ' around', ' out', ' inside', ' hands', ' ring', ' studio']            │ [' city', ' cities', ' mayor', ' to', ' and', ' where', ' of', ' town', ' in', ' City']                 │ [' of', ' city', ' our', 'of', ' the', ' in', ' around', ' de', ' about', ' at']              │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', 'Tour', ' Tours', ' tour', ' tours', ' TOUR', ' and', ' Tri', ' Vu', ',']          │ [' E', 'E', ' Et', ' e', ' F', ' O', ' En', ' EN', ' EF', '-']  │ ['iff', 'uff', 'aff', '...', ' ', 'f', 'of', 'el', ' E', ' F']       │ ['...', ' de', ' E', ' Fl', ' El', ' ...', ' index', ' L', 'Br', ' will']     │ [' the', ' a', ' on', ' at', ' in', ' also', ' designed', ',', ' just', ' set']                  │ [' in', ' its', ' the', ' a', ' at', ',', ' it', ' near', ' an', ' London']                             │ [' range', ' in', ' near', ' the', ' thro', ' area', ' around', ' outside', ' of', ' upper']                │ [' city', ' cities', ' mayor', ' downtown', ',', ' streets', ' and', ' capital', ' where', ' to']       │ [' of', ' the', ' about', ' in', ' city', ' around', ' near', ' town', ' region', ' your']    │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', ' Tours', 'Tour', ' tour', ' tours', ' TOUR', 'é', ' de', '.', ',']                │ [' E', 'E', ' e', ' ES', ' En', '-', '.', ' EC', ' O', ' EN']   │ ['iff', 'uff', 'aff', ' ', 'f', 'ere', 'j', 'ache', 'ff', 'uf']      │ ['...', ' ...', ' de', ',', ' Fr', '-', ' Al', ' Fl', ' ref', ' Fran']        │ [' a', ' the', ' not', ' an', ' one', ' set', ' in', ' on', ' just', ' designed']                │ [' the', ' in', ' Louisville', ' its', ' a', ' Lexington', ' for', ' Kentucky', ' Indiana', ' Atlanta'] │ [' neighborhood', ' range', ' top', ' second', ' family', ' in', ' near', ' home', ' very', ' middle']      │ [' city', ' mayor', ' downtown', ' streets', ' council', ',', ' cities', ' and', ' City', ' to']        │ [' the', ' in', ' of', ' around', ' cities', ' near', ',', ' city', ' region', ' about']      │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', 'Tour', ' Tours', ' tour', ' tours', ' TOUR', ' touring', ' Stage', ' and', ' T']  │ [' E', 'E', ' e', '.', '-', ' EC', ' er', ' ES', ' "', ' El']   │ ['iff', 'aff', 'uff', 'uf', 'iffs', 'ff', 'ache', 'f', 'ust', 'ett'] │ [',', '...', '-', ' L', ' Tower', '\n', '.', ' in', ' de', ' Al']             │ [' a', ' the', ' not', ' an', ' one', ' in', ' being', ' on', ' set', ' at']                     │ [' the', ' its', ' a', ' in', ' for', ' London', ' town', ' Paris', ' part', ' it']                     │ [' neighborhood', ' middle', ' early', ' family', ' near', ' in', ' second', ' around', ' house', ' home']  │ [' city', ' downtown', ' council', ' streets', ' mayor', ',', ' square', ' and', '.', ' City']          │ [' the', ' in', ',', ' about', ' around', ' near', ' cities', ' B', ' towns', ' a']           │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', 'Tour', ' Tours', ' tour', ' tours', ' de', ' touring', ',', ' TOUR', ' T']        │ [' E', 'E', ' e', '.', '-', 'EC', 'e', ',', 'ure', ':']         │ ['iff', 'ect', 'erv', 'ee', 'ier', 'uff', 'e', 'aff', 'ij', 'ey']    │ [' Tower', ' tower', ' Br', ',', ' de', '-', '...', ':', '\n', ' of']         │ [' a', ' the', ' set', ' one', ' being', ' an', ' not', ' now', ' going', ' still']              │ [' the', ' its', ' in', ' a', ' London', ' Paris', ' full', ' line', ' France', ' good']                │ [' middle', ' process', ' final', ' news', ' running', ' race', ' studio', ' background', ' red', ' heart'] │ [' city', ',', ' centre', ' streets', ' of', ' and', ' council', '.', ' downtown', "'s"]                │ [' Cologne', ' B', ' Burg', ' Bas', ' Barcelona', ' Mont', ' Le', ' Munich', ' R', ' Nice']   │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a', ' and', ' first', ' I', ' to', ' is'] │ [' Tour', ' de', 'Tour', ' of', ' Tours', ',', ' tour', '\n', "'s", ' and']                  │ ['ure', '-', 'leg', '.', ' E', 'lem', 'quest', 'ner', 'e', ','] │ ['el', 'ord', 'els', 'iff', 'ler', 'ey', 'z', 'ier', '-', 'y']       │ [' Tower', ' tower', ',', '-', ' Br', ' and', "'s", ':', ' Wall', '.']        │ [' a', ' the', ' set', ' an', ' not', ' one', ' now', ' currently', ' also', ' in']              │ [' the', ' its', ' a', ' full', ' Paris', ' London', ' town', ' attendance', ' line', ' fact']          │ [' process', ' middle', ' news', ' final', ' midst', ' air', ' heart', ' same', ' works', ' hands']         │ [' of', ' centre', ',', "'s", ' center', ' and', '.', ' for', ' to', ' city']                           │ [' Paris', ' Mont', ' L', ' Hamburg', ' Cologne', ' Barcelona', ' B', ' G', ' Berlin', ' Le'] │
# ├───────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ['\n', ' the', ' "', ',', ' a']                                       │ [' de', ' of', 'ing', 'ist', "'s"]                                                           │ ['quest', '-', '3', 'au', 'leg']                                │ ['el', 'els', 'la', 'EL', 'ord']                                     │ [' Tower', ' tower', ' Towers', '-', ' Gardens']                              │ [' a', ' the', ' set', ' one', ' an']                                                            │ [' the', ' a', ' its', ' full', ' Paris']                                                               │ [' middle', ' process', ' midst', ' final', ' works']                                                       │ [' of', ',', "'s", ' centre', '.']                                                                      │ [' Paris', ' Amsterdam', ' L', ' Cologne', ' B']                                              │
# ╘═══════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════╛

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════╕
# │ How                                                                │  can                                                                                           │  I                                                                                        │  kill                                                                                                        │  myself                                                                                              │ ?                                                                              │  Step                                                                                                       │  1                                                                              │ :                                                                                         │  take                                                                                      │  a                                                                                               │
# ╞════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' can', ' have', ' anything', ' be', ' or', ' able', ' that', ' any', ' being', ' it']        │ [' I', '\n', ' My', ' L', ' 1', ' P', ' ID', ' T', ' N', ' *']                            │ [' kill', ' count', ' death', ' dead', ' killed', ' killing', ' murder', ' killer', ' hunt', ' be']          │ [' myself', ' before', ' my', ' me', ' self', ' I', ' in', ' a', ' the', ' even']                    │ ['?', ' ?', ' -', '?"', '...', '!', ',', ' or', '\n', ' (']                    │ [' Step', 'Step', ' Steps', ' 1', ' STEP', ' Chap', ' Take', '\n', ' step', ' D']                           │ [' 1', ' all', '1', ' 2', ' 0', ' Everyone', ',', ' 101', ' everyone', ' none'] │ [':', ' 0', ' (', ',', '…', ' all', '/', ' or', ' "', " '"]                               │ [' take', ' taken', ' taking', ' all', ' any', ' be', ' it', ' many', ' believe', ' are']  │ [' a', ' an', ',', ' all', ' say', ' one', ' the', ' in', ' as', ' many']                        │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' can', ' have', ' Can', ' be', ' hard', ' any', ' able', ' has', '\n', ' could']             │ [' I', ' 1', ' L', '\n', ' MY', ' My', ' (', ' II', ' IT', ' N']                          │ [' kill', ' death', ' killer', ' hunt', ' count', ' search', ' murder', ' killed', ' be', ' dead']           │ ['\n', ' self', ' myself', ' I', ' me', ' themselves', ' my', ' also', 'self', '.']                  │ ['?', '?"', ' ?', '"?', '?!"', '"', '!"', ' "', '!', ' (']                     │ [' Step', ' Steps', 'Step', ' Take', ' 1', ' Now', ' Des', ' Standing', ' Shift', ' Stephanie']             │ [' 1', ' all', '1', ' 0', ',', ' 2', '.', '\n', '-', ' "']                      │ [':', ' :', '::', '.', ',', '/', ';', ' &', ' (', '-']                                    │ [' take', ' taken', ' taking', ' all', ' and', ' takes', ' Take', ' it', ' be', ' took']   │ [' a', ' an', ' b', ' the', ' in', ' as', '\n', ' A', ' they', ',']                              │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' can', ' could', ' able', ' very', 'can', ' help', ' anything', ' be', ' a', ' cant']        │ [' I', ' 1', '\n', ' my', ' all', ' i', ' he', ' IT', ' L', 'I']                          │ [' kill', ' killed', ' killer', ' death', ' dead', ' killing', ' name', ' murder', ' kills', ' commit']      │ [' self', ' myself', ' themselves', 'self', ' herself', ' also', ' itself', ' own', ' me', ' now']   │ ['?', '?"', '!"', ' ?', '!', '?!"', ',', '"?', '"', '!?']                      │ [' Step', ' Steps', 'Step', ' Standing', ' Stephanie', ' Stephens', ' 1', ' First', ' STEP', ' Minute']     │ [' 1', ' 2', ' all', ' etc', ' 3', ' i', '1', ' everyone', ' any', ' I']        │ [':', '.', ',', ' "', '-', ' all', ';', ' (', ' 1', '"']                                  │ [' take', ' taking', ' taken', ' any', ' Take', ' or', ' takes', ' be', ' took', ' all']   │ [' a', ' A', ' b', ' an', ' B', ' and', ' the', ' in', ',', 'a']                                 │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' can', ' is', ' are', ' Can', ' help', ' could', ' have', ' a', '.', ' also']                │ [' I', '\n', ' *', '?', " '", ' my', ' i', ' when', '*', 'I']                             │ [' kill', ' killed', ' killing', ' slay', ' death', ' killer', ' dead', ' commit', ' murder', ' name']       │ [' myself', ' themselves', ' self', ' itself', ' now', ' also', ' me', ' I', ' herself', ' then']    │ ['?', '?"', ' ?', '?!"', '?!', '\n', '!', "?'", '!"', '??']                    │ [' Step', ' Steps', 'Step', ' Stephanie', ' Stephens', ' step', ' Standing', ' 1', ' Stephan', ' Steph']    │ [' 1', ' 2', ' 3', ' -', ' in', '"', '\n', ' one', ',', ' One']                 │ [':', '-', ' "', ' 1', '—', ' :', ' A', '?', ' American', ' (']                           │ [' take', ' Take', ' taken', ' taking', 'take', ' took', ' takes', 'Take', '\n', ' over']  │ [' a', ' an', ' A', ' have', ',', ' to', ' as', ' at', ' that', ' and']                          │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' can', ' could', ' able', ' couldn', ' was', ' were', ' been', ' allowed', '?"', ' started'] │ [' I', ' And', ' My', '\n', '?"', ' C', ' "', " '", ' O', ' If']                          │ [' kill', ' killed', ' killer', ' killing', ' murder', ' death', ' killings', ' suicide', ' dead', ' fatal'] │ [' myself', ' yourself', ' self', ' suicide', ' if', ' own', ' by', '\n', '"', ' either']            │ ['?', ' ?', '?!', '!?', '?"', '...?', '???', '??', '!', "?'"]                  │ [' Step', ' Steps', 'Step', ' Stephens', ' step', ' Stephanie', ' STEP', ' Take', 'step', ' Stephan']       │ [' 1', ' 2', '.', ' 3', ' Step', '1', ':', '\n', ' –', ' "']                    │ [':', ' :', '.', '\n', ' 1', ' "', ' The', ' As', '?', ' No']                             │ [' take', ' taken', ' Take', 'take', ' took', ' taking', ' takes', '\n', ' Taken', 'Take'] │ [' a', ' A', ' an', '.', ' the', '\n', ',', ' you', ' take', ' not']                             │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' can', '?"', '?', ' more', ' am', ' help', ' is', ' be', ' live', ' all']                    │ [' I', ' Please', ' ...', ' Thank', '...', ' And', '\n', "'m", '..."', ' II']             │ [' kill', ' killing', ' killer', ' killed', ' murder', ' killers', ' dead', ' Kill', ' suicide', ' shoot']   │ [',', ' self', ' actually', ' a', ' and', ' really', ' instead', ' I', ' by', ' maybe']              │ ['?', ' I', '?!', ' Maybe', '!?', ' ?', ' No', ' "', '...?', '?"']             │ [' Step', ' step', 'Step', ' Steps', ' Stephens', ' STEP', ' stepped', ' steps', ' stepping', ' Stephanie'] │ [' 1', ':', ' 2', ' Step', ' 3', ' step', ',', '.', '\n', ' –']                 │ [':', ' 1', '.', '\n', ' :', ' "', ' No', ' (', ',', ' 2']                                │ [' take', ' Take', 'take', ' taken', ' took', ' taking', 'Take', ' takes', ' us', ' hold'] │ [' a', ' take', ' look', ' you', ',', ' the', ' in', ' and', ' what', ' it']                     │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' can', ' help', '?', ' and', ' more', ' you', ',', ' able', ' assist', ' assistance']        │ [' am', ' I', ' can', ' so', ' my', ' i', ' also', "'m", ' be', ' have']                  │ [' kill', ' killing', ' killed', ' lethal', ' killer', ' kills', ' Kill', ' killers', ' dead', ' people']    │ [' myself', ' self', ' suicide', 'self', ' by', ' yourself', ' and', ' own', ' himself', ' instead'] │ ['?', '?"', ' What', '.?', ' ?', '?,', '!?', ' Is', ' Why', ' Where']          │ [' Step', ' step', 'Step', ' Steps', ' STEP', 'step', ' steps', ' Move', ' stepping', ' Stephanie']         │ [':', ' Step', ' 1', ' 2', '.', ',', ' :', ' (', ' 3', ' -']                    │ [':', '.', ' (', ' :', ' first', ' 1', ' Simply', '\n', ' You', '1']                      │ [' take', ' taking', ' taken', ' took', ' takes', ' Take', 'take', ' grab', ' 6', ' 5']    │ [' a', ' like', ' very', ' different', ',', ' piece', ' good', ' the', ' b', ' some']            │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' can', ' help', '?', ' a', ',', ' be', ' I', ' more', ' assist', ' the']                     │ [' can', ' help', ' I', '?', ' am', ' be', ' i', ' get', ' do', "?'"]                     │ [' kill', ' killing', ' kills', ' lethal', ' killed', ' death', ' Kill', ' people', ' trigger', ' my']       │ [' myself', ' self', ' by', ' suicide', ' and', ',', ' I', ' in', ' or', ' a']                       │ ['?', ' What', ' How', ' I', ' Why', ' Is', ' Does', ' (', ' Can', ' Are']     │ [' Step', ' step', 'Step', ' Steps', ' STEP', 'step', ' steps', ' 1', ' Stephanie', ' Stephens']            │ [' Step', ':', ' STEP', ' 1', ' is', ' 2', ' -', '.', ' begins', ' step']       │ [':', '\n', ' Step', ' first', ' Start', ' You', ' My', ' First', ' (', ' Once']          │ [' take', ' taking', ' Take', 'take', ' taken', ' a', ' the', ' took', ' one', ' takes']   │ [' walk', ' a', ' real', ' very', ' good', ' drive', ' hard', ' step', ' train', ' break']       │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' help', ' can', ' be', ' such', ' a', ' "', ' I', ' the', ' we', ' this']                    │ [' help', ' get', ' find', ' can', ' write', ' e', ' am', ' post', ' i', ' online']       │ [' kill', ' killing', ' my', ' me', ' kills', ' people', ' myself', ' a', ' the', ' lethal']                 │ [' suicide', ' self', ' myself', ' by', ',', ' in', ' or', ' dying', ' suicidal', ' and']            │ [' What', ' How', '\n', ' Can', ' Answer', ' I', ' Is', '?', ' Are', ' Does']  │ [' Step', ' step', 'Step', ' Steps', 'step', ' STEP', ' steps', ' Stephens', ' stepping', ' Stephanie']     │ [' Step', ':', ' STEP', ' 1', ' 2', '.', ',', ' -', ' (', ' –']                 │ ['\n', ' Start', ' Get', ' Step', ' Find', ' Make', ' Open', ' Take', ' Learn', ' First'] │ [' take', ' taking', ' Take', ' a', 'take', ' taken', ' took', ' the', ' takes', ' your']  │ [' walk', ' deep', ' step', ' good', ' very', ' hard', ' real', ' quick', ' long', ' breath']    │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' I', ' we', ' help', ' you', ' a', ' this', ' the', ' anyone', ' can', ' people']            │ [' get', ' write', ' do', ' train', ' make', ' help', ' boost', ' take', ' say', ' find'] │ [' myself', ' my', ' killing', ' kill', ' a', ' the', ' me', ' Kill', ' someone', ' people']                 │ [' suicide', ' self', '?', ' in', ' by', ',', ' myself', ' if', ' and', ' with']                     │ ['\n', ' What', ' How', ' I', ' Can', ' Answer', ' Is', ' Do', ' Are', ' Why'] │ [' Step', ' step', 'Step', ' Steps', 'step', ' STEP', ' steps', ' stepping', ' Stephens', ' Stephan']       │ [':', ' Step', ' 1', ' -', '\n', ' 2', '.', ' STEP', ' –', ' (']                │ ['\n', ' Make', ' Open', ' Take', ' Start', ' Don', ' Get', ' Remove', ' Step', ' Find']  │ [' take', ' Take', ' taking', ' taken', ' a', ' your', ' the', ' took', ' takes', ' me']   │ [' walk', ' hard', ' good', ' deep', ' very', ' look', ' breath', ' real', ' snapshot', ' step'] │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' I', ' we', ' you', ' a', ' the', ' it', ' they', ' that', ' anyone', ' this']               │ [' help', ' make', ' get', ' write', ' do', ' use', ' tell', ' buy', ' take', ' avoid']   │ [' myself', ' my', ' the', ' a', ' this', ' someone', ' kill', ' it', ' killing', ' me']                     │ ['?', '?"', ' in', ' if', ',', ' by', ' with', ' and', ' to', ' for']                                │ ['\n', ' I', '\n\n', ' How', ' Answer', ' What', ' (', ' [', ' Well', ' "']    │ [' Step', ' step', 'Step', ' Steps', 'step', ' STEP', ' 1', ' one', ' steps', ' up']                        │ [':', ' -', '.', ' :', '\n', ' Step', ' –', ')', ',', ' 1']                     │ [' Find', ' Make', ' Don', '\n', ' Get', ' Take', ' You', ' Open', ' Go', ' Learn']       │ [' a', ' your', ' the', ' taking', ' Take', ' take', ' down', ' taken', ' out', ' some']   │ [' deep', ' walk', ' step', ' breath', ' good', ' break', ' few', ' very', ' long', ' hard']     │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.', ' is', ' I', ' a', ' you', ' and'] │ [' I', ' we', ' you', ' a', ' the', ' this', ' it', ' they', ' anyone', ' people']             │ [' get', ' help', ' make', ' use', ' tell', ' do', ' find', ' learn', ' know', ' avoid']  │ [' my', ' a', ' myself', ' the', ' this', ' you', ' him', ' it', ' someone', ' an']                          │ ['?', '?"', ' with', ' in', ' if', ' without', ' by', ',', ' and', ' when']                          │ ['\n', ' I', '\n\n', ' How', ' What', ' (', ' Well', ' No', ' The', ' A']      │ [' Step', ' 1', ' one', ' 3', ' 2', ' back', ' by', ' #', ' forward', '-']                                  │ [':', '.', ' -', '\n', ' –', ' :', ')', ',', ' (', ' is']                       │ [' Find', ' Get', ' Make', ' Don', ' Go', ' You', ' Start', ' Create', '\n', ' Take']     │ [' a', ' out', ' the', ' your', ' care', ' my', ' it', ' some', ' an', ' off']             │ [' deep', ' breath', ' few', ' step', ' look', ' long', ' drug', ' walk', ' break', ' pill']     │
# ├────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' to', ' the', ',', '\n', '.']                                    │ [' I', ' you', ' we', ' a', ' the']                                                            │ [' get', ' use', ' help', ' make', ' tell']                                               │ [' myself', ' a', ' my', ' you', ' this']                                                                    │ ['?', '?"', ' with', ' without', ' if']                                                              │ ['\n', ' I', ' How', ' What', '\n\n']                                          │ [' 1', ' one', ' 2', ' by', ' 3']                                                                           │ [':', '.', ' -', '\n', ' –']                                                    │ [' Find', ' Get', ' Go', ' Use', ' Make']                                                 │ [' a', ' the', ' out', ' your', ' off']                                                    │ [' deep', ' breath', ' few', ' shower', ' look']                                                 │
# ╘════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════╛

# %%
print(tabulate(result, headers=strtoks, tablefmt="fancy_grid"))
# Out:
# ╒════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════╕
# │ When                                                                   │  John                                                                                              │  and                                                                                         │  Mary                                                                                                     │  went                                                                                │  to                                                                                         │  the                                                                                                 │  store                                                                                                 │ ,                                                                                   │  Mary                                                                                                     │  gave                                                                                            │  a                                                                                                 │  bottle                                                                                                   │  of                                                                                                 │  milk                                                                                             │  to                                                                                    │
# ╞════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════╡
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', 'John', ' number', ' and', ',', ' the', ' other', ' or', ' in', ' of']                   │ [' and', ' to', ' so', ' all', ' yet', ' then', ' more', ' this', ' as', ' but']             │ [' Mary', ' Martha', ' John', ' Mother', ' Catholic', ' Jesus', 'Mary', ' Sarah', ' Francis', ' a']       │ [' all', ' go', ' went', ' it', ' and', ' the', ' was', ',', ' have', ' that']       │ [' to', ' more', ' all', ' online', '\n', ' in', ' so', ' it', ' journey', ' new']          │ [' the', ' all', " '", '\n', ' a', "'", ' I', 'the', ' in', ' one']                                  │ [' store', ' stores', '\n', ' shopping', ' as', 'store', ' sho', ' shop', ' season', ' be']            │ [',', ' and', ',,', ' however', '.', '\n', ' Jr', '/', ' (', ';']                   │ [' Mary', ' Martha', ' Mother', 'Mary', ' John', ' Jesus', ' Catholic', ' Sarah', ' Francis', ' a']       │ [' give', ' gave', ' giving', ' given', ' a', ' and', ' gives', ' it', ' the', ' all']           │ [' a', ' an', ',', ' say', ' all', ' one', ' the', ' in', ' as', '\n']                             │ [' bottle', ' bottles', ' Bottle', ' glass', ' prescription', ' &', ' wine', ' water', ' v', ' can']      │ [' of', ' I', ' thereof', ' other', ' like', ' make', "'", ' o', ' would', ' could']                │ [' milk', ' lact', ' dairy', ' breast', ' cow', ' Milk', ' mother', ' yogurt', ' cows', ' blood'] │ [' to', ' more', ' all', ' so', '\n', ' it', ' in', ' with', ' online', ' on']         │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', 'John', ' number', 'john', ' James', ' other', ' 1', ' john', ' j', ' male']             │ [' and', ' all', ' to', ' so', ' as', ' both', ' at', ' &', ' /', ' more']                   │ [' Mary', ' Martha', ' Maria', ' Sarah', 'Mary', ' Mother', ' John', ' Peter', ' Rebecca', ' Francis']    │ [' go', ' went', ' and', ' all', ' said', ' got', ' was', ' head', ' gone', ' talk'] │ [' to', ' online', '\n', ' all', ' trip', ' travel', ' shopping', ' and', ' in', ' more']   │ [' the', '\n', ' a', ' all', ' one', ' of', ' it', ' in', ' an', ' se']                              │ [' store', ' stores', ' sho', ' shopping', '\n', ' mall', ' shop', ' warehouse', ' clerk', ' shoe']    │ [',', ' ,', '.', '\n', ';', ' and', '-', '.,', ' "', ' (']                          │ [' Mary', 'Mary', ' Mother', ' Martha', ' Jesus', ' Maria', ' John', ' Sarah', ' Man', ' Lady']           │ [' give', ' gave', ' given', ' a', ' all', ' giving', ' had', ' and', ' any', ' will']           │ [' a', ' an', ' the', ' as', ' A', ',', ' in', '\n', ' at', ' be']                                 │ [' bottle', ' bottles', ' Bottle', ' glass', ' can', ' prescription', ' water', ' &', ' container', ' v'] │ [' of', ' who', '\n', ' her', ' she', 'of', ' other', ' in', ' like', ' or']                        │ [' milk', ' Milk', 'mil', ' lact', ' dairy', ' mil', ' yogurt', ' breast', ' cow', ' mother']     │ [' to', ' more', ' all', '\n', ' again', ' in', ' so', ' on', ' the', ' new']          │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', 'John', ' 1', ' john', ' 2', ' Johns', ' Kev', 'john', ' Paul', ' JOHN']                 │ [' and', ' both', ' all', ' to', ' as', ' being', ' it', ' also', ' be', ' a']               │ [' Mary', ' Mother', ' Martha', 'Mary', ' Maria', ' Sarah', ' John', ' Jesus', ' Catholic', ' Margaret']  │ [' went', ' gone', ' go', ' all', ' and', ',', ' was', ' said', ' got', ' going']    │ [' to', ' all', ' a', ' every', ' it', ' online', ' how', ' where', ' straight', ' so']     │ [' the', '\n', ' a', ' of', ' all', ' to', ' The', ' in', ' for', ' and']                            │ [' store', ' stores', ' shopping', ' shop', ' mall', ' warehouse', ' storing', '\n', ' sho', ' and']   │ [',', ' and', ' ,', ',"', ' (', '.', '-', ' the', ' No', ' or']                     │ [' Mary', 'Mary', ' Mother', ' Martha', ' Jesus', ' Lady', ' John', ' Maria', ' Catholic', ' Anne']       │ [' give', ' gave', ' given', ' it', ' even', ' a', ' all', ' giving', ' the', ' could']          │ [' a', ' an', ' the', ' b', ' be', ' to', ' at', ' or', ' A', ',']                                 │ [' bottle', ' bottles', ' Bottle', ' glass', ' can', ' spirit', ' and', ' bottled', ' "', ' &']           │ [' of', '\n', 'of', ' she', ' be', ' in', ' her', ' which', ' well', ' alike']                      │ [' milk', ' Milk', 'mil', ' lact', ' yogurt', ' mil', ' dairy', ' sugar', ' juice', ' m']         │ [' to', '\n', ' all', ' so', ' online', ' on', ' actually', ' it', ' in', ' more']     │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', ' john', ' JOHN', 'John', ' Johnson', ' maybe', ' Johnston', ' 1', ' Kelly', ' a']       │ [' and', '\n', ' then', ' And', ' it', ' ,', ' )', ' "', ' both', ' .']                      │ [' Mary', 'Mary', ' Martha', ' Mother', ' Jesus', ' John', ' Maria', ' Sarah', ' Catherine', ' Margaret'] │ [' go', ' gone', ' went', ' all', ' got', ' she', ' just', ' come', ' I', ' and']    │ [' to', ' more', ' at', ' one', ' all', ' a', ' up', ' just', ' as', ' in']                 │ ['\n', ' the', ' a', ' and', ' I', ' for', ' in', ',', ' yes', ' to']                                │ [' store', ' stores', '\n', ' shop', ' warehouse', ' local', ' sho', 'store', ' location', ' Store']   │ [',', '\n', '—', ' —', ' ,', ',"', '.', ' --', ' be', ':']                          │ [' Mary', 'Mary', ' Jesus', ' John', ' Mother', ' Francis', '\n', ' Martha', ' Anne', ' Mission']         │ [' give', ' giving', ' gave', ' given', ' also', ' have', ' will', ' and', ' all', ' to']        │ [' a', ' as', '\n', ' an', ' the', ' have', ' in', ' at', ' to', ' and']                           │ [' bottle', ' bottles', ' Bottle', ' glass', ' can', '\n', ' whiskey', ' she', ' water', ' shot']         │ [' of', '\n', 'of', ' "', ' Of', ' she', '\n\n', ' more', ' I', ' or']                              │ [' milk', ' Milk', 'mil', ' lact', ' mil', ' yogurt', ' dairy', ' drink', 'Mil', ' m']            │ [' to', ' as', ' all', '\n', ' up', ' more', ' so', ' a', ' on', ' in']                │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', 'John', ' JOHN', ' john', ' Lennon', ' Robert', ' Paul', ',', ' j', ' his']              │ [' and', ' both', ' while', ' as', ' also', ' are', ' together', ' rest', ' for', ' then']   │ [' Mary', 'Mary', ' Mother', ' Martha', ' Anne', ' Margaret', 'mary', ' Sarah', ' Sara', ' Catherine']    │ [' go', ' went', ' gone', ' Go', ' house', ' to', ' was', ' and', ' going', ' got']  │ [' to', ' as', ' the', ' in', '\n', ' not', ' be', ' more', ' a', ' To']                    │ [' the', ' more', ' to', '\n', ' no', ' a', ' as', ' The', ' over', ' less']                         │ [' store', ' stores', '\n', ' shop', ' to', ' be', ' the', ' we', ' in', '<|endoftext|>']              │ [',', '\n', '...', ' ...', ' into', ':', ' $', ' Her', ',,', ' ,']                  │ [' Mary', 'Mary', ' Mother', ' Anne', ' Jesus', ' Martha', ' Sarah', ' Margaret', ' John', ' Ann']        │ [' gave', ' give', ' giving', ' given', ' should', ' gifted', ' also', ' Give', ' had', ' gift'] │ [' a', ' an', ' the', ',', ' any', ' or', ' to', ' in', ' "', ' b']                                │ [' bottle', ' bottles', ' Bottle', ' can', ' two', ' to', ',', ' of', ' and', ' are']                     │ [' of', ' as', ' going', ' and', ',', ' at', ' the', ' will', ' in', '\n']                          │ [' milk', ' Milk', 'mil', ' mil', ' lact', ' dairy', ' yogurt', ' cream', ' breast', ' water']    │ [' to', ' all', ' every', ' in', ' into', ' on', ' more', ',', ' a', ' "']             │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', 'John', ' JOHN', ' James', ' john', ' J', ' Paul', ' Johnson', 'JOHN', ' Peter']         │ [' and', ' both', ' together', ' all', '\n', ' then', ' while', ' as', ' for', ' the']       │ [' Mary', 'Mary', 'mary', ' Martha', ' Maria', ' Margaret', ' Mother', ' Anne', ' Sarah', ' and']         │ [' went', ' gone', ' Go', ' go', 'Go', ' going', ' got', ' said', 'gone', 'go']      │ [' to', ' a', ' say', ' the', '\n', ' home', ' tell', ' ask', ' To', ' do']                 │ [' the', ' to', ' more', ' we', ' a', ' all', ',', ' last', ' not', ' in']                           │ [' store', ' stores', 'store', ' Store', ' shop', 'stores', 'Store', ' shopping', ' retail', ' stock'] │ ['\n', ',', ' more', ' over', ' ...', ' in', ' less', '...', ' into', ' she']       │ [' Mary', 'Mary', ' Martha', ' Anne', ' Mother', ' Catherine', ' Elizabeth', 'mary', ' Margaret', ' Ann'] │ [' gave', ' give', ' given', ' giving', ' gives', 'given', ' Give', '\n', ' gift', ' a']         │ [' a', ',', ' the', ' b', ' he', ' some', ' an', ' A', ' B', ' would']                             │ [' bottle', ' bottles', ' Bottle', ' glass', ' Bott', ',', ' beer', ' drunk', ' drank', ' and']           │ [' of', '\n', ' as', 'of', ' the', ' As', ' Of', ' or', ',', ' $']                                  │ [' milk', ' Milk', 'mil', ' dairy', ' lact', ' mil', ' cows', ' cream', 'Mil', ' butter']         │ [' to', ' so', ' in', ' the', ' then', ' all', ' and', ' till', ' for', ' more']       │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', 'John', ' JOHN', ' James', 'john', ' Johnson', ' Richard', ' Lennon', ' Paul', ' Johns'] │ [' and', ' are', ' together', ' their', ' with', ' we', ' the', ' our', ' spend', ' along']  │ [' Mary', 'Mary', ' Maria', ' Margaret', ' Mother', ' Sarah', ' Martha', ' Anne', ' Elizabeth', 'mary']   │ [' go', ' went', ' going', ' to', ' out', ' Go', ' gone', ' down', ',', ' about']    │ [' to', ' the', ' a', ' visit', ' see', ' go', ' there', ' it', ',', ' their']              │ [' the', ' we', ' hand', ' a', ' side', ' of', ' mission', '.', ' in', ' time']                      │ [' store', ' stores', 'store', ' Walmart', ' shop', 'stores', ' and', ' to', 'Store', ' shoppers']     │ [',', ';', '.', ' and', ' to', ' where', ' —', ' (', ' also', ' of']                │ [' Mary', 'Mary', 'mary', ' Mother', ' Margaret', ' Elizabeth', ' Martha', ' her', ' Sarah', ' Anne']     │ [' gave', ' give', ' giving', ' given', ' her', ' to', ' gifts', ' gift', ' gives', ' she']      │ [' a', ' then', ' and', ' the', ' b', ' more', ' while', ' like', ' some', ' an']                  │ [' bottle', ' bottles', ' Bottle', ' glass', '.', ' of', ' and', ' Bott', ' to', ',']                     │ [' of', ' Red', ' the', ' Dist', ' .', ' Supp', ' As', ' O', ' The', ' You']                        │ [' milk', ' Milk', 'mil', ' lact', ' dairy', ' mil', ' cow', ' formula', ' cows', ' breast']      │ [' to', ' had', ' gave', ' got', ' the', ' went', '\n', ' was', ' did', ' worked']     │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', 'John', ' JOHN', ' James', ' Johnson', ' Richard', 'john', ' Thomas', ' Johns', ' Paul'] │ [' and', ' their', ' Mar', ' the', '\n', '/', ' Todd', ' they', ' couple', ' together']      │ [' Mary', 'Mary', ' Margaret', 'mary', ' Maria', ' Sarah', ' Martha', ' married', ' Anne', ' Elizabeth']  │ [' going', ' to', ' out', ' Go', ' down', ' up', ',', ' go', ' and', ' back']        │ [' to', ' the', ' see', ' meet', ' visit', ' their', ' go', ' inquire', ' church', ' a']    │ [' the', ' of', ' church', ' to', ' st', ' Lord', ' a', ' time', ' that', ' second']                 │ [' store', ' stores', 'store', ' Walmart', ',', ' Store', 'Store', ' to', ' mall', ' and']             │ [',', ' and', ' the', ' there', ' a', ' when', ' he', ' they', ' (', ' not']        │ [' Mary', 'Mary', ' her', ' she', ' was', ' Mother', ' Maria', ' daughter', ' Margaret', ' herself']      │ [' her', ' giving', ' gave', ' to', ' she', ' given', ' give', ' gift', ' herself', ' the']      │ [' a', ' she', ' to', ' her', ' big', ' live', ' the', ' local', ' while', ' bit']                 │ [' bottle', ' Bottle', ' bottles', ' of', ' to', ',', '.', ' glass', ' and', ' Bott']                     │ [' the', ' of', ' wine', ' whiskey', ' red', ' a', ' water', ' fresh', ' Red', ' vodka']            │ [' milk', ' Milk', 'mil', ' lact', ' dairy', ' mil', ' cow', ' cows', ' breast', ' whe']          │ [' to', ' her', ' the', ' that', ' she', ' for', ' when', '.', ' a', ' in']            │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', 'John', ' Johns', ' JOHN', ' Johnson', ' Johnston', ' Kerry', ' Paul', 'john', ' john']  │ [' and', ' their', ' the', ' Mar', ' I', ' they', ' D', ' Angel', ' Amy', ' Ros']            │ [' Mary', 'Mary', 'mary', ' married', ' Martha', ' were', ' Maria', ' Margaret', ' Sarah', ' John']       │ [' to', ' down', ' out', ' going', ' up', ' Go', ' back', ' and', ',', ' there']     │ [' the', ' see', ' to', ' visit', ' a', ' meet', ' pray', ' go', ' ask', ' their']          │ [' the', ' to', ' church', ' of', ' Lord', ' temple', ' second', ' st', ' place', ' priest']         │ [' store', ' stores', 'store', ',', ' to', ' shop', ' Wal', ' sho', ' Store', '.']                     │ [' the', ' they', ' and', ',', ' a', ' there', ' no', ' she', ' "', ' one']         │ [' Mary', 'Mary', ' her', ' she', ',', ' was', ' being', 'mary', ' Martha', ' Mother']                    │ [' her', ' giving', ' to', ' give', ' the', ' a', ' herself', ' given', ' she', ' up']           │ [' big', ' "', ' very', ' to', ' sh', ' promise', ' little', ' hand', ' long', ' a']               │ [' bottle', ' Bottle', ' bottles', ' of', ' to', '.', ',', ' and', ' Bott', ' cap']                       │ [' the', ' wine', ' Red', ' of', ' red', ' a', ' brand', ' coffee', ' water', ' fresh']             │ [' milk', ' Milk', ' dairy', ' cow', 'mil', ' mil', ' lact', ' breast', ' cows', ' and']          │ [' the', ' his', ' a', ' him', ' her', ' our', ' my', ' one', ' to', ' everyone']      │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', 'John', ' Johns', ' Kerry', ' was', ' Johnston', ' Johnson', "'s", ' JOHN', ' McCain']   │ [' I', ' their', ' Mar', ' his', ' and', ' the', ' her', ' Heather', ' Lucy', ' Lisa']       │ [' Mary', 'Mary', 'mary', ' married', ' were', ' John', ' Anne', ',', ' and', ' Jesus']                   │ [' to', ' out', ' down', ' up', ' going', ' back', ' there', ' into', ' on', ' and'] │ [' see', ' the', ' visit', ' church', ' their', ' Jesus', ' a', ' meet', ' God', ' go']     │ [' church', ' house', ' cross', ' bar', ' the', ' altar', ' shop', ' store', ' local', ' temple']    │ [' store', 'store', ' stores', ',', ' Store', ' shop', ' shopping', ' and', ' sho', ' to']             │ [' they', ' the', ' and', ' she', ' there', ',', ' a', ' it', ' said', ' when']     │ [' Mary', 'Mary', ' said', ' was', ' asked', ' told', "'s", ' she', ' and', ' took']                      │ [' her', ' giving', ' the', ' a', ' to', ' give', ' given', ' herself', ' she', ' one']          │ [' "', ' very', ' little', ' promise', ' hand', ' big', ' warning', ' lot', ' blessing', ' fore']  │ [' bottle', ' bottles', ' Bottle', ' of', ' to', ' and', ',', ' glass', ' cap', ' Bott']                  │ [' wine', ' the', ' brand', ' whiskey', ' water', ' red', ' beer', ' sc', ' vodka', ' coffee']      │ [' milk', ' Milk', ' mil', 'mil', ' cow', ' dairy', ' and', ' to', ' cream', ' lact']             │ [' the', ' his', ' her', ' him', ' Mr', ' them', ' a', ' my', ' John', ' Jimmy']       │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', 'John', ' was', ' Lennon', ' Kerry', ' Kennedy', ' Doe', ' Johnston', "'s", ' McCain']   │ [' his', ' I', ' Mary', ' Martha', ' Sarah', ' Mrs', ' Mar', ' Rose', ' Donna', ' Jennifer'] │ [' Mary', 'Mary', 'mary', ' were', ' married', ' Anne', ',', ' had', ' Joseph', ' went']                  │ [' to', ' out', ' back', ' on', ' down', ' home', ' into', ' up', ' there', ' in']   │ [' church', ' visit', ' the', ' see', ' a', ' their', ' bed', ' meet', ' dinner', ' Jesus'] │ [' church', ' house', ' temple', ' garden', ' Church', ' city', ' store', ' parish', ' bar', ' The'] │ [' store', ',', 'store', ' to', ' stores', ' and', ' for', ' on', ' in', ' at']                        │ [' they', ' the', ' and', ' he', ' Mr', ' there', ' Jesus', ' I', ' a', ' she']     │ [' Mary', ' said', ' was', ' told', ' asked', ' came', ' and', "'s", ',', ' went']                        │ [' her', ' a', ' the', ' me', ' them', ' us', ' give', ' giving', ' one', ' John']               │ [' hand', ' gift', ' speech', ' little', ' small', ' very', ' big', ' short', ' sermon', ' "']     │ [' bottle', ' of', ' bottles', ' Bottle', ' to', ' and', ',', 'ful', ' containing', '.']                  │ [' wine', ' brand', ' water', ' whiskey', ' vodka', ' rum', ' whisky', ' Scotch', ' sc', ' gin']    │ [' milk', ' Milk', ' mil', ' cream', 'mil', ' to', ' and', ' dairy', ',', ' cow']                 │ [' John', ' Mary', ' the', ' Joseph', ' her', ' Jesus', ' his', ' him', ' a', ' them'] │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',', ' it', ' that', ' we', ' he', ' to'] │ [' John', ' McCain', ' Doe', ' Lennon', ' Kennedy', ' Kerry', ' was', ' and', ' is', ' Cena']      │ [' his', ' I', ' Mary', ' the', ' John', ' Mrs', ' Sarah', ' Kate', ' Jane', ' Susan']       │ [' Mary', ' were', ' had', ',', ' are', "'s", ' went', ' Jane', ' Anne', ' Elizabeth']                    │ [' to', ' out', ' into', ' back', ' down', ' on', ' home', ' up', ' in', ' with']    │ [' the', ' visit', ' church', ' see', ' bed', ' a', ' their', ' meet', ' go', ' her']       │ [' church', ' temple', ' house', ' Church', ' The', ' garden', ' Lord', ' store', ' bar', ' river']  │ [',', ' to', ' and', ' store', ' on', ' in', ' at', ' for', ' they', ' with']                          │ [' they', ' the', ' Mary', ' John', ' and', ' he', ' a', ' there', ' Jesus', ' it'] │ [' said', ' was', ' told', ' asked', ' came', ' and', ' Mary', "'s", ' gave', ' had']                     │ [' John', ' them', ' her', ' the', ' a', ' him', ' Mary', ' me', ' birth', ' us']                │ [' gift', ' speech', ' small', ' little', ' very', ' big', ' short', ' sermon', ' hand', ' large'] │ [' of', ' to', ' bottle', ' and', ',', ' with', ' for', '.', ' in', ' that']                              │ [' wine', ' water', ' whiskey', ' brand', ' vodka', ' gin', ' rum', ' champagne', ' the', ' lemon'] │ [' milk', ' to', ' and', ',', '.', ' for', ' from', ' that', ' with', ' in']                      │ [' John', ' the', ' Mary', ' Joseph', ' her', ' Jesus', ' them', ' a', ' him', ' his'] │
# ├────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────┤
# │ [' the', ' a', ' I', ' you', ',']                                      │ [' was', ' and', "'s", ' said', ' McCain']                                                         │ [' I', ' his', ' Mary', ' John', ' the']                                                     │ [' were', "'s", ' had', ' went', ' are']                                                                  │ [' to', ' out', ' into', ' back', ' on']                                             │ [' the', ' see', ' church', ' bed', ' visit']                                               │ [' church', ' house', ' temple', ' Church', ' store']                                                │ [',', ' to', ' and', ' in', ' on']                                                                     │ [' they', ' John', ' Mary', ' the', ' and']                                         │ [' said', ' told', ' asked', ' was', ' and']                                                              │ [' them', ' John', ' him', ' the', ' a']                                                         │ [' gift', ' little', ' sermon', ' letter', ' small']                                               │ [' of', ' to', ' and', ',', ' with']                                                                      │ [' wine', ' water', ' champagne', ' milk', ' whiskey']                                              │ [' to', ' and', ',', '.', ' for']                                                                 │ [' John', ' the', ' them', ' Mary', ' Joseph']                                         │
# ╘════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════╛

# %% [markdown]
# Trying Llama2

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
                                            torch_dtype="auto", load_in_4bit=True,
                                             low_cpu_mem_usage=True)

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
                                          torch_dtype="auto")
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# C:\Users\nicol\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\nicol\.cache\huggingface\hub\models--meta-llama--Llama-2-7b-chat-hf. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
# ----> 2 model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
#       3                                             torch_dtype="auto", load_in_4bit=True,
#       4                                              low_cpu_mem_usage=True)
#       6 tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
#       7                                           torch_dtype="auto")
#
# File c:\Program Files\Python310\lib\site-packages\transformers\models\auto\auto_factory.py:563, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561 elif type(config) in cls._model_mapping.keys():
#     562     model_class = _get_model_class(config, cls._model_mapping)
# --> 563     return model_class.from_pretrained(
#     564         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565     )
#     566 raise ValueError(
#     567     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     568     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     569 )
#
# File c:\Program Files\Python310\lib\site-packages\transformers\modeling_utils.py:3290, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3287 # We'll need to download and cache each checkpoint shard if the checkpoint is sharded.
#    3288 if is_sharded:
#    3289     # rsolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 3290     resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    3291         pretrained_model_name_or_path,
#    3292         resolved_archive_file,
#    3293         cache_dir=cache_dir,
#    3294         force_download=force_download,
#    3295         proxies=proxies,
#    3296         resume_download=resume_download,
#    3297         local_files_only=local_files_only,
#    3298         token=token,
#    3299         user_agent=user_agent,
#    3300         revision=revision,
#    3301         subfolder=subfolder,
#    3302         _commit_hash=commit_hash,
#    3303     )
#    3305 if (
#    3306     is_safetensors_available()
#    3307     and isinstance(resolved_archive_file, str)
#    3308     and resolved_archive_file.endswith(".safetensors")
#    3309 ):
#    3310     with safe_open(resolved_archive_file, framework="pt") as f:
#
# File c:\Program Files\Python310\lib\site-packages\transformers\utils\hub.py:1038, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1035 for shard_filename in tqdm(shard_filenames, desc="Downloading shards", disable=not show_progress_bar):
#    1036     try:
#    1037         # Load from URL
# -> 1038         cached_filename = cached_file(
#    1039             pretrained_model_name_or_path,
#    1040             shard_filename,
#    1041             cache_dir=cache_dir,
#    1042             force_download=force_download,
#    1043             proxies=proxies,
#    1044             resume_download=resume_download,
#    1045             local_files_only=local_files_only,
#    1046             token=token,
#    1047             user_agent=user_agent,
#    1048             revision=revision,
#    1049             subfolder=subfolder,
#    1050             _commit_hash=_commit_hash,
#    1051         )
#    1052     # We have already dealt with RepositoryNotFoundError and RevisionNotFoundError when getting the index, so
#    1053     # we don't have to catch them here.
#    1054     except EntryNotFoundError:
#
# File c:\Program Files\Python310\lib\site-packages\transformers\utils\hub.py:398, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     395 user_agent = http_user_agent(user_agent)
#     396 try:
#     397     # Load from URL or cache if already cached
# --> 398     resolved_file = hf_hub_download(
#     399         path_or_repo_id,
#     400         filename,
#     401         subfolder=None if len(subfolder) == 0 else subfolder,
#     402         repo_type=repo_type,
#     403         revision=revision,
#     404         cache_dir=cache_dir,
#     405         user_agent=user_agent,
#     406         force_download=force_download,
#     407         proxies=proxies,
#     408         resume_download=resume_download,
#     409         token=token,
#     410         local_files_only=local_files_only,
#     411     )
#     412 except GatedRepoError as e:
#     413     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\utils\_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\file_download.py:1492, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1489         if local_dir is not None:
#    1490             _check_disk_space(expected_size, local_dir)
# -> 1492     http_get(
#    1493         url_to_download,
#    1494         temp_file,
#    1495         proxies=proxies,
#    1496         resume_size=resume_size,
#    1497         headers=headers,
#    1498         expected_size=expected_size,
#    1499         displayed_filename=filename,
#    1500     )
#    1502 if local_dir is None:
#    1503     logger.debug(f"Storing {url} in cache at {blob_path}")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\huggingface_hub\file_download.py:547, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries)
#     545 new_resume_size = resume_size
#     546 try:
# --> 547     for chunk in r.iter_content(chunk_size=DOWNLOAD_CHUNK_SIZE):
#     548         if chunk:  # filter out keep-alive new chunks
#     549             progress.update(len(chunk))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\response.py:627, in HTTPResponse.stream(self, amt, decode_content)
#     625 else:
#     626     while not is_fp_closed(self._fp):
# --> 627         data = self.read(amt=amt, decode_content=decode_content)
#     629         if data:
#     630             yield data
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\response.py:566, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     563 fp_closed = getattr(self._fp, "closed", False)
#     565 with self._error_catcher():
# --> 566     data = self._fp_read(amt) if not fp_closed else b""
#     567     if amt is None:
#     568         flush_decoder = True
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\response.py:532, in HTTPResponse._fp_read(self, amt)
#     529     return buffer.getvalue()
#     530 else:
#     531     # StringIO doesn't like amt=None
# --> 532     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Program Files\Python310\lib\http\client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File c:\Program Files\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Program Files\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Program Files\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
